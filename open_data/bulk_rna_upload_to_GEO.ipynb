# %% [markdown]
# This notebook prepares the bulk RNAseq data for upload to GEO

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import os

# %%
df = pd.read_csv('/Users/djuna/Documents/ABCA7lof2/bulkRNAseq/abca7_rna_seq_metadata_with_seqIDs.csv')

# %%
df
# Out:
#    SampleName     Line      Treatment  Vol (ul)        Conc      Type  Pool  \
# 0          E1  Control            H20        30  2-10 ng/ul  totalRNA   NaN
# 1          E2  Control            H20        30  2-10 ng/ul  totalRNA   NaN
# 2          Y1     Y622            H20        30  2-10 ng/ul  totalRNA   NaN
# 3          Y2     Y622            H20        30  2-10 ng/ul  totalRNA   NaN
# 4          Y3     Y622            H20        30  2-10 ng/ul  totalRNA   NaN
# 5          Y4     Y622            H20        30  2-10 ng/ul  totalRNA   NaN
# 6          Y5     Y622            H20        30  2-10 ng/ul  totalRNA   NaN
# 7          Y6     Y622            H20        30  2-10 ng/ul  totalRNA   NaN
# 8          Y7     Y622            H20        30  2-10 ng/ul  totalRNA   NaN
# 9          Y8     Y622            H20        30  2-10 ng/ul  totalRNA   NaN
# 10         C1     Y622  Choline2Weeks        30  2-10 ng/ul  totalRNA   NaN
# 11         C2     Y622  Choline2Weeks        30  2-10 ng/ul  totalRNA   NaN
# 12         C3     Y622  Choline2Weeks        30  2-10 ng/ul  totalRNA   NaN
# 13         C4     Y622  Choline2Weeks        30  2-10 ng/ul  totalRNA   NaN
# 14         C5     Y622  Choline2Weeks        30  2-10 ng/ul  totalRNA   NaN
# 15         C6     Y622  Choline2Weeks        30  2-10 ng/ul  totalRNA   NaN
# 16         C7     Y622  Choline2Weeks        30  2-10 ng/ul  totalRNA   NaN
# 17         C8     Y622  Choline2Weeks        30  2-10 ng/ul  totalRNA   NaN
# 18         G1       G2            H20        30  2-10 ng/ul  totalRNA   NaN
# 19         G2       G2            H20        30  2-10 ng/ul  totalRNA   NaN
# 20         G4       G2            H20        30  2-10 ng/ul  totalRNA   NaN
# 21         G5       G2            H20        30  2-10 ng/ul  totalRNA   NaN
# 22         G6       G2            H20        30  2-10 ng/ul  totalRNA   NaN
# 23         G7       G2            H20        30  2-10 ng/ul  totalRNA   NaN
# 24         G8       G2            H20        30  2-10 ng/ul  totalRNA   NaN
# 25        G10       G2            H20        30  2-10 ng/ul  totalRNA   NaN
#
#    Genome                                              Notes           SeqID
# 0   human  diff & extraction batch 1 (1 well, DOI:101624,...      D24-18553
# 1   human  diff & extraction batch 1 (1 well, DOI:101624,...      D24-18554
# 2   human  diff & extraction batch 1 (1 well, DOI:101624,...      D24-18555
# 3   human  diff & extraction batch 1 (1 well, DOI:101624,...      D24-18556
# 4   human  diff & extraction batch 1 (1 well, DOI:101624,...      D24-18557
# 5   human  diff & extraction batch 1 (1 well, DOI:101624,...      D24-18558
# 6   human  diff & extraction batch 1 (1 well, DOI:101624,...      D24-18559
# 7   human         diff & extraction batch 2 (2 wells pooled)      D24-18560
# 8   human         diff & extraction batch 2 (2 wells pooled)      D24-18561
# 9   human         diff & extraction batch 2 (2 wells pooled)      D24-18562
# 10  human  diff & extraction batch 1 (1 well, DOI:101624,...      D24-18563
# 11  human  diff & extraction batch 1 (1 well, DOI:101624,...      D24-18564
# 12  human  diff & extraction batch 1 (1 well, DOI:101624,...      D24-18565
# 13  human  diff & extraction batch 1 (1 well, DOI:101624,...      D24-18566
# 14  human  diff & extraction batch 1 (1 well, DOI:101624,...      D24-18567
# 15  human         diff & extraction batch 2 (2 wells pooled)      D24-18568
# 16  human         diff & extraction batch 2 (2 wells pooled)      D24-18569
# 17  human         diff & extraction batch 2 (2 wells pooled)      D24-18570
# 18  human  diff & extraction batch 1 (1 well, DOI:101624,...      D24-18571
# 19  human  diff & extraction batch 1 (1 well, DOI:101624,...      D24-18572
# 20  human  diff & extraction batch 1 (1 well, DOI:101624,...      D24-18574
# 21  human  diff & extraction batch 1 (1 well, DOI:101624,...      D24-18575
# 22  human  diff & extraction batch 1 (1 well, DOI:101624,...      D24-18576
# 23  human         diff & extraction batch 2 (2 wells pooled)      D24-18577
# 24  human         diff & extraction batch 2 (2 wells pooled)      D24-18578
# 25  human         diff & extraction batch 2 (2 wells pooled)      D24-18580

# %%
# removing batch 2 from the counts matrix and renaming columns 

counts = pd.read_csv('/Users/djuna/Documents/ABCA7lof2/bulkRNAseq/counts.txt', sep='\t', comment="#")

df = pd.read_csv('/Users/djuna/Documents/ABCA7lof2/bulkRNAseq/abca7_rna_seq_metadata_with_seqIDs.csv')

no_batch2 = df[~df["Notes"].str.contains(r"\bbatch\s*2\b", case=False, na=False)].copy()
no_batch2['SeqID'] = [x.split('    ')[1].split(' ')[0] for x in no_batch2["SeqID"]]
keep_ids = np.array(no_batch2['SeqID'])
fixed_cols = ["Geneid", "Chr", "Start", "End", "Strand", "Length", "gene_name", "gene_type"]
columns_to_keep = ['/home/gridsan/djuna/homer/github/ABCA7lof2/bulkRNAseq/mapped/241121Tsa_' + x + '_Aligned.out.sam' for x in keep_ids]

subset = counts[fixed_cols + columns_to_keep]
subset.columns = list(subset.columns[:8])  + [x.split('_')[1].split('Aligned')[0] for x in subset.columns[8:]]

# sanity check
for i in subset.columns[8:]:
    x = np.array(subset[[i]])
    y = np.array(counts[[f'/home/gridsan/djuna/homer/github/ABCA7lof2/bulkRNAseq/mapped/241121Tsa_{i}_Aligned.out.sam']])
    print(np.array_equal(x, y))
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %%
# format metadata for GEO
dictionary = {'Control': 'control', 'Y622': 'p.Tyr622*', 'G2': 'p.Glu50fs*3'}
teatment_dict = {'H20': '+ H20 (last 14 days)', 'Choline2Weeks': '+ CDP-choline (last 14 days))'}
metadata_geo_format = no_batch2.copy()

# calculate days apart
fmt = "%m%d%y"
d1 = datetime.strptime('101624', fmt)
d2 = datetime.strptime('111324', fmt)
days_apart = (d2 - d1).days

# add the metadata
metadata_geo_format['library name'] = metadata_geo_format['SeqID']
metadata_geo_format['title'] = metadata_geo_format['Line'].map(dictionary) + ' ' + metadata_geo_format['Treatment'].map(teatment_dict) + ' ' + 'replicate ' + (list(np.arange(2).astype(str)) + list(np.arange(5).astype(str))*3)
metadata_geo_format['library strategy'] = 'RNA-seq'
metadata_geo_format['organism'] = metadata_geo_format['Genome']
metadata_geo_format['tissue'] = np.nan
metadata_geo_format['cell line'] = metadata_geo_format['Line'].map(dictionary)
metadata_geo_format['cell type'] = 'iPSC-derivded induced neurons'
metadata_geo_format['genotype'] = 'ABCA7' + metadata_geo_format['Line'].map(dictionary)
metadata_geo_format['treatment'] = metadata_geo_format['Treatment'].map(teatment_dict)
metadata_geo_format['time'] = 'Day ' + str(days_apart)
metadata_geo_format['molecule'] = 'total RNA'
metadata_geo_format['single or paired-end'] = 'paired-end'
metadata_geo_format['instrument model'] = 'Element AVITI'
metadata_geo_format['description'] = ['Column name in counts.txt: ' + x for x in metadata_geo_format['SeqID']]
metadata_geo_format['processed data file'] = 'counts.txt'
metadata_geo_format['processed data file 2'] = np.nan
metadata_geo_format['raw file 1'] = ['241121Tsa_' + x + '_1_sequence.fastq' for x in metadata_geo_format['SeqID']]
metadata_geo_format['raw file 2'] = ['241121Tsa_' + x + '_2_sequence.fastq' for x in metadata_geo_format['SeqID']]

columns_to_keep = ['library name', 'title', 'library strategy', 'organism', 'tissue', 'cell line', 'cell type', 'genotype', 'treatment', 'time', 'molecule', 'single or paired-end', 'instrument model', 'description', 'processed data file', 'processed data file 2', 'raw file 1', 'raw file 2']
metadata_geo_format = metadata_geo_format[columns_to_keep]
metadata_geo_format.index = np.arange(len(metadata_geo_format))

# %%
metadata_geo_format
# Out:
#    library name                                              title  \
# 0     D24-18553           control + H20 (last 14 days) replicate 0
# 1     D24-18554           control + H20 (last 14 days) replicate 1
# 2     D24-18555         p.Tyr622* + H20 (last 14 days) replicate 0
# 3     D24-18556         p.Tyr622* + H20 (last 14 days) replicate 1
# 4     D24-18557         p.Tyr622* + H20 (last 14 days) replicate 2
# 5     D24-18558         p.Tyr622* + H20 (last 14 days) replicate 3
# 6     D24-18559         p.Tyr622* + H20 (last 14 days) replicate 4
# 7     D24-18563  p.Tyr622* + CDP-choline (last 14 days)) replic...
# 8     D24-18564  p.Tyr622* + CDP-choline (last 14 days)) replic...
# 9     D24-18565  p.Tyr622* + CDP-choline (last 14 days)) replic...
# 10    D24-18566  p.Tyr622* + CDP-choline (last 14 days)) replic...
# 11    D24-18567  p.Tyr622* + CDP-choline (last 14 days)) replic...
# 12    D24-18571       p.Glu50fs*3 + H20 (last 14 days) replicate 0
# 13    D24-18572       p.Glu50fs*3 + H20 (last 14 days) replicate 1
# 14    D24-18574       p.Glu50fs*3 + H20 (last 14 days) replicate 2
# 15    D24-18575       p.Glu50fs*3 + H20 (last 14 days) replicate 3
# 16    D24-18576       p.Glu50fs*3 + H20 (last 14 days) replicate 4
#
#    library strategy organism  tissue    cell line  \
# 0           RNA-seq    human     NaN      control
# 1           RNA-seq    human     NaN      control
# 2           RNA-seq    human     NaN    p.Tyr622*
# 3           RNA-seq    human     NaN    p.Tyr622*
# 4           RNA-seq    human     NaN    p.Tyr622*
# 5           RNA-seq    human     NaN    p.Tyr622*
# 6           RNA-seq    human     NaN    p.Tyr622*
# 7           RNA-seq    human     NaN    p.Tyr622*
# 8           RNA-seq    human     NaN    p.Tyr622*
# 9           RNA-seq    human     NaN    p.Tyr622*
# 10          RNA-seq    human     NaN    p.Tyr622*
# 11          RNA-seq    human     NaN    p.Tyr622*
# 12          RNA-seq    human     NaN  p.Glu50fs*3
# 13          RNA-seq    human     NaN  p.Glu50fs*3
# 14          RNA-seq    human     NaN  p.Glu50fs*3
# 15          RNA-seq    human     NaN  p.Glu50fs*3
# 16          RNA-seq    human     NaN  p.Glu50fs*3
#
#                         cell type          genotype  \
# 0   iPSC-derivded induced neurons      ABCA7control
# 1   iPSC-derivded induced neurons      ABCA7control
# 2   iPSC-derivded induced neurons    ABCA7p.Tyr622*
# 3   iPSC-derivded induced neurons    ABCA7p.Tyr622*
# 4   iPSC-derivded induced neurons    ABCA7p.Tyr622*
# 5   iPSC-derivded induced neurons    ABCA7p.Tyr622*
# 6   iPSC-derivded induced neurons    ABCA7p.Tyr622*
# 7   iPSC-derivded induced neurons    ABCA7p.Tyr622*
# 8   iPSC-derivded induced neurons    ABCA7p.Tyr622*
# 9   iPSC-derivded induced neurons    ABCA7p.Tyr622*
# 10  iPSC-derivded induced neurons    ABCA7p.Tyr622*
# 11  iPSC-derivded induced neurons    ABCA7p.Tyr622*
# 12  iPSC-derivded induced neurons  ABCA7p.Glu50fs*3
# 13  iPSC-derivded induced neurons  ABCA7p.Glu50fs*3
# 14  iPSC-derivded induced neurons  ABCA7p.Glu50fs*3
# 15  iPSC-derivded induced neurons  ABCA7p.Glu50fs*3
# 16  iPSC-derivded induced neurons  ABCA7p.Glu50fs*3
#
#                         treatment    time   molecule single or paired-end  \
# 0            + H20 (last 14 days)  Day 28  total RNA           paired-end
# 1            + H20 (last 14 days)  Day 28  total RNA           paired-end
# 2            + H20 (last 14 days)  Day 28  total RNA           paired-end
# 3            + H20 (last 14 days)  Day 28  total RNA           paired-end
# 4            + H20 (last 14 days)  Day 28  total RNA           paired-end
# 5            + H20 (last 14 days)  Day 28  total RNA           paired-end
# 6            + H20 (last 14 days)  Day 28  total RNA           paired-end
# 7   + CDP-choline (last 14 days))  Day 28  total RNA           paired-end
# 8   + CDP-choline (last 14 days))  Day 28  total RNA           paired-end
# 9   + CDP-choline (last 14 days))  Day 28  total RNA           paired-end
# 10  + CDP-choline (last 14 days))  Day 28  total RNA           paired-end
# 11  + CDP-choline (last 14 days))  Day 28  total RNA           paired-end
# 12           + H20 (last 14 days)  Day 28  total RNA           paired-end
# 13           + H20 (last 14 days)  Day 28  total RNA           paired-end
# 14           + H20 (last 14 days)  Day 28  total RNA           paired-end
# 15           + H20 (last 14 days)  Day 28  total RNA           paired-end
# 16           + H20 (last 14 days)  Day 28  total RNA           paired-end
#
#    instrument model                           description processed data file  \
# 0     Element AVITI  Column name in counts.txt: D24-18553          counts.txt
# 1     Element AVITI  Column name in counts.txt: D24-18554          counts.txt
# 2     Element AVITI  Column name in counts.txt: D24-18555          counts.txt
# 3     Element AVITI  Column name in counts.txt: D24-18556          counts.txt
# 4     Element AVITI  Column name in counts.txt: D24-18557          counts.txt
# 5     Element AVITI  Column name in counts.txt: D24-18558          counts.txt
# 6     Element AVITI  Column name in counts.txt: D24-18559          counts.txt
# 7     Element AVITI  Column name in counts.txt: D24-18563          counts.txt
# 8     Element AVITI  Column name in counts.txt: D24-18564          counts.txt
# 9     Element AVITI  Column name in counts.txt: D24-18565          counts.txt
# 10    Element AVITI  Column name in counts.txt: D24-18566          counts.txt
# 11    Element AVITI  Column name in counts.txt: D24-18567          counts.txt
# 12    Element AVITI  Column name in counts.txt: D24-18571          counts.txt
# 13    Element AVITI  Column name in counts.txt: D24-18572          counts.txt
# 14    Element AVITI  Column name in counts.txt: D24-18574          counts.txt
# 15    Element AVITI  Column name in counts.txt: D24-18575          counts.txt
# 16    Element AVITI  Column name in counts.txt: D24-18576          counts.txt
#
#     processed data file 2                            raw file 1  \
# 0                     NaN  241121Tsa_D24-18553_1_sequence.fastq
# 1                     NaN  241121Tsa_D24-18554_1_sequence.fastq
# 2                     NaN  241121Tsa_D24-18555_1_sequence.fastq
# 3                     NaN  241121Tsa_D24-18556_1_sequence.fastq
# 4                     NaN  241121Tsa_D24-18557_1_sequence.fastq
# 5                     NaN  241121Tsa_D24-18558_1_sequence.fastq
# 6                     NaN  241121Tsa_D24-18559_1_sequence.fastq
# 7                     NaN  241121Tsa_D24-18563_1_sequence.fastq
# 8                     NaN  241121Tsa_D24-18564_1_sequence.fastq
# 9                     NaN  241121Tsa_D24-18565_1_sequence.fastq
# 10                    NaN  241121Tsa_D24-18566_1_sequence.fastq
# 11                    NaN  241121Tsa_D24-18567_1_sequence.fastq
# 12                    NaN  241121Tsa_D24-18571_1_sequence.fastq
# 13                    NaN  241121Tsa_D24-18572_1_sequence.fastq
# 14                    NaN  241121Tsa_D24-18574_1_sequence.fastq
# 15                    NaN  241121Tsa_D24-18575_1_sequence.fastq
# 16                    NaN  241121Tsa_D24-18576_1_sequence.fastq
#
#                               raw file 2
# 0   241121Tsa_D24-18553_2_sequence.fastq
# 1   241121Tsa_D24-18554_2_sequence.fastq
# 2   241121Tsa_D24-18555_2_sequence.fastq
# 3   241121Tsa_D24-18556_2_sequence.fastq
# 4   241121Tsa_D24-18557_2_sequence.fastq
# 5   241121Tsa_D24-18558_2_sequence.fastq
# 6   241121Tsa_D24-18559_2_sequence.fastq
# 7   241121Tsa_D24-18563_2_sequence.fastq
# 8   241121Tsa_D24-18564_2_sequence.fastq
# 9   241121Tsa_D24-18565_2_sequence.fastq
# 10  241121Tsa_D24-18566_2_sequence.fastq
# 11  241121Tsa_D24-18567_2_sequence.fastq
# 12  241121Tsa_D24-18571_2_sequence.fastq
# 13  241121Tsa_D24-18572_2_sequence.fastq
# 14  241121Tsa_D24-18574_2_sequence.fastq
# 15  241121Tsa_D24-18575_2_sequence.fastq
# 16  241121Tsa_D24-18576_2_sequence.fastq

# %%
df
# Out:
#    SampleName     Line      Treatment  Vol (ul)        Conc      Type  Pool  \
# 0          E1  Control            H20        30  2-10 ng/ul  totalRNA   NaN
# 1          E2  Control            H20        30  2-10 ng/ul  totalRNA   NaN
# 2          Y1     Y622            H20        30  2-10 ng/ul  totalRNA   NaN
# 3          Y2     Y622            H20        30  2-10 ng/ul  totalRNA   NaN
# 4          Y3     Y622            H20        30  2-10 ng/ul  totalRNA   NaN
# 5          Y4     Y622            H20        30  2-10 ng/ul  totalRNA   NaN
# 6          Y5     Y622            H20        30  2-10 ng/ul  totalRNA   NaN
# 7          Y6     Y622            H20        30  2-10 ng/ul  totalRNA   NaN
# 8          Y7     Y622            H20        30  2-10 ng/ul  totalRNA   NaN
# 9          Y8     Y622            H20        30  2-10 ng/ul  totalRNA   NaN
# 10         C1     Y622  Choline2Weeks        30  2-10 ng/ul  totalRNA   NaN
# 11         C2     Y622  Choline2Weeks        30  2-10 ng/ul  totalRNA   NaN
# 12         C3     Y622  Choline2Weeks        30  2-10 ng/ul  totalRNA   NaN
# 13         C4     Y622  Choline2Weeks        30  2-10 ng/ul  totalRNA   NaN
# 14         C5     Y622  Choline2Weeks        30  2-10 ng/ul  totalRNA   NaN
# 15         C6     Y622  Choline2Weeks        30  2-10 ng/ul  totalRNA   NaN
# 16         C7     Y622  Choline2Weeks        30  2-10 ng/ul  totalRNA   NaN
# 17         C8     Y622  Choline2Weeks        30  2-10 ng/ul  totalRNA   NaN
# 18         G1       G2            H20        30  2-10 ng/ul  totalRNA   NaN
# 19         G2       G2            H20        30  2-10 ng/ul  totalRNA   NaN
# 20         G4       G2            H20        30  2-10 ng/ul  totalRNA   NaN
# 21         G5       G2            H20        30  2-10 ng/ul  totalRNA   NaN
# 22         G6       G2            H20        30  2-10 ng/ul  totalRNA   NaN
# 23         G7       G2            H20        30  2-10 ng/ul  totalRNA   NaN
# 24         G8       G2            H20        30  2-10 ng/ul  totalRNA   NaN
# 25        G10       G2            H20        30  2-10 ng/ul  totalRNA   NaN
#
#    Genome                                              Notes           SeqID
# 0   human  diff & extraction batch 1 (1 well, DOI:101624,...      D24-18553
# 1   human  diff & extraction batch 1 (1 well, DOI:101624,...      D24-18554
# 2   human  diff & extraction batch 1 (1 well, DOI:101624,...      D24-18555
# 3   human  diff & extraction batch 1 (1 well, DOI:101624,...      D24-18556
# 4   human  diff & extraction batch 1 (1 well, DOI:101624,...      D24-18557
# 5   human  diff & extraction batch 1 (1 well, DOI:101624,...      D24-18558
# 6   human  diff & extraction batch 1 (1 well, DOI:101624,...      D24-18559
# 7   human         diff & extraction batch 2 (2 wells pooled)      D24-18560
# 8   human         diff & extraction batch 2 (2 wells pooled)      D24-18561
# 9   human         diff & extraction batch 2 (2 wells pooled)      D24-18562
# 10  human  diff & extraction batch 1 (1 well, DOI:101624,...      D24-18563
# 11  human  diff & extraction batch 1 (1 well, DOI:101624,...      D24-18564
# 12  human  diff & extraction batch 1 (1 well, DOI:101624,...      D24-18565
# 13  human  diff & extraction batch 1 (1 well, DOI:101624,...      D24-18566
# 14  human  diff & extraction batch 1 (1 well, DOI:101624,...      D24-18567
# 15  human         diff & extraction batch 2 (2 wells pooled)      D24-18568
# 16  human         diff & extraction batch 2 (2 wells pooled)      D24-18569
# 17  human         diff & extraction batch 2 (2 wells pooled)      D24-18570
# 18  human  diff & extraction batch 1 (1 well, DOI:101624,...      D24-18571
# 19  human  diff & extraction batch 1 (1 well, DOI:101624,...      D24-18572
# 20  human  diff & extraction batch 1 (1 well, DOI:101624,...      D24-18574
# 21  human  diff & extraction batch 1 (1 well, DOI:101624,...      D24-18575
# 22  human  diff & extraction batch 1 (1 well, DOI:101624,...      D24-18576
# 23  human         diff & extraction batch 2 (2 wells pooled)      D24-18577
# 24  human         diff & extraction batch 2 (2 wells pooled)      D24-18578
# 25  human         diff & extraction batch 2 (2 wells pooled)      D24-18580

# %%
metadata_geo_format
# Out:
#    library name                                              title  \
# 0     D24-18553           control + H20 (last 14 days) replicate 0
# 1     D24-18554           control + H20 (last 14 days) replicate 1
# 2     D24-18555         p.Tyr622* + H20 (last 14 days) replicate 0
# 3     D24-18556         p.Tyr622* + H20 (last 14 days) replicate 1
# 4     D24-18557         p.Tyr622* + H20 (last 14 days) replicate 2
# 5     D24-18558         p.Tyr622* + H20 (last 14 days) replicate 3
# 6     D24-18559         p.Tyr622* + H20 (last 14 days) replicate 4
# 7     D24-18563  p.Tyr622* + CDP-choline (last 14 days)) replic...
# 8     D24-18564  p.Tyr622* + CDP-choline (last 14 days)) replic...
# 9     D24-18565  p.Tyr622* + CDP-choline (last 14 days)) replic...
# 10    D24-18566  p.Tyr622* + CDP-choline (last 14 days)) replic...
# 11    D24-18567  p.Tyr622* + CDP-choline (last 14 days)) replic...
# 12    D24-18571       p.Glu50fs*3 + H20 (last 14 days) replicate 0
# 13    D24-18572       p.Glu50fs*3 + H20 (last 14 days) replicate 1
# 14    D24-18574       p.Glu50fs*3 + H20 (last 14 days) replicate 2
# 15    D24-18575       p.Glu50fs*3 + H20 (last 14 days) replicate 3
# 16    D24-18576       p.Glu50fs*3 + H20 (last 14 days) replicate 4
#
#    library strategy organism  tissue    cell line  \
# 0           RNA-seq    human     NaN      control
# 1           RNA-seq    human     NaN      control
# 2           RNA-seq    human     NaN    p.Tyr622*
# 3           RNA-seq    human     NaN    p.Tyr622*
# 4           RNA-seq    human     NaN    p.Tyr622*
# 5           RNA-seq    human     NaN    p.Tyr622*
# 6           RNA-seq    human     NaN    p.Tyr622*
# 7           RNA-seq    human     NaN    p.Tyr622*
# 8           RNA-seq    human     NaN    p.Tyr622*
# 9           RNA-seq    human     NaN    p.Tyr622*
# 10          RNA-seq    human     NaN    p.Tyr622*
# 11          RNA-seq    human     NaN    p.Tyr622*
# 12          RNA-seq    human     NaN  p.Glu50fs*3
# 13          RNA-seq    human     NaN  p.Glu50fs*3
# 14          RNA-seq    human     NaN  p.Glu50fs*3
# 15          RNA-seq    human     NaN  p.Glu50fs*3
# 16          RNA-seq    human     NaN  p.Glu50fs*3
#
#                         cell type          genotype  \
# 0   iPSC-derivded induced neurons      ABCA7control
# 1   iPSC-derivded induced neurons      ABCA7control
# 2   iPSC-derivded induced neurons    ABCA7p.Tyr622*
# 3   iPSC-derivded induced neurons    ABCA7p.Tyr622*
# 4   iPSC-derivded induced neurons    ABCA7p.Tyr622*
# 5   iPSC-derivded induced neurons    ABCA7p.Tyr622*
# 6   iPSC-derivded induced neurons    ABCA7p.Tyr622*
# 7   iPSC-derivded induced neurons    ABCA7p.Tyr622*
# 8   iPSC-derivded induced neurons    ABCA7p.Tyr622*
# 9   iPSC-derivded induced neurons    ABCA7p.Tyr622*
# 10  iPSC-derivded induced neurons    ABCA7p.Tyr622*
# 11  iPSC-derivded induced neurons    ABCA7p.Tyr622*
# 12  iPSC-derivded induced neurons  ABCA7p.Glu50fs*3
# 13  iPSC-derivded induced neurons  ABCA7p.Glu50fs*3
# 14  iPSC-derivded induced neurons  ABCA7p.Glu50fs*3
# 15  iPSC-derivded induced neurons  ABCA7p.Glu50fs*3
# 16  iPSC-derivded induced neurons  ABCA7p.Glu50fs*3
#
#                         treatment    time   molecule single or paired-end  \
# 0            + H20 (last 14 days)  Day 28  total RNA           paired-end
# 1            + H20 (last 14 days)  Day 28  total RNA           paired-end
# 2            + H20 (last 14 days)  Day 28  total RNA           paired-end
# 3            + H20 (last 14 days)  Day 28  total RNA           paired-end
# 4            + H20 (last 14 days)  Day 28  total RNA           paired-end
# 5            + H20 (last 14 days)  Day 28  total RNA           paired-end
# 6            + H20 (last 14 days)  Day 28  total RNA           paired-end
# 7   + CDP-choline (last 14 days))  Day 28  total RNA           paired-end
# 8   + CDP-choline (last 14 days))  Day 28  total RNA           paired-end
# 9   + CDP-choline (last 14 days))  Day 28  total RNA           paired-end
# 10  + CDP-choline (last 14 days))  Day 28  total RNA           paired-end
# 11  + CDP-choline (last 14 days))  Day 28  total RNA           paired-end
# 12           + H20 (last 14 days)  Day 28  total RNA           paired-end
# 13           + H20 (last 14 days)  Day 28  total RNA           paired-end
# 14           + H20 (last 14 days)  Day 28  total RNA           paired-end
# 15           + H20 (last 14 days)  Day 28  total RNA           paired-end
# 16           + H20 (last 14 days)  Day 28  total RNA           paired-end
#
#    instrument model                           description processed data file  \
# 0     Element AVITI  Column name in counts.txt: D24-18553          counts.txt
# 1     Element AVITI  Column name in counts.txt: D24-18554          counts.txt
# 2     Element AVITI  Column name in counts.txt: D24-18555          counts.txt
# 3     Element AVITI  Column name in counts.txt: D24-18556          counts.txt
# 4     Element AVITI  Column name in counts.txt: D24-18557          counts.txt
# 5     Element AVITI  Column name in counts.txt: D24-18558          counts.txt
# 6     Element AVITI  Column name in counts.txt: D24-18559          counts.txt
# 7     Element AVITI  Column name in counts.txt: D24-18563          counts.txt
# 8     Element AVITI  Column name in counts.txt: D24-18564          counts.txt
# 9     Element AVITI  Column name in counts.txt: D24-18565          counts.txt
# 10    Element AVITI  Column name in counts.txt: D24-18566          counts.txt
# 11    Element AVITI  Column name in counts.txt: D24-18567          counts.txt
# 12    Element AVITI  Column name in counts.txt: D24-18571          counts.txt
# 13    Element AVITI  Column name in counts.txt: D24-18572          counts.txt
# 14    Element AVITI  Column name in counts.txt: D24-18574          counts.txt
# 15    Element AVITI  Column name in counts.txt: D24-18575          counts.txt
# 16    Element AVITI  Column name in counts.txt: D24-18576          counts.txt
#
#     processed data file 2                            raw file 1  \
# 0                     NaN  241121Tsa_D24-18553_1_sequence.fastq
# 1                     NaN  241121Tsa_D24-18554_1_sequence.fastq
# 2                     NaN  241121Tsa_D24-18555_1_sequence.fastq
# 3                     NaN  241121Tsa_D24-18556_1_sequence.fastq
# 4                     NaN  241121Tsa_D24-18557_1_sequence.fastq
# 5                     NaN  241121Tsa_D24-18558_1_sequence.fastq
# 6                     NaN  241121Tsa_D24-18559_1_sequence.fastq
# 7                     NaN  241121Tsa_D24-18563_1_sequence.fastq
# 8                     NaN  241121Tsa_D24-18564_1_sequence.fastq
# 9                     NaN  241121Tsa_D24-18565_1_sequence.fastq
# 10                    NaN  241121Tsa_D24-18566_1_sequence.fastq
# 11                    NaN  241121Tsa_D24-18567_1_sequence.fastq
# 12                    NaN  241121Tsa_D24-18571_1_sequence.fastq
# 13                    NaN  241121Tsa_D24-18572_1_sequence.fastq
# 14                    NaN  241121Tsa_D24-18574_1_sequence.fastq
# 15                    NaN  241121Tsa_D24-18575_1_sequence.fastq
# 16                    NaN  241121Tsa_D24-18576_1_sequence.fastq
#
#                               raw file 2
# 0   241121Tsa_D24-18553_2_sequence.fastq
# 1   241121Tsa_D24-18554_2_sequence.fastq
# 2   241121Tsa_D24-18555_2_sequence.fastq
# 3   241121Tsa_D24-18556_2_sequence.fastq
# 4   241121Tsa_D24-18557_2_sequence.fastq
# 5   241121Tsa_D24-18558_2_sequence.fastq
# 6   241121Tsa_D24-18559_2_sequence.fastq
# 7   241121Tsa_D24-18563_2_sequence.fastq
# 8   241121Tsa_D24-18564_2_sequence.fastq
# 9   241121Tsa_D24-18565_2_sequence.fastq
# 10  241121Tsa_D24-18566_2_sequence.fastq
# 11  241121Tsa_D24-18567_2_sequence.fastq
# 12  241121Tsa_D24-18571_2_sequence.fastq
# 13  241121Tsa_D24-18572_2_sequence.fastq
# 14  241121Tsa_D24-18574_2_sequence.fastq
# 15  241121Tsa_D24-18575_2_sequence.fastq
# 16  241121Tsa_D24-18576_2_sequence.fastq

# %%
# save files for upload to GEO
out_path = '/Users/djuna/Documents/abca7_dryad/for_GEO'
metadata_geo_format.to_csv(
    os.path.join(out_path, "metadata_geo_format.txt"),
    sep="\t",
    index=False)

subset.to_csv(
    os.path.join(out_path, "counts.txt"),
    sep="\t",
    index=False)

# %%
# save directories to copy 
dirs = [f'/home/gridsan/djuna/homer/github/ABCA7lof2/bulkRNAseq/raw_data/241121Tsa/{x}-6997E' for x in metadata_geo_format['library name']]

files = []
for i in range(len(dirs)):
    files.append(np.array(dirs)[i] + '/' + np.array(metadata_geo_format['raw file 1'])[i])

for i in range(len(dirs)):
    files.append(np.array(dirs)[i] + '/' + np.array(metadata_geo_format['raw file 2'])[i])

out_file = '/Users/djuna/Documents/abca7_dryad/for_GEO/files_to_copy.txt'
with open(out_file, "w", encoding="utf-8") as fh:
    for path in files:
        fh.write(f"{path}\n")

# %%
sums = pd.read_csv(out_path + '/md5sums_241121Tsa.txt', sep=' ', header=None)

# %%
sums_dictionary = dict(zip(sums.iloc[:,2], sums.iloc[:,0]))

# %%
[print(sums_dictionary[f'./{x.split("_")[1]}-6997E/' + x]) for x in metadata_geo_format['raw file 1']]
# Out:
# 4753a0a2b6d26b805d923f0e0bf89b12
# 9f30611ba848a8b6fb7a8d07cbc2798c
# 3c27698cab64c1757f03674d3fdf03a2
# d78dd242cb995317db4a765c303e969d
# 7054bad0c2b30eca7d8c1feae8a3836d
# b904e8c975b6451cfc8618c94db69826
# 1ded8c14aa8c642e540e1d9760c2763f
# 33c282580ddacdf7a148c6422abe1943
# 72aeabd8da7dce01b71e5d5b9e5ac8f7
# d41d8cd98f00b204e9800998ecf8427e
# 93aff76990a2fb879e3467cca4156b86
# 4ce3b4602b71fec6b58fe6f354f2176f
# 96c093e4f3cce404da9239ff4ec0a270
# 5970480aebc7be3b9fd1abf905487e35
# d2edca09c55a18e8ba15ffca080f080a
# b79b2aee07423e194f7b3c3c8a0c5280
# 0df1b253377eb9b1debfe668512bbf04
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
[print(sums_dictionary[f'./{x.split("_")[1]}-6997E/' + x]) for x in metadata_geo_format['raw file 2']]
# Out:
# 6ecc784fc9e68348b859abd0849f1796
# 3e288dab0fc5a9e75d62b240092bd69d
# 7f9e50db45d5265596084c0741a81d51
# 6f1338aa088a7768f82fcd7d1d18a2a7
# 545ceb2f44eec894eb01964a85a6d1d6
# 374117427b75beafa10160b313356d7c
# b6f6e679583e73107f1c06b386c5563f
# b3fd1bdfe7b0c00707162ef67a123a5c
# fb6c939312730f391c3e1bdca7e6fddc
# d41d8cd98f00b204e9800998ecf8427e
# e7d8676ee689360f8663443ae7e3b773
# 8591d7c26e6ee64b9656e9055b76ca82
# 83e6eb3a9864829e223173fa50aa5397
# 7403ecc31a5e7870c2a266ea770f7bee
# 09a0841f1a3654214e91cf5016a7e797
# 0ac3f44a97890898cdaa7ae644ec0597
# 6768728140e9bf3502a656df74f35f0d
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
metadata_geo_format
# Out:
#    library name                                              title  \
# 0     D24-18553           control + H20 (last 14 days) replicate 0
# 1     D24-18554           control + H20 (last 14 days) replicate 1
# 2     D24-18555         p.Tyr622* + H20 (last 14 days) replicate 0
# 3     D24-18556         p.Tyr622* + H20 (last 14 days) replicate 1
# 4     D24-18557         p.Tyr622* + H20 (last 14 days) replicate 2
# 5     D24-18558         p.Tyr622* + H20 (last 14 days) replicate 3
# 6     D24-18559         p.Tyr622* + H20 (last 14 days) replicate 4
# 7     D24-18563  p.Tyr622* + CDP-choline (last 14 days)) replic...
# 8     D24-18564  p.Tyr622* + CDP-choline (last 14 days)) replic...
# 9     D24-18565  p.Tyr622* + CDP-choline (last 14 days)) replic...
# 10    D24-18566  p.Tyr622* + CDP-choline (last 14 days)) replic...
# 11    D24-18567  p.Tyr622* + CDP-choline (last 14 days)) replic...
# 12    D24-18571       p.Glu50fs*3 + H20 (last 14 days) replicate 0
# 13    D24-18572       p.Glu50fs*3 + H20 (last 14 days) replicate 1
# 14    D24-18574       p.Glu50fs*3 + H20 (last 14 days) replicate 2
# 15    D24-18575       p.Glu50fs*3 + H20 (last 14 days) replicate 3
# 16    D24-18576       p.Glu50fs*3 + H20 (last 14 days) replicate 4
#
#    library strategy organism  tissue    cell line  \
# 0           RNA-seq    human     NaN      control
# 1           RNA-seq    human     NaN      control
# 2           RNA-seq    human     NaN    p.Tyr622*
# 3           RNA-seq    human     NaN    p.Tyr622*
# 4           RNA-seq    human     NaN    p.Tyr622*
# 5           RNA-seq    human     NaN    p.Tyr622*
# 6           RNA-seq    human     NaN    p.Tyr622*
# 7           RNA-seq    human     NaN    p.Tyr622*
# 8           RNA-seq    human     NaN    p.Tyr622*
# 9           RNA-seq    human     NaN    p.Tyr622*
# 10          RNA-seq    human     NaN    p.Tyr622*
# 11          RNA-seq    human     NaN    p.Tyr622*
# 12          RNA-seq    human     NaN  p.Glu50fs*3
# 13          RNA-seq    human     NaN  p.Glu50fs*3
# 14          RNA-seq    human     NaN  p.Glu50fs*3
# 15          RNA-seq    human     NaN  p.Glu50fs*3
# 16          RNA-seq    human     NaN  p.Glu50fs*3
#
#                         cell type          genotype  \
# 0   iPSC-derivded induced neurons      ABCA7control
# 1   iPSC-derivded induced neurons      ABCA7control
# 2   iPSC-derivded induced neurons    ABCA7p.Tyr622*
# 3   iPSC-derivded induced neurons    ABCA7p.Tyr622*
# 4   iPSC-derivded induced neurons    ABCA7p.Tyr622*
# 5   iPSC-derivded induced neurons    ABCA7p.Tyr622*
# 6   iPSC-derivded induced neurons    ABCA7p.Tyr622*
# 7   iPSC-derivded induced neurons    ABCA7p.Tyr622*
# 8   iPSC-derivded induced neurons    ABCA7p.Tyr622*
# 9   iPSC-derivded induced neurons    ABCA7p.Tyr622*
# 10  iPSC-derivded induced neurons    ABCA7p.Tyr622*
# 11  iPSC-derivded induced neurons    ABCA7p.Tyr622*
# 12  iPSC-derivded induced neurons  ABCA7p.Glu50fs*3
# 13  iPSC-derivded induced neurons  ABCA7p.Glu50fs*3
# 14  iPSC-derivded induced neurons  ABCA7p.Glu50fs*3
# 15  iPSC-derivded induced neurons  ABCA7p.Glu50fs*3
# 16  iPSC-derivded induced neurons  ABCA7p.Glu50fs*3
#
#                         treatment    time   molecule single or paired-end  \
# 0            + H20 (last 14 days)  Day 28  total RNA           paired-end
# 1            + H20 (last 14 days)  Day 28  total RNA           paired-end
# 2            + H20 (last 14 days)  Day 28  total RNA           paired-end
# 3            + H20 (last 14 days)  Day 28  total RNA           paired-end
# 4            + H20 (last 14 days)  Day 28  total RNA           paired-end
# 5            + H20 (last 14 days)  Day 28  total RNA           paired-end
# 6            + H20 (last 14 days)  Day 28  total RNA           paired-end
# 7   + CDP-choline (last 14 days))  Day 28  total RNA           paired-end
# 8   + CDP-choline (last 14 days))  Day 28  total RNA           paired-end
# 9   + CDP-choline (last 14 days))  Day 28  total RNA           paired-end
# 10  + CDP-choline (last 14 days))  Day 28  total RNA           paired-end
# 11  + CDP-choline (last 14 days))  Day 28  total RNA           paired-end
# 12           + H20 (last 14 days)  Day 28  total RNA           paired-end
# 13           + H20 (last 14 days)  Day 28  total RNA           paired-end
# 14           + H20 (last 14 days)  Day 28  total RNA           paired-end
# 15           + H20 (last 14 days)  Day 28  total RNA           paired-end
# 16           + H20 (last 14 days)  Day 28  total RNA           paired-end
#
#    instrument model                           description processed data file  \
# 0     Element AVITI  Column name in counts.txt: D24-18553          counts.txt
# 1     Element AVITI  Column name in counts.txt: D24-18554          counts.txt
# 2     Element AVITI  Column name in counts.txt: D24-18555          counts.txt
# 3     Element AVITI  Column name in counts.txt: D24-18556          counts.txt
# 4     Element AVITI  Column name in counts.txt: D24-18557          counts.txt
# 5     Element AVITI  Column name in counts.txt: D24-18558          counts.txt
# 6     Element AVITI  Column name in counts.txt: D24-18559          counts.txt
# 7     Element AVITI  Column name in counts.txt: D24-18563          counts.txt
# 8     Element AVITI  Column name in counts.txt: D24-18564          counts.txt
# 9     Element AVITI  Column name in counts.txt: D24-18565          counts.txt
# 10    Element AVITI  Column name in counts.txt: D24-18566          counts.txt
# 11    Element AVITI  Column name in counts.txt: D24-18567          counts.txt
# 12    Element AVITI  Column name in counts.txt: D24-18571          counts.txt
# 13    Element AVITI  Column name in counts.txt: D24-18572          counts.txt
# 14    Element AVITI  Column name in counts.txt: D24-18574          counts.txt
# 15    Element AVITI  Column name in counts.txt: D24-18575          counts.txt
# 16    Element AVITI  Column name in counts.txt: D24-18576          counts.txt
#
#     processed data file 2                            raw file 1  \
# 0                     NaN  241121Tsa_D24-18553_1_sequence.fastq
# 1                     NaN  241121Tsa_D24-18554_1_sequence.fastq
# 2                     NaN  241121Tsa_D24-18555_1_sequence.fastq
# 3                     NaN  241121Tsa_D24-18556_1_sequence.fastq
# 4                     NaN  241121Tsa_D24-18557_1_sequence.fastq
# 5                     NaN  241121Tsa_D24-18558_1_sequence.fastq
# 6                     NaN  241121Tsa_D24-18559_1_sequence.fastq
# 7                     NaN  241121Tsa_D24-18563_1_sequence.fastq
# 8                     NaN  241121Tsa_D24-18564_1_sequence.fastq
# 9                     NaN  241121Tsa_D24-18565_1_sequence.fastq
# 10                    NaN  241121Tsa_D24-18566_1_sequence.fastq
# 11                    NaN  241121Tsa_D24-18567_1_sequence.fastq
# 12                    NaN  241121Tsa_D24-18571_1_sequence.fastq
# 13                    NaN  241121Tsa_D24-18572_1_sequence.fastq
# 14                    NaN  241121Tsa_D24-18574_1_sequence.fastq
# 15                    NaN  241121Tsa_D24-18575_1_sequence.fastq
# 16                    NaN  241121Tsa_D24-18576_1_sequence.fastq
#
#                               raw file 2
# 0   241121Tsa_D24-18553_2_sequence.fastq
# 1   241121Tsa_D24-18554_2_sequence.fastq
# 2   241121Tsa_D24-18555_2_sequence.fastq
# 3   241121Tsa_D24-18556_2_sequence.fastq
# 4   241121Tsa_D24-18557_2_sequence.fastq
# 5   241121Tsa_D24-18558_2_sequence.fastq
# 6   241121Tsa_D24-18559_2_sequence.fastq
# 7   241121Tsa_D24-18563_2_sequence.fastq
# 8   241121Tsa_D24-18564_2_sequence.fastq
# 9   241121Tsa_D24-18565_2_sequence.fastq
# 10  241121Tsa_D24-18566_2_sequence.fastq
# 11  241121Tsa_D24-18567_2_sequence.fastq
# 12  241121Tsa_D24-18571_2_sequence.fastq
# 13  241121Tsa_D24-18572_2_sequence.fastq
# 14  241121Tsa_D24-18574_2_sequence.fastq
# 15  241121Tsa_D24-18575_2_sequence.fastq
# 16  241121Tsa_D24-18576_2_sequence.fastq

# %%
sums_dictionary
# Out:
# {'./D24-18556-6997E/241121Tsa_D24-18556_1_sequence.fastq': 'd78dd242cb995317db4a765c303e969d',
#  './D24-18556-6997E/241121Tsa_D24-18556_2_sequence.fastq': '6f1338aa088a7768f82fcd7d1d18a2a7',
#  './D24-18557-6997E/241121Tsa_D24-18557_1_sequence.fastq': '7054bad0c2b30eca7d8c1feae8a3836d',
#  './D24-18557-6997E/241121Tsa_D24-18557_2_sequence.fastq': '545ceb2f44eec894eb01964a85a6d1d6',
#  './D24-18559-6997E/241121Tsa_D24-18559_1_sequence.fastq': '1ded8c14aa8c642e540e1d9760c2763f',
#  './D24-18559-6997E/241121Tsa_D24-18559_2_sequence.fastq': 'b6f6e679583e73107f1c06b386c5563f',
#  './D24-18561-6997E/241121Tsa_D24-18561_1_sequence.fastq': '3b60310ad2ff92e3622980f616e0d196',
#  './D24-18561-6997E/241121Tsa_D24-18561_2_sequence.fastq': '8e3d039a972c0b895ddb5726ea610ddf',
#  './D24-18562-6997E/241121Tsa_D24-18562_1_sequence.fastq': '0643c65208df9a438d5374fa2fd188d8',
#  './D24-18562-6997E/241121Tsa_D24-18562_2_sequence.fastq': '75a1d60d70bef31246ffa53ebea614bb',
#  './D24-18564-6997E/241121Tsa_D24-18564_1_sequence.fastq': '72aeabd8da7dce01b71e5d5b9e5ac8f7',
#  './D24-18564-6997E/241121Tsa_D24-18564_2_sequence.fastq': 'fb6c939312730f391c3e1bdca7e6fddc',
#  './D24-18566-6997E/241121Tsa_D24-18566_1_sequence.fastq': '93aff76990a2fb879e3467cca4156b86',
#  './D24-18566-6997E/241121Tsa_D24-18566_2_sequence.fastq': 'e7d8676ee689360f8663443ae7e3b773',
#  './D24-18568-6997E/241121Tsa_D24-18568_1_sequence.fastq': '75282cc7922a2630203736d2a0961469',
#  './D24-18568-6997E/241121Tsa_D24-18568_2_sequence.fastq': '549a41bf1e98789ff1740dae1b5b7225',
#  './D24-18570-6997E/241121Tsa_D24-18570_1_sequence.fastq': 'b63423916c8313f03981bcf94b4b1c85',
#  './D24-18570-6997E/241121Tsa_D24-18570_2_sequence.fastq': 'ac7bc665c378aa558d5fbbf5c33d94ce',
#  './D24-18571-6997E/241121Tsa_D24-18571_1_sequence.fastq': '96c093e4f3cce404da9239ff4ec0a270',
#  './D24-18571-6997E/241121Tsa_D24-18571_2_sequence.fastq': '83e6eb3a9864829e223173fa50aa5397',
#  './D24-18573-6997E/241121Tsa_D24-18573_1_sequence.fastq': '2a51b115fcb400a10c6ccd48de7fd763',
#  './D24-18573-6997E/241121Tsa_D24-18573_2_sequence.fastq': '3e49782824d1a2756cf7b99eaa1e3b5d',
#  './D24-18574-6997E/241121Tsa_D24-18574_1_sequence.fastq': 'd2edca09c55a18e8ba15ffca080f080a',
#  './D24-18574-6997E/241121Tsa_D24-18574_2_sequence.fastq': '09a0841f1a3654214e91cf5016a7e797',
#  './D24-18576-6997E/241121Tsa_D24-18576_1_sequence.fastq': '0df1b253377eb9b1debfe668512bbf04',
#  './D24-18576-6997E/241121Tsa_D24-18576_2_sequence.fastq': '6768728140e9bf3502a656df74f35f0d',
#  './D24-18578-6997E/241121Tsa_D24-18578_2_sequence.fastq': '176a65b1b6b28a90b873fc260ad31997',
#  './D24-18578-6997E/241121Tsa_D24-18578_1_sequence.fastq': '248b1279e279b44682e7dcec255c775c',
#  './D24-18580-6997E/241121Tsa_D24-18580_1_sequence.fastq': '71f5cc88e046fdd631fbdf6d244fcc0f',
#  './D24-18580-6997E/241121Tsa_D24-18580_2_sequence.fastq': 'f31104687a0acd0685f99729ddf19d25',
#  './241210_14505_6997E_L1_1_sequence_unmapped_barcodes.fastq': '1e40847cf02219a4bb12e2eba18d3de7',
#  './D24-18565-6997E/241121Tsa_D24-18565_2_sequence.fastq': 'd41d8cd98f00b204e9800998ecf8427e',
#  './D24-18565-6997E/241121Tsa_D24-18565_1_sequence.fastq': 'd41d8cd98f00b204e9800998ecf8427e',
#  './D24-18553-6997E/241121Tsa_D24-18553_1_sequence.fastq': '4753a0a2b6d26b805d923f0e0bf89b12',
#  './D24-18553-6997E/241121Tsa_D24-18553_2_sequence.fastq': '6ecc784fc9e68348b859abd0849f1796',
#  './D24-18554-6997E/241121Tsa_D24-18554_1_sequence.fastq': '9f30611ba848a8b6fb7a8d07cbc2798c',
#  './D24-18554-6997E/241121Tsa_D24-18554_2_sequence.fastq': '3e288dab0fc5a9e75d62b240092bd69d',
#  './D24-18555-6997E/241121Tsa_D24-18555_1_sequence.fastq': '3c27698cab64c1757f03674d3fdf03a2',
#  './D24-18555-6997E/241121Tsa_D24-18555_2_sequence.fastq': '7f9e50db45d5265596084c0741a81d51',
#  './D24-18558-6997E/241121Tsa_D24-18558_1_sequence.fastq': 'b904e8c975b6451cfc8618c94db69826',
#  './D24-18558-6997E/241121Tsa_D24-18558_2_sequence.fastq': '374117427b75beafa10160b313356d7c',
#  './D24-18560-6997E/241121Tsa_D24-18560_1_sequence.fastq': 'a3a44a323745737131ce7d878aea7adf',
#  './D24-18560-6997E/241121Tsa_D24-18560_2_sequence.fastq': 'f29e8cf94ca98b7f7f24be456c9faca3',
#  './D24-18563-6997E/241121Tsa_D24-18563_1_sequence.fastq': '33c282580ddacdf7a148c6422abe1943',
#  './D24-18563-6997E/241121Tsa_D24-18563_2_sequence.fastq': 'b3fd1bdfe7b0c00707162ef67a123a5c',
#  './D24-18567-6997E/241121Tsa_D24-18567_1_sequence.fastq': '4ce3b4602b71fec6b58fe6f354f2176f',
#  './D24-18567-6997E/241121Tsa_D24-18567_2_sequence.fastq': '8591d7c26e6ee64b9656e9055b76ca82',
#  './D24-18569-6997E/241121Tsa_D24-18569_1_sequence.fastq': '07c2320752d59d736b2dc1770f5f53d8',
#  './D24-18569-6997E/241121Tsa_D24-18569_2_sequence.fastq': 'e36955ca84da87d97a3acf31822baeb5',
#  './D24-18572-6997E/241121Tsa_D24-18572_1_sequence.fastq': '5970480aebc7be3b9fd1abf905487e35',
#  './D24-18572-6997E/241121Tsa_D24-18572_2_sequence.fastq': '7403ecc31a5e7870c2a266ea770f7bee',
#  './D24-18575-6997E/241121Tsa_D24-18575_1_sequence.fastq': 'b79b2aee07423e194f7b3c3c8a0c5280',
#  './D24-18575-6997E/241121Tsa_D24-18575_2_sequence.fastq': '0ac3f44a97890898cdaa7ae644ec0597',
#  './D24-18577-6997E/241121Tsa_D24-18577_1_sequence.fastq': '33e781c489366e2be17e1584c5e52956',
#  './D24-18577-6997E/241121Tsa_D24-18577_2_sequence.fastq': '79927db487ce67e9a64ecf22186f4935',
#  './241210_14505_6997E_L1_2_sequence_unmapped_barcodes.fastq': 'ef180aba611443f7b7271c7927784de4'}
