# %%
import os
import urllib.request

output_dir = "../../bulkRNAseq/"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

urls = ['https://storage.googleapis.com/abca7lof/241121Tsa/abca7_rna_seq_metadata_with_seqIDs.csv',
'https://storage.googleapis.com/abca7lof/241121Tsa/counts.txt']

for url in urls:
    local_filename = os.path.join(output_dir, os.path.basename(url))
    urllib.request.urlretrieve(url, local_filename)
    print("Download completed!")
# Out:
# Download completed!
# Download completed!

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# load data
counts = pd.read_csv('../../bulkRNAseq/counts.txt', delimiter='\t', comment="#")
metadata = pd.read_csv('../../bulkRNAseq/abca7_rna_seq_metadata_with_seqIDs.csv')
metadata['SeqID'] = metadata['SeqID'].str.strip()

# %%
metadata[(metadata['Notes'].str.contains('batch 1')) & (metadata['Treatment']=='H20')]['Line'].value_counts()
# Out:
# Line
# Y622       5
# G2         5
# Control    2
# Name: count, dtype: int64

# %%
# show the number of genes of each type
gene_type_counts = counts['gene_type'].value_counts().reset_index()
gene_type_counts.columns = ['gene_type', 'count']

plt.figure(figsize=(5, 8))
sns.barplot(x='count', y='gene_type', data=gene_type_counts, palette='viridis')
plt.xlabel('Count')
plt.ylabel('Gene Type')
plt.title('Gene Type Counts')
plt.show()

# %%
# get counts
sam_columns = [col for col in counts.columns if col.endswith('.sam')]
counts_extracted = counts[sam_columns]
new_column_names = {col: col.split('_')[1].split('Aligned')[0] for col in counts_extracted.columns}
counts_extracted.rename(columns=new_column_names, inplace=True)
counts_sums = counts_extracted.sum(axis=0)
counts_cpm = counts_extracted.div(counts_sums, axis=1) * 1e6 


names = set(counts['gene_name'][counts['gene_type']=='protein_coding'])
index = counts['gene_type']=='protein_coding'
counts_cpm_protein_coding = counts_cpm[index]
counts_cpm_protein_coding.index = counts['gene_name'][index]
counts_cpm_protein_coding = counts_cpm_protein_coding.iloc[:, 1:]
# Out:
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_61885/1389774987.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   counts_extracted.rename(columns=new_column_names, inplace=True)

# %%
# show PCA; treatment batch 1
batch_1_seqids = metadata[metadata['Notes'].str.contains('batch 1')]['SeqID']
line_seqids = metadata[metadata['Line'] == 'Y622']['SeqID']
counts_cpm_protein_coding_batch_1 = counts_cpm_protein_coding[np.intersect1d(batch_1_seqids, line_seqids)]
scaler = StandardScaler()
counts_cpm_protein_coding_scaled_1 = scaler.fit_transform(counts_cpm_protein_coding_batch_1.T)

# treatment batch 2
batch_2_seqids = metadata[metadata['Notes'].str.contains('batch 2')]['SeqID']
line_seqids = metadata[metadata['Line'] == 'Y622']['SeqID']
counts_cpm_protein_coding_batch_2 = counts_cpm_protein_coding[np.intersect1d(batch_2_seqids, line_seqids)]
scaler = StandardScaler()
counts_cpm_protein_coding_scaled_2 = scaler.fit_transform(counts_cpm_protein_coding_batch_2.T)

data_scaled = pd.DataFrame(np.hstack((counts_cpm_protein_coding_scaled_1.T, counts_cpm_protein_coding_scaled_2.T)), index=counts_cpm_protein_coding.index)
data_scaled.columns = np.concatenate([counts_cpm_protein_coding_batch_1.columns, counts_cpm_protein_coding_batch_2.columns])

# %%
# show PCA; treatment batch 1
batch_1_seqids = metadata[metadata['Notes'].str.contains('batch 1')]['SeqID']
line_seqids = metadata[metadata['Line'] == 'Y622']['SeqID']
counts_cpm_protein_coding_batch_1 = counts_cpm_protein_coding[np.intersect1d(batch_1_seqids, line_seqids)]

# Perform PCA on the counts_cpm_protein_coding
scaler = StandardScaler()
counts_cpm_protein_coding_scaled = scaler.fit_transform(counts_cpm_protein_coding_batch_1.T)
pca = PCA(n_components=4)
principal_components = pca.fit_transform(counts_cpm_protein_coding_scaled)

# Create a DataFrame with the principal components
pca_df = pd.DataFrame(data=principal_components, columns=['PC1', 'PC2', 'PC3', 'PC4'])
pca_df['SeqID'] = counts_cpm_protein_coding_batch_1.columns
pca_df = pd.merge(pca_df, metadata, on='SeqID')

# plot results
plt.figure(figsize=(2, 2))
sns.scatterplot(x='PC1', y='PC2', hue='Line', style='Treatment', data=pca_df, palette={'Control': 'grey', 'Y622': 'orange'}, edgecolor='w')

pca_df['grp'] = pca_df['Treatment'] + '_' + pca_df['Line']
#Add confidence ellipses for each group
import matplotlib.patches as patches
for line in pca_df['grp'].unique():
    line_data = pca_df[pca_df['grp'] == line]
    confidence_ellipse = np.cov(line_data['PC1'], line_data['PC2'])
    eigenvals, eigenvecs = np.linalg.eig(confidence_ellipse)
    angle = np.degrees(np.arctan2(eigenvecs[1,0], eigenvecs[0,0]))
    
    ellipse = patches.Ellipse(xy=(line_data['PC1'].mean(), line_data['PC2'].mean()),
                            width=2*np.sqrt(eigenvals[0])*2,
                            height=2*np.sqrt(eigenvals[1])*2,
                            angle=angle,
                            fill=True,
                            alpha=0.2,
                            color='grey' if line=='Control' else 'orange')
    plt.gca().add_patch(ellipse)

explained_variance = pca.explained_variance_ratio_
plt.xlabel(f'PC 1 ({explained_variance[0]*100:.2f}%)')
plt.ylabel(f'PC 2 ({explained_variance[1]*100:.2f}%)')
plt.legend(title='Line', bbox_to_anchor=(1.05, 1), loc='upper left')
# Remove the existing legend
plt.legend([],[], frameon=False)

# Add a custom legend based on marker type
from matplotlib.lines import Line2D


legend_elements = [
    Line2D([0], [0], marker='o', color='w',
           markerfacecolor='orange', markersize=7, label=r'+ H$_2$O'),
    Line2D([0], [0], marker='x', color='orange',
           markersize=7, linestyle='None', label='+ CDP-choline')
]
plt.legend(handles=legend_elements, title='', bbox_to_anchor=(.5, 1.35), loc='upper center', frameon=False)

plt.savefig('../../paper/main_plots/pca_rna_batch1.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import pandas as pd
import numpy as np

data1 = pd.read_csv('../../bulkRNAseq/y622_degs.csv', index_col=0)
data2 = pd.read_csv('../../bulkRNAseq/choline_degs.csv', index_col=0)
data3 = pd.read_csv('../../bulkRNAseq/g2_degs.csv', index_col=0)
data4 = pd.read_csv('../../bulkRNAseq/choline_batch2_degs.csv', index_col=0)

data1.head()
data2.head()
data1.index = data1['genes']
data2.index = data2['genes']
data3.index = data3['genes']
data4.index = data4['genes']
data1['score'] = -np.log10(data1['P.Value']) * np.sign(data1['logFC'])
data2['score'] = -np.log10(data2['P.Value']) * np.sign(data2['logFC'])
data3['score'] = -np.log10(data3['P.Value']) * np.sign(data3['logFC'])
data4['score'] = -np.log10(data4['P.Value']) * np.sign(data4['logFC'])

# %%
data4

# %%
x = data1[(data1['genes'].str.startswith('SLC25A')) & (data1['adj.P.Val']<0.05)]['genes'].values

# %%
data2.loc[x]
# Out:
#              genes     logFC   AveExpr         t   P.Value  adj.P.Val  \
# genes
# SLC25A43  SLC25A43  1.489805 -0.185117  4.861642  0.000128   0.001147
# SLC25A23  SLC25A23  0.411454  5.269891  5.081721  0.000080   0.000799
# SLC25A1    SLC25A1  0.264484  7.262840  4.010738  0.000830   0.004713
# SLC25A25  SLC25A25  0.433159  3.051925  4.135400  0.000630   0.003827
# SLC25A44  SLC25A44  0.121535  6.230510  1.529092  0.143750   0.238467
#
#                  B     score
# genes
# SLC25A43  1.102539  3.893286
# SLC25A23  0.443240  4.099524
# SLC25A1  -2.134310  3.080763
# SLC25A25 -1.245451  3.200830
# SLC25A44 -6.933534  0.842392

# %%
data1[(data1['genes'].str.startswith('UCP'))]
# Out:
#       genes     logFC   AveExpr         t  P.Value  adj.P.Val         B  \
# genes
# UCP2   UCP2 -0.491852  2.568785 -3.213421   0.0071   0.052417 -3.169911
#
#           score
# genes
# UCP2  -2.148715

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy import stats
import stack_data  # Adjust this to your module's data-loading function

data_merged = pd.merge(data1, data2, left_index=True, right_index=True)


plt.figure(figsize=(4, 4))

# Create a random subsample (e.g., 10% of the points)
sample_df = data_merged.sample(frac=0.2, random_state=42)

# Plot the regression line using the full dataset without scatter points
sns.regplot(x='score_x', y='score_y', data=data_merged, scatter=False, ci=95, color='black', line_kws={'linewidth': 1})

# Overlay scatter points from the subsample
sns.scatterplot(x='score_x', y='score_y', data=sample_df, color='black', alpha=0.3, s=20)

# Calculate Pearson correlation coefficient and p-value
r, p = stats.pearsonr(data_merged['score_x'], data_merged['score_y'])

# Add text annotation with the correlation coefficient
plt.text(0.01, 1.05, f'Pearson r = {r:.3f}',
         transform=plt.gca().transAxes, verticalalignment='top')

# Add horizontal and vertical dotted lines at zero
plt.axhline(y=0, color='grey', linestyle='dotted')
plt.axvline(x=0, color='grey', linestyle='dotted')

plt.xlabel('WT vs p.Tyr622*')
plt.ylabel('p.Tyr622* + H$_2$O vs p.Tyr622* + CDP-choline')
# Add arrow in lower right quadrant
plt.annotate('', xy=(14, -14), xytext=(10, -14),
             arrowprops=dict(facecolor='black', shrink=0.05, width=1, headwidth=5))
plt.text(7, -14.5, 'Up in LoF', ha='center', fontsize=9)

plt.annotate('', xy=(-14, -14), xytext=(-10, -14),
             arrowprops=dict(facecolor='black', shrink=0.05, width=1, headwidth=5))
plt.text(-6, -14.5, 'Down in LoF', ha='center', fontsize=9)

plt.annotate('', xy=(14, 14), xytext=(14, 10),
             arrowprops=dict(facecolor='black', shrink=0.05, width=1, headwidth=5))
plt.text(13.5, 2.5, 'Up with \n CDP-choline', ha='center', fontsize=9, rotation=90)

plt.annotate('', xy=(14, -14), xytext=(14, -10),
             arrowprops=dict(facecolor='black', shrink=0.05, width=1, headwidth=5))
plt.text(13.5, -10, 'Down with \n CDP-choline', ha='center', fontsize=9, rotation=90)


plt.xlim(-15, 15)
plt.ylim(-15, 15)
plt.savefig('../../paper/main_plots/rna_correlation_plot.png', bbox_inches='tight')

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy import stats
import stack_data  # Adjust this to your module's data-loading function

data_merged = pd.merge(data1, data3, left_index=True, right_index=True)


plt.figure(figsize=(4, 4))

# Create a random subsample (e.g., 10% of the points)
sample_df = data_merged.sample(frac=0.2, random_state=42)

# Plot the regression line using the full dataset without scatter points
sns.regplot(x='score_x', y='score_y', data=data_merged, scatter=False, ci=95, color='black', line_kws={'linewidth': 1})

# Overlay scatter points from the subsample
sns.scatterplot(x='score_x', y='score_y', data=sample_df, color='black', alpha=0.3, s=20)

# Calculate Pearson correlation coefficient and p-value
r, p = stats.pearsonr(data_merged['score_x'], data_merged['score_y'])

# Add text annotation with the correlation coefficient
plt.text(0.01, 1.05, f'Pearson r = {r:.3f}',
         transform=plt.gca().transAxes, verticalalignment='top')

# Add horizontal and vertical dotted lines at zero
plt.axhline(y=0, color='grey', linestyle='dotted')
plt.axvline(x=0, color='grey', linestyle='dotted')

plt.xlabel('WT vs p.Tyr622*')
plt.ylabel('WT vs p.Glu50fs*3')
# Add arrow in lower right quadrant
plt.annotate('', xy=(14, -14), xytext=(10, -14),
             arrowprops=dict(facecolor='black', shrink=0.05, width=1, headwidth=5))
plt.text(7, -14.5, 'Up in \n p.Tyr622*', ha='center', fontsize=9)

plt.annotate('', xy=(-14, -14), xytext=(-10, -14),
             arrowprops=dict(facecolor='black', shrink=0.05, width=1, headwidth=5))
plt.text(-6, -14.5, 'Down in \n p.Tyr622*', ha='center', fontsize=9)

plt.annotate('', xy=(14, 14), xytext=(14, 10),
             arrowprops=dict(facecolor='black', shrink=0.05, width=1, headwidth=5))
plt.text(13.5, 2.5, 'Up in \n p.Glu50fs*3', ha='center', fontsize=9, rotation=90)

plt.annotate('', xy=(14, -14), xytext=(14, -10),
             arrowprops=dict(facecolor='black', shrink=0.05, width=1, headwidth=5))
plt.text(13.5, -10, 'Down in \n p.Glu50fs*3', ha='center', fontsize=9, rotation=90)


plt.xlim(-15, 15)
plt.ylim(-15, 15)
plt.savefig('../../paper/extended_plots/rna_correlation_both_lof_lines.png', bbox_inches='tight')

plt.show()

# %%
data_merged = pd.merge(data2, data4, left_index=True, right_index=True)
sns.regplot(x='logFC_x', y='logFC_y', data=data_merged, scatter=False, ci=95, color='black', line_kws={'linewidth': 1})
plt.xlabel('p.Tyr622* + H$_2$O')
# Out:
# Text(0.5, 0, 'p.Tyr622* + H$_2$O')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy import stats
import stack_data  # Adjust this to your module's data-loading function

data_merged = pd.merge(data2, data4, left_index=True, right_index=True)


plt.figure(figsize=(4, 4))

# Create a random subsample (e.g., 10% of the points)
sample_df = data_merged.sample(frac=1, random_state=42)

# Plot the regression line using the full dataset without scatter points
sns.regplot(x='score_x', y='score_y', data=data_merged, scatter=False, ci=95, color='black', line_kws={'linewidth': 1})

# Overlay scatter points from the subsample
sns.scatterplot(x='score_x', y='score_y', data=sample_df, color='black', alpha=0.3, s=1)

# Calculate Pearson correlation coefficient and p-value
r, p = stats.pearsonr(data_merged['score_x'], data_merged['score_y'])

# Add text annotation with the correlation coefficient
plt.text(0.01, 1.05, f'Pearson r = {r:.3f}',
         transform=plt.gca().transAxes, verticalalignment='top')

# Add horizontal and vertical dotted lines at zero
plt.axhline(y=0, color='grey', linestyle='dotted')
plt.axvline(x=0, color='grey', linestyle='dotted')

plt.xlabel('WT vs p.Tyr622*')
plt.ylabel('WT vs p.Glu50fs*3')
# Add arrow in lower right quadrant
plt.annotate('', xy=(14, -14), xytext=(10, -14),
             arrowprops=dict(facecolor='black', shrink=0.05, width=1, headwidth=5))
plt.text(7, -14.5, 'Up in \n p.Tyr622*', ha='center', fontsize=9)

plt.annotate('', xy=(-14, -14), xytext=(-10, -14),
             arrowprops=dict(facecolor='black', shrink=0.05, width=1, headwidth=5))
plt.text(-6, -14.5, 'Down in \n p.Tyr622*', ha='center', fontsize=9)

plt.annotate('', xy=(14, 14), xytext=(14, 10),
             arrowprops=dict(facecolor='black', shrink=0.05, width=1, headwidth=5))
plt.text(13.5, 2.5, 'Up in \n p.Glu50fs*3', ha='center', fontsize=9, rotation=90)

plt.annotate('', xy=(14, -14), xytext=(14, -10),
             arrowprops=dict(facecolor='black', shrink=0.05, width=1, headwidth=5))
plt.text(13.5, -10, 'Down in \n p.Glu50fs*3', ha='center', fontsize=9, rotation=90)


#plt.xlim(-15, 15)
#plt.ylim(-15, 15)
#plt.savefig('../../paper/extended_plots/rna_correlation_both_lof_lines.png', bbox_inches='tight')

plt.show()

# %%
data2.loc[data2.index.intersection(df[df['Symbol'].str.startswith('ABC')]['Symbol'].values)]
# Out:
#          genes     logFC   AveExpr         t   P.Value  adj.P.Val         B  \
# genes
# ABCB10  ABCB10  0.457811  5.056224  6.346516  0.000006   0.000103  3.161214
# ABCD3    ABCD3  0.497746  6.011900  4.486697  0.000290   0.002132 -0.959238
# ABCD2    ABCD2  0.588662  0.536651  2.873459  0.010161   0.031207 -3.324473
# ABCD1    ABCD1  0.866845 -0.712500  2.743570  0.013416   0.038746 -3.299600
# ABCB8    ABCB8  0.021438  3.979582  0.249490  0.805827   0.862124 -7.728539
# ABCB6    ABCB6  0.003501  1.550175  0.019713  0.984491   0.989903 -7.164223
# ABCB7    ABCB7 -0.001102  3.909638 -0.010107  0.992048   0.995221 -7.747338
#
#            score
# genes
# ABCB10  5.238136
# ABCD3   3.537670
# ABCD2   1.993074
# ABCD1   1.872392
# ABCB8   0.093758
# ABCB6   0.006788
# ABCB7  -0.003468

# %%
# Define lists of genes in each category
phospholipid_genes = [
    'CHKA', 'CHKB', 'PCYT1A', 'PCYT1B', 
    'CHPT1', 'CEPT1', 'PEMT', 
    'LPCAT1', 'LPCAT2', 'LPCAT3', 'LPCAT4'
]

choline_transporter_genes = [
    'SLC44A2', 'SLC44A1', 'SLC44A3', 'SLC44A5'
]

fatty_acid_genes = [
    'SCD', 'SCD5', 'FADS1', 'FADS2', 'FADS3', 
    'ELOVL2', 'ELOVL5', 'ACSL'
]

# Create an empty dictionary to store the mapping
gene_to_category = {}

# Map each gene to its category
for gene in phospholipid_genes:
    gene_to_category[gene] = 'Phospholipid Synthesis/Remodeling'

for gene in choline_transporter_genes:
    gene_to_category[gene] = 'Choline Transport'

for gene in fatty_acid_genes:
    gene_to_category[gene] = 'Fatty Acid Metabolism'

# Print the resulting dictionary
print(gene_to_category)
# Out:
# {'CHKA': 'Phospholipid Synthesis/Remodeling', 'CHKB': 'Phospholipid Synthesis/Remodeling', 'PCYT1A': 'Phospholipid Synthesis/Remodeling', 'PCYT1B': 'Phospholipid Synthesis/Remodeling', 'CHPT1': 'Phospholipid Synthesis/Remodeling', 'CEPT1': 'Phospholipid Synthesis/Remodeling', 'PEMT': 'Phospholipid Synthesis/Remodeling', 'LPCAT1': 'Phospholipid Synthesis/Remodeling', 'LPCAT2': 'Phospholipid Synthesis/Remodeling', 'LPCAT3': 'Phospholipid Synthesis/Remodeling', 'LPCAT4': 'Phospholipid Synthesis/Remodeling', 'SLC44A2': 'Choline Transport', 'SLC44A1': 'Choline Transport', 'SLC44A3': 'Choline Transport', 'SLC44A5': 'Choline Transport', 'SCD': 'Fatty Acid Metabolism', 'SCD5': 'Fatty Acid Metabolism', 'FADS1': 'Fatty Acid Metabolism', 'FADS2': 'Fatty Acid Metabolism', 'FADS3': 'Fatty Acid Metabolism', 'ELOVL2': 'Fatty Acid Metabolism', 'ELOVL5': 'Fatty Acid Metabolism', 'ACSL': 'Fatty Acid Metabolism'}

# %%
genes = list(gene_to_category.keys())
y = data2.loc[np.array(genes)[[g in data2.index for g in genes]]]
y['category'] = y['genes'].map(gene_to_category)
y = y[y['adj.P.Val']<0.05]

y=y[y['category']!='Fatty Acid Metabolism']

plt.figure(figsize=(2.7, 2.5))
ax = sns.barplot(y='genes', x='score', data=y[['genes', 'score', 'category']].sort_values(['category', 'score'], ascending=[False, False]), width = .8, hue='category', 
            palette={'Choline Transport': '#F97A1F', 'Fatty Acid Metabolism': '#F97A1F', 'Phospholipid Synthesis/Remodeling': '#C91D42'}, dodge=False)
# Set the y tick labels color according to the category color palette
# for label in ax.get_yticklabels():
#     gene = label.get_text()
#     category = gene_to_category.get(gene, '')
#     if category == 'Choline Transport':
#         label.set_color('#F97A1F')
#     elif category == 'Fatty Acid Metabolism':
#         label.set_color('#F97A1F')
#     elif category == 'Phospholipid Synthesis/Remodeling':
#         label.set_color('#C91D42')

plt.ylabel('')
plt.title('')
plt.yticks(fontstyle='italic')


legend_elements = [
    Line2D([0], [0], marker='o', color='w',
           markerfacecolor='#C91D42', markersize=10, label='PC Synthesis/Remodeling'),
    Line2D([0], [0], marker='o', markerfacecolor='#F97A1F', color='w',
           markersize=10, linestyle='None', label='Choline Transport')
]
plt.legend(handles=legend_elements, title='', bbox_to_anchor=(0.25, 1.3), loc='upper center', frameon=False)
plt.xlabel('-log$_{10}$(p-value) * sign(logFC) \n [p.Tyr622* + H$_2$O \n vs p.Tyr622* + CDP-choline]')

plt.savefig('../../paper/extended_plots/choline_synth_genes.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
genes = list(gene_to_category.keys())
y = data2.loc[np.array(genes)[[g in data2.index for g in genes]]]
y['category'] = y['genes'].map(gene_to_category)
y = y[y['adj.P.Val']<0.05]

y=y[y['category']=='Fatty Acid Metabolism']

plt.figure(figsize=(2.7, 2.5))
ax = sns.barplot(y='genes', x='score', data=y[['genes', 'score', 'category']].sort_values(['category', 'score'], ascending=[False, False]), width = .8, hue='category', 
            palette={'Choline Transport': '#F97A1F', 'Fatty Acid Metabolism': '#36E2BD', 'Phospholipid Synthesis/Remodeling': '#C91D42'}, dodge=False)
# Set the y tick labels color according to the category color palette
# for label in ax.get_yticklabels():
#     gene = label.get_text()
#     category = gene_to_category.get(gene, '')
#     if category == 'Choline Transport':
#         label.set_color('#F97A1F')
#     elif category == 'Fatty Acid Metabolism':
#         label.set_color('#F97A1F')
#     elif category == 'Phospholipid Synthesis/Remodeling':
#         label.set_color('#C91D42')

plt.ylabel('')
plt.title('')
plt.yticks(fontstyle='italic')


legend_elements = [
    Line2D([0], [0], marker='o', color='w',
           markerfacecolor='#36E2BD', markersize=10, label='Unsaturated Fatty Acid Metabolism'),
    
]
plt.legend(handles=legend_elements, title='', bbox_to_anchor=(0.3, 1.3), loc='upper center', frameon=False)
plt.xlabel('-log$_{10}$(p-value) * sign(logFC) \n [p.Tyr622* + H$_2$O \n vs p.Tyr622* + CDP-choline]')

plt.savefig('../../paper/extended_plots/desaturase_genes.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
genes = list(gene_to_category.keys())
y = data1.loc[np.array(genes)[[g in data1.index for g in genes]]]
y['category'] = y['genes'].map(gene_to_category)
y = y[y['adj.P.Val']<0.05]

y=y[y['category']=='Fatty Acid Metabolism']

plt.figure(figsize=(2.7, 2.5))
ax = sns.barplot(y='genes', x='score', data=y[['genes', 'score', 'category']].sort_values(['category', 'score'], ascending=[False, False]), width = .8, hue='category', 
            palette={'Choline Transport': '#F97A1F', 'Fatty Acid Metabolism': '#36E2BD', 'Phospholipid Synthesis/Remodeling': '#C91D42'}, dodge=False)
# Set the y tick labels color according to the category color palette
# for label in ax.get_yticklabels():
#     gene = label.get_text()
#     category = gene_to_category.get(gene, '')
#     if category == 'Choline Transport':
#         label.set_color('#F97A1F')
#     elif category == 'Fatty Acid Metabolism':
#         label.set_color('#F97A1F')
#     elif category == 'Phospholipid Synthesis/Remodeling':
#         label.set_color('#C91D42')

plt.ylabel('')
plt.title('')
plt.yticks(fontstyle='italic')


legend_elements = [
    Line2D([0], [0], marker='o', color='w',
           markerfacecolor='#36E2BD', markersize=10, label='Unsaturated Fatty Acid Metabolism'),
    
]
plt.legend(handles=legend_elements, title='', bbox_to_anchor=(0.3, 1.3), loc='upper center', frameon=False)
plt.xlabel('-log$_{10}$(p-value) * sign(logFC) \n [WT vs p.Tyr622*]')

plt.savefig('../../paper/extended_plots/desaturase_genes_e3_v_y622.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# genes            UCP2
# logFC        0.052862
# AveExpr      2.455362
# t            0.454185
# P.Value      0.655164
# adj.P.Val    0.744864
# B           -7.308195
# score         0.18365
# Name: UCP2, dtype: object

# %%
# Load the specific sheet from the Excel file
excel_file_path = '../../../../Downloads/Human.MitoCarta3.0.xls'
sheet_name = 'Sheet1'  # Replace with the name of the sheet you want to load

# Read the specific sheet into a DataFrame
df = pd.read_excel(excel_file_path, sheet_name='A Human MitoCarta3.0')

# Display the first few rows of the DataFrame to verify the content
#df.head()

# %%
dictionary = dict(zip(df['Symbol'], df['MitoCarta3.0_SubMitoLocalization']))

# %%
data1_mito = data1.loc[df['Symbol'][[x in set(data1.index) for x in df['Symbol']]]]

data2_mito = data2.loc[df['Symbol'][[x in set(data2.index) for x in df['Symbol']]]]

x = pd.merge(data1_mito, data2_mito, left_index=True, right_index=True)
x['category'] = x['genes_x'].map(dictionary)

x.head()
# Out:
#        genes_x   logFC_x  AveExpr_x       t_x  P.Value_x  adj.P.Val_x  \
# genes
# CYC1      CYC1 -0.010086   8.262270 -0.112412   0.912282     0.950910
# SDHB      SDHB  0.158903   7.299210  1.757461   0.103282     0.256550
# COQ7      COQ7  0.106409   5.356537  1.009527   0.331864     0.527029
# SDHA      SDHA  0.062024   5.515638  0.552580   0.590296     0.740710
# UQCRC1  UQCRC1 -0.105863   9.183046 -1.242216   0.236957     0.428024
#
#              B_x   score_x genes_y   logFC_y  AveExpr_y       t_y  P.Value_y  \
# genes
# CYC1   -7.841391 -0.039871    CYC1 -0.280341   8.119527 -5.007905   0.000093
# SDHB   -6.285683  0.985974    SDHB -0.240714   7.226107 -4.359117   0.000384
# COQ7   -7.085754  0.479039    COQ7 -0.149634   5.313715 -2.224002   0.039284
# SDHA   -7.469801  0.228930    SDHA -0.155638   5.458298 -2.092805   0.050909
# UQCRC1 -7.127569 -0.625330  UQCRC1 -0.296956   9.005188 -5.323783   0.000047
#
#         adj.P.Val_y       B_y   score_y category
# genes
# CYC1       0.000909  0.010392 -4.030579      MIM
# SDHB       0.002656 -1.355676 -3.415666      MIM
# COQ7       0.087394 -5.684523 -1.405785      MIM
# SDHA       0.106644 -5.940550 -1.293208      MIM
# UQCRC1     0.000543  0.636534 -4.323868      MIM

# %%
data1_mito
# Out:
#            genes     logFC   AveExpr         t   P.Value  adj.P.Val         B  \
# genes
# CYC1        CYC1 -0.010086  8.262270 -0.112412  0.912282   0.950910 -7.841391
# SDHB        SDHB  0.158903  7.299210  1.757461  0.103282   0.256550 -6.285683
# COQ7        COQ7  0.106409  5.356537  1.009527  0.331864   0.527029 -7.085754
# SDHA        SDHA  0.062024  5.515638  0.552580  0.590296   0.740710 -7.469801
# UQCRC1    UQCRC1 -0.105863  9.183046 -1.242216  0.236957   0.428024 -7.127569
# ...          ...       ...       ...       ...       ...        ...       ...
# ARMCX6    ARMCX6  0.290565  5.089564  2.848507  0.014157   0.077331 -4.207370
# METTL4    METTL4  0.027856  3.303517  0.160038  0.875408   0.930969 -7.298622
# SPHKAP    SPHKAP -0.046563  3.818177 -0.303046  0.766839   0.866133 -7.359504
# NAT8L      NAT8L  0.154988  2.544380  0.813187  0.431328   0.616961 -6.800241
# PIGBOS1  PIGBOS1  0.387362  4.147284  2.936639  0.011986   0.070406 -3.905759
#
#             score
# genes
# CYC1    -0.039871
# SDHB     0.985974
# COQ7     0.479039
# SDHA     0.228930
# UQCRC1  -0.625330
# ...           ...
# ARMCX6   1.849034
# METTL4   0.057790
# SPHKAP  -0.115296
# NAT8L    0.365193
# PIGBOS1  1.921332
#
# [1042 rows x 8 columns]

# %%
sns.scatterplot(data=x, x='score_x', y='score_y', hue='category', s = 10)

# Label top and bottom genes
top_genes = x.nlargest(15, 'score_x').index
bottom_genes = x.nsmallest(10, 'score_x').index

for gene in top_genes:
    plt.text(x.loc[gene, 'score_x'], x.loc[gene, 'score_y'], gene, fontsize=9, ha='right', va='bottom')

for gene in bottom_genes:
    plt.text(x.loc[gene, 'score_x'], x.loc[gene, 'score_y'], gene, fontsize=9, ha='right', va='bottom')

plt.show()

# %%
x['category'].value_counts()
# Out:
# category
# Matrix        487
# MIM           325
# MOM           102
# unknown        48
# IMS            46
# Membrane       31
# MOM|IMS         1
# Matrix|IMS      1
# MOM|Matrix      1
# Name: count, dtype: int64

# %%
np.sum(x['adj.P.Val_x']<0.05)
# Out:
# 122

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from adjustText import adjust_text

# Your scatterplot
sns.scatterplot(data=x, x='logFC_x', y=-1*np.log10(x['adj.P.Val_x']), hue='category', s=10)

# Label top genes
top_genes = x.nlargest(20, 'logFC_x').index
texts = []
for gene in top_genes:
    if x.loc[gene, 'adj.P.Val_x'] < 0.05:
        txt = plt.text(x.loc[gene, 'logFC_x'],
                       -1 * np.log10(x.loc[gene, 'adj.P.Val_x']),
                       gene, fontsize=9, ha='right', va='bottom')
        texts.append(txt)

# Adjust text positions to reduce overlap
adjust_text(texts, arrowprops=dict(arrowstyle='-', color='grey', lw=0.5))

#plt.xlim(-2, 2)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from adjustText import adjust_text

# Your scatterplot
sns.scatterplot(data=x, x='logFC_y', y=-1*np.log10(x['adj.P.Val_y']), hue='category', s=10)

# Label top genes
top_genes = x.nsmallest(20, 'logFC_y').index
texts = []
for gene in top_genes:
    if x.loc[gene, 'adj.P.Val_y'] < 0.05:
        txt = plt.text(x.loc[gene, 'logFC_y'],
                       -1 * np.log10(x.loc[gene, 'adj.P.Val_y']),
                       gene, fontsize=9, ha='right', va='bottom')
        texts.append(txt)

# Adjust text positions to reduce overlap
adjust_text(texts, arrowprops=dict(arrowstyle='-', color='grey', lw=0.5))

#plt.xlim(-2, 2)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
isinstance(df['MitoCarta3.0_MitoPathways'][0], str)
# Out:
# True

# %%
df['cat'] = [x.split(' |')[0].split('> ')[-1] if isinstance(x, str) else np.NaN for x in df['MitoCarta3.0_MitoPathways'].values]

# %%
y=data1_mito[data1_mito['adj.P.Val']<0.05]
y['abs_score'] = np.abs(y['score'])
y['cat'] = y['genes'].map(dictionary)
y1 = y.sort_values(by='abs_score', ascending=False)[:10]
y2 = y.sort_values(by='abs_score', ascending=True)[:10]
y = pd.concat([y1, y2])
y
# Out:
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_61885
# MFN2     -3.540603  -2.204852   2.204852                          Fusion
# ALDH5A1  -3.274447  -2.213468   2.213468                 GABA metabolism
# MRPS30   -3.309604   2.218849   2.218849          Mitochondrial ribosome
# PICK1    -3.411232  -2.221489   2.221489                             NaN
# NDUFAF2  -3.373201   2.239266   2.239266             CI assembly factors
# SFXN3    -3.437829  -2.257355   2.257355               Serine metabolism

# %%
import matplotlib.pyplot as plt
from matplotlib.colors import to_rgb, to_hex

def adjust_color(color, factor):
    """
    Adjust brightness of a color.
    factor > 1 makes the color lighter; factor < 1 makes it darker.
    """
    r, g, b = to_rgb(color)
    r = min(r * factor, 1)
    g = min(g * factor, 1)
    b = min(b * factor, 1)
    return to_hex((r, g, b))

def economist_distinct_palette(n_colors=25):
    # Define a few base colors reminiscent of The Economist style
    base_colors = [
        "#C8102E",  # bright red
        "#8C1515",  # deep red
        "#F6B600",  # gold/yellow
        "#555555",  # dark grey
        "#006E90",  # blueish
        "#008272",  # teal
        "#D4AF37",  # warm gold
        "#A7A9AC",  # light grey
        "#000000"   # black
    ]
    
    # Generate variations for each base color: original, lighter, and darker
    colors = []
    for base in base_colors:
        colors.append(base)
        colors.append(adjust_color(base, 1.3))  # lighter version
        colors.append(adjust_color(base, 0.7))  # darker version

    # Remove duplicates and select the first n_colors
    unique_colors = []
    for color in colors:
        if color not in unique_colors:
            unique_colors.append(color)
    return unique_colors[:n_colors]

# Generate the palette
palette = economist_distinct_palette(20)

# %%
len(y['cat'].value_counts())
# Out:
# 15

# %%
plt.figure(figsize=(2.7, 4))
ax = sns.barplot(y='genes', x='score', data=y[['genes', 'score', 'cat']].sort_values([ 'score'], ascending=[ False]), width = .8, hue = 'cat', dodge=False, palette = palette)
# Set the y tick labels color according to the category color palette
# for label in ax.get_yticklabels():
#     gene = label.get_text()
#     category = gene_to_category.get(gene, '')
#     if category == 'Choline Transport':
#         label.set_color('#F97A1F')
#     elif category == 'Fatty Acid Metabolism':
#         label.set_color('#F97A1F')
#     elif category == 'Phospholipid Synthesis/Remodeling':
#         label.set_color('#C91D42')

plt.ylabel('')
plt.title('')
plt.yticks(fontstyle='italic')


# legend_elements = [
#     Line2D([0], [0], marker='o', color='w',
#            markerfacecolor='#36E2BD', markersize=10, label='Unsaturated Fatty Acid Metabolism'),
    
#]
# plt.legend(handles=legend_elements, title='', bbox_to_anchor=(0.3, 1.3), loc='upper center', frameon=False)
# plt.xlabel('-log$_{10}$(p-value) * sign(logFC) \n [WT vs p.Tyr622*]')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

#plt.savefig('../../paper/extended_plots/desaturase_genes_e3_v_y622.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Out:
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_61885/3440099738.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data1_mito['cat'][data1_mito['cat'].isna()] = 'other'
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_61885/3440099738.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1_mito['cat'][data1_mito['cat'].isna()] = 'other'

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from adjustText import adjust_text

# %%
import pandas as pd
import numpy as np

data1 = pd.read_csv('../../bulkRNAseq/y622_degs.csv', index_col=0)
data2 = pd.read_csv('../../bulkRNAseq/choline_degs.csv', index_col=0)
data3 = pd.read_csv('../../bulkRNAseq/g2_degs.csv', index_col=0)

data1.head()
data2.head()
data1.index = data1['genes']
data2.index = data2['genes']
data3.index = data3['genes']
data1['score'] = -np.log10(data1['P.Value']) * np.sign(data1['logFC'])
data2['score'] = -np.log10(data2['P.Value']) * np.sign(data2['logFC'])
data3['score'] = -np.log10(data3['P.Value']) * np.sign(data3['logFC'])

# %%
# prepare the mito data
df['cat'] = [x.split(' |')[0].split('> ')[-1] if isinstance(x, str) else np.NaN for x in df['MitoCarta3.0_MitoPathways'].values]
dictionary = dict(zip(df['Symbol'], df['cat']))

# %%
data1_mito.loc[top_genes]
# Out:
#            genes     logFC   AveExpr          t       P.Value  adj.P.Val  \
# genes
# CRYZ        CRYZ  1.809203  1.647095   6.961141  1.220084e-05   0.000841
# BIK          BIK  1.089864  2.598365   3.681893  2.940002e-03   0.032213
# CASP3      CASP3  0.957502  9.116634  12.919164  1.340752e-08   0.000006
# SUGCT      SUGCT  0.941497 -1.003656   2.214018  4.609327e-02   0.157716
# MTHFD2L  MTHFD2L  0.887993  5.668080   8.350979  1.827016e-06   0.000231
# PET117    PET117  0.706144  1.508358   2.752166  1.697600e-02   0.086422
# BCL2L1    BCL2L1  0.694675  5.065276   6.071814  4.679242e-05   0.002272
# FUNDC1    FUNDC1  0.679959  6.927653   5.724053  8.152262e-05   0.003253
# CMC4        CMC4  0.633427 -0.415673   1.390942  1.885066e-01   0.373165
# PRELID2  PRELID2  0.602337  1.416642   1.960495  7.260926e-02   0.206687
#
#                 B     score                        cat  size
# genes
# CRYZ     3.619066  4.913610                      other    50
# BIK     -2.147726  2.531652                  Apoptosis    50
# CASP3    9.978601  7.872652                  Proteases    50
# SUGCT   -4.048478  1.336362      Amino acid metabolism    50
# MTHFD2L  5.018690  5.738258  Folate and 1-C metabolism    50
# PET117  -3.670009  1.770165       CIV assembly factors    50
# BCL2L1   1.671628  4.329824                  Apoptosis    50
# FUNDC1   0.924102  4.088722                  Mitophagy    50
# CMC4    -5.392557  0.724674                      other    50
# PRELID2 -5.018476  1.139008                      other    50

# %%
# prep data
data1_mito = data2.loc[df['Symbol'][[x in set(data2.index) for x in df['Symbol']]]]
#data1_mito['cat'] = data1_mito['genes'].map(dictionary)
#data1_mito['cat'][data1_mito['cat'].isna()] = 'other'
data1_mito[data1_mito['adj.P.Val']>0.05]['cat'] = 'other'

plt.figure(figsize=(4, 3))
bottom_genes = data1_mito.nsmallest(10, 'score').index
top_genes = data1_mito.nlargest(10, 'score').index
top_genes = np.concatenate([bottom_genes, top_genes])

data1_mito.loc[~data1_mito.index.isin(top_genes), 'cat'] = 'other'

# Your scatterplot
data1_mito['size'] = np.where(data1_mito.index.isin(top_genes), 50, 10)
data1_mito['cat'][(data1_mito['logFC']<0) & (data1_mito['adj.P.Val']<0.05)] = 'down'
data1_mito['cat'][(data1_mito['logFC']>0) & (data1_mito['adj.P.Val']<0.05)] = 'up'
data1_mito['cat'][data1_mito['adj.P.Val']>0.05] = 'other'
palette = {'down': 'orange', 'up': 'purple', 'other': '#A7A9AC'}
sns.scatterplot(data=data1_mito, x='logFC', y=-1*np.log10(data1_mito['adj.P.Val']), hue='cat', size='size', sizes=(10, 50), palette=palette)
# Label top genes
texts = []
for gene in top_genes:
    
    if data1_mito.loc[gene, 'adj.P.Val'] < 0.05:
        #print(gene)
        color = palette[data1_mito.loc[gene, 'cat']]
        txt = plt.text(data1_mito.loc[gene, 'logFC'],
                       -1 * np.log10(data1_mito.loc[gene, 'adj.P.Val']),
                       gene, fontsize=10, ha='right', va='bottom', style='italic', color=color)
        texts.append(txt)

# Adjust text positions to reduce overlap
plt.xlim(-3, 3)
#plt.ylim(0,6)

adjust_text(texts, arrowprops=dict(arrowstyle='-', color='grey', lw=0.5))

sns.despine(top=True, right=True)
plt.xlabel('log$_{2}$(Fold Change)')
plt.ylabel('-log$_{10}$(adj.p-value) * sign(logFC)')
plt.legend(bbox_to_anchor=(1.25, 0.5), loc='center left')

plt.annotate('', xy=(3,0), xytext=(1, 0),
             arrowprops=dict(facecolor='black', shrink=0.05, width=1, headwidth=5))
plt.text(2, .5, 'Up with \n CDP-Choline', ha='center', fontsize=9)

plt.annotate('', xy=(-3,0), xytext=(-1, 0),
             arrowprops=dict(facecolor='black', shrink=0.05, width=1, headwidth=5))
plt.text(-2, .5, 'Down with \n CDP-Choline', ha='center', fontsize=9)
plt.legend().remove()
plt.title('Mitochondrial genes (MitoCarta Database 3.0)', fontsize=10)

plt.savefig('../../paper/main_plots/choline_mito_degs.png', dpi=300, bbox_inches='tight')

plt.show()
# Out:
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_61885/1843486173.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1_mito[data1_mito['adj.P.Val']>0.05]['cat'] = 'other'
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_61885/1843486173.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data1_mito['cat'][(data1_mito['logFC']<0) & (data1_mito['adj.P.Val']<0.05)] = 'down'
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_61885/1843486173.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1_mito['cat'][(data1_mito['logFC']<0) & (data1_mito['adj.P.Val']<0.05)] = 'down'
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_61885/1843486173.py:17: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data1_mito['cat'][(data1_mito['logFC']>0) & (data1_mito['adj.P.Val']<0.05)] = 'up'
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_61885/1843486173.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1_mito['cat'][(data1_mito['logFC']>0) & (data1_mito['adj.P.Val']<0.05)] = 'up'
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_61885/1843486173.py:18: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data1_mito['cat'][data1_mito['adj.P.Val']>0.05] = 'other'
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_61885/1843486173.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1_mito['cat'][data1_mito['adj.P.Val']>0.05] = 'other'

# %%
# prep data
data1_mito = data1.loc[df['Symbol'][[x in set(data1.index) for x in df['Symbol']]]]
#data1_mito['cat'] = data1_mito['genes'].map(dictionary)
#data1_mito['cat'][data1_mito['cat'].isna()] = 'other'
data1_mito[data1_mito['adj.P.Val']>0.05]['cat'] = 'other'

plt.figure(figsize=(4, 3))
bottom_genes = data1_mito.nsmallest(10, 'score').index
top_genes = data1_mito.nlargest(10, 'score').index
top_genes = np.concatenate([bottom_genes, top_genes])

data1_mito.loc[~data1_mito.index.isin(top_genes), 'cat'] = 'other'

# Your scatterplot
data1_mito['size'] = np.where(data1_mito.index.isin(top_genes), 50, 10)
data1_mito['cat'][(data1_mito['logFC']<0) & (data1_mito['adj.P.Val']<0.05)] = 'down'
data1_mito['cat'][(data1_mito['logFC']>0) & (data1_mito['adj.P.Val']<0.05)] = 'up'
data1_mito['cat'][data1_mito['adj.P.Val']>0.05] = 'other'
palette = {'down': 'grey', 'up': 'orange', 'other': '#A7A9AC'}
sns.scatterplot(data=data1_mito, x='logFC', y=-1*np.log10(data1_mito['adj.P.Val']), hue='cat', size='size', sizes=(10, 50), palette=palette)
# Label top genes
texts = []
for gene in top_genes:
    
    if data1_mito.loc[gene, 'adj.P.Val'] < 0.05:
        #print(gene)
        color = palette[data1_mito.loc[gene, 'cat']]
        txt = plt.text(data1_mito.loc[gene, 'logFC'],
                       -1 * np.log10(data1_mito.loc[gene, 'adj.P.Val']),
                       gene, fontsize=10, ha='right', va='bottom', style='italic', color=color)
        texts.append(txt)

# Adjust text positions to reduce overlap
plt.xlim(-3, 3)
#plt.ylim(0,6)

adjust_text(texts, arrowprops=dict(arrowstyle='-', color='grey', lw=0.5))

sns.despine(top=True, right=True)
plt.xlabel('log$_{2}$(Fold Change)')
plt.ylabel('-log$_{10}$(adj.p-value) * sign(logFC)')
plt.legend(bbox_to_anchor=(1.25, 0.5), loc='center left')

plt.annotate('', xy=(3,0), xytext=(1, 0),
             arrowprops=dict(facecolor='black', shrink=0.05, width=1, headwidth=5))
plt.text(2, .5, 'Up in p.Tyr622*', ha='center', fontsize=7)

plt.annotate('', xy=(-3,0), xytext=(-1, 0),
             arrowprops=dict(facecolor='black', shrink=0.05, width=1, headwidth=5))
plt.text(-2, .5, 'Down in p.Tyr622*', ha='center', fontsize=7)
plt.legend().remove()
plt.title('Mitochondrial genes (MitoCarta Database 3.0)', fontsize=10)

plt.savefig('../../paper/main_plots/y622_mito_degs.png', dpi=300, bbox_inches='tight')

plt.show()
# Out:
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_61885/3500503826.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1_mito[data1_mito['adj.P.Val']>0.05]['cat'] = 'other'
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_61885/3500503826.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data1_mito['cat'][(data1_mito['logFC']<0) & (data1_mito['adj.P.Val']<0.05)] = 'down'
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_61885/3500503826.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1_mito['cat'][(data1_mito['logFC']<0) & (data1_mito['adj.P.Val']<0.05)] = 'down'
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_61885/3500503826.py:17: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data1_mito['cat'][(data1_mito['logFC']>0) & (data1_mito['adj.P.Val']<0.05)] = 'up'
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_61885/3500503826.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1_mito['cat'][(data1_mito['logFC']>0) & (data1_mito['adj.P.Val']<0.05)] = 'up'
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_61885/3500503826.py:18: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data1_mito['cat'][data1_mito['adj.P.Val']>0.05] = 'other'
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_61885/3500503826.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1_mito['cat'][data1_mito['adj.P.Val']>0.05] = 'other'

# %%
# Load the specific sheet from the Excel file
excel_file_path = '../../../../Downloads/Human.MitoCarta3.0.xls'
sheet_name = 'Sheet1'  # Replace with the name of the sheet you want to load

# Read the specific sheet into a DataFrame
paths = pd.read_excel(excel_file_path, sheet_name='C MitoPathways')

# Display the first few rows of the DataFrame to verify the content
#df.head()

# %%
paths = paths.dropna()

# %%
pathways = dict(zip(paths['MitoPathway'], [x.split(', ') for x in paths['Genes']]))
all_genes = set(data1_mito['genes'].values)

# %%
# Subset pathways dictionary to only include genes in all_genes
subset_pathways = {k: [gene for gene in v if gene in all_genes] for k, v in pathways.items()}

# %%
genes_up = data2_mito[(data2_mito['adj.P.Val']<0.05) & (data2_mito['logFC']>0)]['genes'].values
genes_down = data2_mito[(data2_mito['adj.P.Val']<0.05) & (data2_mito['logFC']<0)]['genes'].values

# %%
pathways.keys()
# Out:
# dict_keys(['Mitochondrial central dogma', 'mtDNA maintenance', 'mtDNA replication', 'mtDNA nucleoid', 'mtDNA repair', 'mtDNA modifications', 'mtDNA stability and decay', 'mtRNA metabolism', 'Transcription', 'mtRNA granules', 'Polycistronic mtRNA processing', 'mt-tRNA modifications', 'mt-rRNA modifications', 'mt-mRNA modifications', 'mtRNA stability and decay', 'Translation', 'Mitochondrial ribosome', 'Mitochondrial ribosome assembly', 'Translation factors', 'mt-tRNA synthetases', 'fMet processing', 'Protein import, sorting and homeostasis', 'Protein import and sorting', 'TOM', 'SAM', 'MIA40', 'TIM22 carrier pathway', 'TIM23 presequence pathway', 'Import motor', 'OXA', 'Preprotein cleavage', 'Protein homeostasis', 'Proteases', 'Chaperones', 'OXPHOS', 'OXPHOS subunits', 'OXPHOS assembly factors', 'Complex I', 'CI subunits', 'CI assembly factors', 'Complex II', 'CII subunits', 'CII assembly factors', 'Complex III', 'CIII subunits', 'CIII assembly factors', 'Complex IV', 'CIV subunits', 'CIV assembly factors', 'Complex V', 'CV subunits', 'CV assembly factors', 'Respirasome assembly', 'Cytochrome C', 'Metabolism', 'Carbohydrate metabolism', 'Gluconeogenesis', 'Malate-aspartate shuttle', 'Glycerol phosphate shuttle', 'Pyruvate metabolism', 'TCA cycle', 'TCA-associated', 'Itaconate metabolism', 'Ketone metabolism', 'Propanoate metabolism', 'Lipid metabolism', 'Fatty acid oxidation', 'Type II fatty acid synthesis', 'Lipoate insertion', 'Cardiolipin synthesis', 'Cholesterol, bile acid, steroid synthesis', 'Cholesterol-associated', 'Phospholipid metabolism', 'Eicosanoid metabolism', 'Amino acid metabolism', 'Branched-chain amino acid metabolism', 'Branched-chain amino acid dehydrogenase complex', 'Lysine metabolism', 'Serine metabolism', 'Glycine metabolism', 'Glycine cleavage system', 'Glutamate metabolism', 'Proline metabolism', 'Glyoxylate metabolism', 'GABA metabolism', 'Catechol metabolism', 'Kynurenine metabolism', 'Urea cycle', 'Nucleotide metabolism', 'Nucleotide import', 'Nucleotide synthesis and processing', 'Creatine metabolism', 'Metals and cofactors', 'Carnitine synthesis and transport', 'Carnitine shuttle', 'Coenzyme A metabolism', 'Coenzyme Q metabolism', 'Copper metabolism', 'Iron homeostasis', 'Heme synthesis and processing', 'Fe-S cluster biosynthesis', 'Molybdenum cofactor synthesis and proteins', 'NAD biosynthesis and metabolism', 'Tetrahydrobiopterin synthesis', 'Fe-S-containing proteins', 'Heme-containing proteins', 'Vitamin metabolism', 'Choline and betaine metabolism', 'Biotin utilizing proteins', 'Vitamin A metabolism', 'Vitamin B1 metabolism', 'Vitamin B2 metabolism', 'Vitamin B6 metabolism', 'Vitamin B12 metabolism', 'Vitamin C metabolism', 'Vitamin D metabolism', 'Folate and 1-C metabolism', 'Detoxification', 'Xenobiotic metabolism', 'ROS and glutathione metabolism', 'Amidoxime reducing complex', 'Electron carriers', 'Cytochromes', 'Q-linked reactions, other', 'Sulfur metabolism', 'Small molecule transport', 'SLC25A family', 'ABC transporters', 'Sideroflexins', 'Calcium uniporter', 'Signaling', 'Calcium homeostasis', 'Calcium cycle', 'Mitochondrial permeability transition pore', 'EF hand proteins', 'Immune response', 'cAMP-PKA signaling', 'Mitochondrial dynamics and surveillance', 'Fusion', 'Fission', 'Organelle contact sites', 'Intramitochondrial membrane interactions', 'Trafficking', 'Mitophagy', 'Autophagy', 'Apoptosis', 'Cristae formation', 'MICOS complex'])

# %%
genes_up = data1_mito[(data1_mito['adj.P.Val']<0.05) & (data1_mito['logFC']>0)]['genes'].values
genes_down = data1_mito[(data1_mito['adj.P.Val']<0.05) & (data1_mito['logFC']<0)]['genes'].values

enr = gp.enrichr(gene_list=list(genes_down),
                 gene_sets=pathways,
                 outdir='enrichr_results', cutoff=1, background=data1_mito['genes'].values)

temp = enr.results#.sort_values('P-value', ascending=True).head(10)
p_values = temp['P-value']
# Apply FDR correction (Benjamini-Hochberg method)
_, fdr_corrected_pvals, _, _ = smm.multipletests(p_values, alpha=0.05, method='fdr_bh')
temp['FDR'] = fdr_corrected_pvals

# %%
temp[temp['Term']=='Fusion']
# Out:
#     Gene_set    Term Overlap   P-value  Adjusted P-value  Odds Ratio  \
# 29  gs_ind_0  Fusion     1/8  0.441832          0.832288    2.655172
#
#     Combined Score Genes       FDR
# 29        2.168812  MFN2  0.832288

# %%
genes_up = data1_mito[(data1_mito['adj.P.Val']<0.05) & (data1_mito['logFC']>0)]['genes'].values
genes_down = data1_mito[(data1_mito['adj.P.Val']<0.05) & (data1_mito['logFC']<0)]['genes'].values

enr = gp.enrichr(gene_list=list(genes_down),
                 gene_sets=pathways,
                 outdir='enrichr_results', cutoff=1, background=data1_mito['genes'].values)

temp = enr.results#.sort_values('P-value', ascending=True).head(10)
p_values = temp['P-value']
# Apply FDR correction (Benjamini-Hochberg method)
_, fdr_corrected_pvals, _, _ = smm.multipletests(p_values, alpha=0.05, method='fdr_bh')
temp['FDR'] = fdr_corrected_pvals

x = temp.sort_values('P-value', ascending=True)#[:10]
x = x[x['P-value']<0.05]

x['direction'] = 'down'
x['score'] = np.log10(x['P-value'])
x['sig'] = x['FDR']<0.05


enr = gp.enrichr(gene_list=list(genes_up),
                 gene_sets=pathways,
                 outdir='enrichr_results', cutoff=1, background=data1_mito['genes'].values)

temp = enr.results#.sort_values('P-value', ascending=True).head(10)
p_values = temp['P-value']
# Apply FDR correction (Benjamini-Hochberg method)
_, fdr_corrected_pvals, _, _ = smm.multipletests(p_values, alpha=0.05, method='fdr_bh')
temp['FDR'] = fdr_corrected_pvals

x2 = temp.sort_values('P-value', ascending=True)#[:10]
x2 = x2[x2['P-value']<0.05]

x2['direction'] = 'up'
x2['score'] = -np.log10(x2['P-value'])
x2['sig'] = x2['FDR']<0.05

both = pd.concat([x, x2])
both = both.sort_values('score', ascending=False)

plt.figure(figsize=(1.5, 2))
ax = sns.barplot(data=both, x='score', y='Term', hue='direction', palette={'down': 'grey', 'up': 'orange'}, width=.8, dodge=False)

sns.despine(ax=ax, top=True, right=True)
plt.ylabel('')
ax.legend_.remove()
plt.show()

# %%
both[['Term', 'score', 'P-value', 'FDR', 'Genes']].to_latex(index=False)
# Out:
# '\\begin{tabular}{lrrrl}\n\\toprule\nTerm & score & P-value & FDR & Genes \\\\\n\\midrule\nApoptosis & 1.900274 & 0.012581 & 0.415774 & BID;CASP3;CYCS;BCL2L1;BIK \\\\\nOXPHOS & 1.894438 & 0.012752 & 0.415774 & NDUFA4;TMEM126A;ATP5MG;SDHAF2;NDUFA1;COX6A1;COX14;CYCS;COA4;NDUFS4;ATP5PB;ATP5MC3;NDUFAF2;MT-ND2 \\\\\nProtein import and sorting & 1.755279 & 0.017568 & 0.415774 & TIMM8A;TIMM10;DNAJC19;SAMM50;TIMM23;TOMM22 \\\\\nOXPHOS subunits & 1.552584 & 0.028017 & 0.477391 & NDUFA4;ATP5MG;NDUFA1;COX6A1;CYCS;NDUFS4;ATP5PB;ATP5MC3;MT-ND2 \\\\\nMitochondrial dynamics and surveillance & 1.473414 & 0.033619 & 0.477391 & BID;ATP5MG;SAMM50;CASP3;CYCS;BCL2L1;FUNDC1;BIK;FUNDC2 \\\\\nAmino acid metabolism & -1.374004 & 0.042267 & 0.263353 & DLST;COMT;SLC25A44;MAOA;ABAT;SFXN3;GCAT;ALDH5A1;MCCC2;AADAT \\\\\nDetoxification & -1.395286 & 0.040245 & 0.263353 & EPHX2;DHRS2;CYB5B;CAT;TXNRD2;MAOA;CYB5R3 \\\\\nEF hand proteins & -1.441227 & 0.036205 & 0.263353 & RHOT2;SLC25A23;SLC25A25 \\\\\nLipid metabolism & -1.441792 & 0.036158 & 0.263353 & EPHX2;SLC25A1;ACADVL;GPAT2;CPT1C;ACADL;IDI1;ACP6;CROT;CYB5R3;CYP27A1;ACAD10 \\\\\nAmidoxime reducing complex & -1.576863 & 0.026493 & 0.238440 & CYB5R3;CYB5B \\\\\nVitamin metabolism & -1.639877 & 0.022915 & 0.232016 & MMAB;DHRS4;PLPBP;PNPO;RFK;PC;SFXN3 \\\\\nGluconeogenesis & -1.844185 & 0.014316 & 0.165654 & PCK2;PC;SLC25A1 \\\\\nCatechol metabolism & -1.857772 & 0.013875 & 0.165654 & COMT;MAOA \\\\\nTCA-associated & -1.887037 & 0.012971 & 0.165654 & ACLY;PCK2;PC;SLC25A1 \\\\\nABC transporters & -2.026052 & 0.009418 & 0.165654 & ABCB6;ABCD2;ABCB8 \\\\\nXenobiotic metabolism & -2.103329 & 0.007883 & 0.165654 & EPHX2;DHRS2;CYB5B;MAOA;CYB5R3 \\\\\nVitamin B6 metabolism & -2.314663 & 0.004845 & 0.165654 & PNPO;PLPBP \\\\\nMetabolism & -4.519649 & 0.000030 & 0.002448 & NMNAT3;DHRS4;CAT;GPAT2;DLAT;FECH;PNPO;SLC25A25;MCCC2;MMAB;COQ9;SLC25A1;PLPBP;ACLY;TXNRD2;ABAT;RFK;TK2;PC;IDI1;PCK2;EPHX2;DHRS2;ACADVL;IDH2;CPT1C;CROT;ALDH5A1;AADAT;ACAD10;TSTD1;CYB5B;DLST;SLC25A44;ABCB6;GATM;SLC25A23;MAOA;ACADL;SFXN3;ACP6;GCAT;COMT;CYP27A1;CYB5R3 \\\\\n\\bottomrule\n\\end{tabular}\n'

# %%
both[['Term', 'score', 'P-value', 'FDR', 'Genes']].to_latex()
# Out:
# '\\begin{tabular}{llrrrl}\n\\toprule\n & Term & score & P-value & FDR & Genes \\\\\n\\midrule\n1 & Apoptosis & 1.900274 & 0.012581 & 0.415774 & BID;CASP3;CYCS;BCL2L1;BIK \\\\\n43 & OXPHOS & 1.894438 & 0.012752 & 0.415774 & NDUFA4;TMEM126A;ATP5MG;SDHAF2;NDUFA1;COX6A1;COX14;CYCS;COA4;NDUFS4;ATP5PB;ATP5MC3;NDUFAF2;MT-ND2 \\\\\n51 & Protein import and sorting & 1.755279 & 0.017568 & 0.415774 & TIMM8A;TIMM10;DNAJC19;SAMM50;TIMM23;TOMM22 \\\\\n45 & OXPHOS subunits & 1.552584 & 0.028017 & 0.477391 & NDUFA4;ATP5MG;NDUFA1;COX6A1;CYCS;NDUFS4;ATP5PB;ATP5MC3;MT-ND2 \\\\\n0 & ABC transporters & -2.026052 & 0.009418 & 0.165654 & ABCB6;ABCD2;ABCB8 \\\\\n74 & Xenobiotic metabolism & -2.103329 & 0.007883 & 0.165654 & EPHX2;DHRS2;CYB5B;MAOA;CYB5R3 \\\\\n72 & Vitamin B6 metabolism & -2.314663 & 0.004845 & 0.165654 & PNPO;PLPBP \\\\\n39 & Metabolism & -4.519649 & 0.000030 & 0.002448 & NMNAT3;DHRS4;CAT;GPAT2;DLAT;FECH;PNPO;SLC25A25;MCCC2;MMAB;COQ9;SLC25A1;PLPBP;ACLY;TXNRD2;ABAT;RFK;TK2;PC;IDI1;PCK2;EPHX2;DHRS2;ACADVL;IDH2;CPT1C;CROT;ALDH5A1;AADAT;ACAD10;TSTD1;CYB5B;DLST;SLC25A44;ABCB6;GATM;SLC25A23;MAOA;ACADL;SFXN3;ACP6;GCAT;COMT;CYP27A1;CYB5R3 \\\\\n\\bottomrule\n\\end{tabular}\n'

# %%
genes_up = data2_mito[(data2_mito['adj.P.Val']<0.05) & (data2_mito['logFC']>0)]['genes'].values
genes_down = data2_mito[(data2_mito['adj.P.Val']<0.05) & (data2_mito['logFC']<0)]['genes'].values

enr = gp.enrichr(gene_list=list(genes_down),
                 gene_sets=pathways,
                 outdir='enrichr_results', cutoff=1, background=data2_mito['genes'].values)

temp = enr.results#.sort_values('P-value', ascending=True).head(10)
p_values = temp['P-value']
# Apply FDR correction (Benjamini-Hochberg method)
_, fdr_corrected_pvals, _, _ = smm.multipletests(p_values, alpha=0.05, method='fdr_bh')
temp['FDR'] = fdr_corrected_pvals

x = temp.sort_values('P-value', ascending=True)#[:10]
x = x[x['P-value']<0.05]
x['direction'] = 'down'
x['score'] = np.log10(x['P-value'])
x['sig'] = x['FDR']<0.05


enr = gp.enrichr(gene_list=list(genes_up),
                 gene_sets=pathways,
                 outdir='enrichr_results', cutoff=1, background=data2_mito['genes'].values)

temp = enr.results#.sort_values('P-value', ascending=True).head(10)
p_values = temp['P-value']
# Apply FDR correction (Benjamini-Hochberg method)
_, fdr_corrected_pvals, _, _ = smm.multipletests(p_values, alpha=0.05, method='fdr_bh')
temp['FDR'] = fdr_corrected_pvals

x2 = temp.sort_values('P-value', ascending=True)#[:10]
x2 = x2[x2['P-value']<0.05]
x2['direction'] = 'up'
x2['score'] = -np.log10(x2['P-value'])
x2['sig'] = x2['FDR']<0.05

both = pd.concat([x, x2])
both = both.sort_values('score', ascending=False)

plt.figure(figsize=(1.5, 2))
ax = sns.barplot(data=both, x='score', y='Term', hue='direction', palette={'down': 'grey', 'up': 'orange'}, width=.8, dodge=False)

sns.despine(ax=ax, top=True, right=True)
plt.ylabel('')
ax.legend_.remove()
plt.show()

# %%
both[['Term', 'score', 'P-value', 'FDR', 'Genes']].to_latex(index=False)
# Out:
# '\\begin{tabular}{lrrrl}\n\\toprule\nTerm & score & P-value & FDR & Genes \\\\\n\\midrule\nEF hand proteins & 4.457699 & 0.000035 & 0.003451 & SLC25A12;SLC25A23;SLC25A25;EFHD1;MICU2;SLC25A13;MICU3;SLC25A24 \\\\\nSmall molecule transport & 3.256577 & 0.000554 & 0.027418 & ABCB10;SLC25A25;MPV17L;ABCD3;ABCD1;SLC25A12;SLC25A1;SLC25A13;MICU3;SFXN1;SLC25A29;SLC25A39;SLC25A43;MICU2;SFXN5;STARD7;SLC25A24;ABCD2;SLC25A15;SLC25A22;SLC25A23;VDAC1;MPV17 \\\\\nCalcium homeostasis & 3.079591 & 0.000833 & 0.027474 & SLC25A12;SLC25A23;SLC25A25;EFHD1;VDAC1;LETM1;SLC25A13;MICU2;MICU3;SLC25A24 \\\\\nMetabolism & 2.846777 & 0.001423 & 0.033450 & ABCB10;NT5DC2;ACSL6;ME3;CS;SLC25A12;PDSS2;HSD17B4;ACLY;TK2;ALDH3A2;IDI1;NADK2;ACADS;CPT2;STARD7;AADAT;ACAD10;AK3;NNT;SOD2;CHCHD7;SLC25A23;OGDH;NMNAT3;MT-CO1;GLS;GPAT2;SLC25A25;OAT;D2HGDH;SLC25A1;ABAT;RFK;SFXN1;ALDH1B1;OXCT1;TST;HIBCH;FHIT;FH;GLYCTK;LACTB;PNPO;SERAC1;ME2;GSR;AGPAT5;PCK2;SLC25A29;EPHX2;GLDC;SFXN5;PDK3;ALDH5A1;SPHK2;SLC25A24;TSTD1;MTFMT;ACP6;NT5M;ALDH9A1;GCAT;KMO;ECI1;CAT;DLAT;COQ2;PPM1K;PRXL2A;MCCC2;CISD3;SPTLC2;SLC25A13;SLC25A15;FASN;ALDH7A1;DLST;GATM;AK4;ACADSB \\\\\nSignaling & 2.772263 & 0.001689 & 0.033450 & NLRX1;SLC25A12;PPTC7;SLC25A23;SLC25A25;EFHD1;VDAC1;LETM1;MACROD1;SLC25A13;MICU2;PDE2A;MICU3;SLC25A24;DELE1 \\\\\nTCA-associated & 2.563737 & 0.002731 & 0.045055 & SLC25A1;ACLY;ME2;SFXN5;ME3;D
PTCD2;MRPL40;MRPS18C;UNG;TFB1M;METTL5;MRPS12;MRPL14;GATC;MRPL34;MRPL32;MRPL16;TSFM;MTPAP;MRPL47;APEX1;MRPS21;ALKBH1;TEFM;MRPL55;MRPL39;MRPS7;MRPS26;MRPL22;TIMM21;MRPL15;MTERF2;NGRN;MRPS18A;TRMT10C;MTERF1;ERAL1;MRM3;COX14;MRPS31;MRPL13;PTCD3;MRPS14;DAP3;MTERF3;MRPL27;MRPS28;RARS2;MRPS18B;RMND1;MRPS15 \\\\\nOXPHOS & -3.420637 & 0.000380 & 0.013414 & UQCR10;FOXRED1;TIMMDC1;ATP5MG;COA3;SDHB;ATP5PB;UQCRH;NDUFA10;COX5B;COA6;COX7A2L;NDUFB3;NDUFA4;CYC1;SDHAF3;FMC1;SDHD;MT-ND4L;UQCRFS1;ATP5IF1;RAB5IF;COX16;NDUFAF6;SDHAF2;SURF1;NDUFV1;NDUFA1;COX6A1;TIMM21;NDUFB8;BCS1L;COA7;NDUFA12;NDUFAF1;ATP5F1A;COX14;SDHC;NDUFA6;NDUFB6;LYRM2;NDUFS4;COX7A2;UQCRC1;TME ...

# %%
temp.sort_values('P-value', ascending=True).iloc[0]['Genes']
# Out:
# 'NMNAT3;DHRS4;CAT;GPAT2;DLAT;FECH;PNPO;SLC25A25;MCCC2;MMAB;COQ9;SLC25A1;PLPBP;ACLY;TXNRD2;ABAT;RFK;TK2;PC;IDI1;PCK2;EPHX2;DHRS2;ACADVL;IDH2;CPT1C;CROT;ALDH5A1;AADAT;ACAD10;TSTD1;CYB5B;DLST;SLC25A44;ABCB6;GATM;SLC25A23;MAOA;ACADL;SFXN3;ACP6;GCAT;COMT;CYP27A1;CYB5R3'

# %%
data2.loc['OPA1']
# Out:
# genes            OPA1
# logFC        0.364388
# AveExpr      6.141216
# t            3.879033
# P.Value      0.001112
# adj.P.Val    0.005926
# B           -2.326228
# score        2.953759
# Name: OPA1, dtype: object

# %%
both[both['Adjusted P-value']<0.05]
# Out:
#     Gene_set                         Term Overlap       P-value  \
# 29  gs_ind_0             EF hand proteins    8/11  3.485789e-05
# 79  gs_ind_0     Small molecule transport   23/75  5.538893e-04
# 12  gs_ind_0          Calcium homeostasis   10/22  8.325479e-04
# 50  gs_ind_0                   Metabolism  81/402  1.423060e-03
# 78  gs_ind_0                    Signaling   15/44  1.689416e-03
# 82  gs_ind_0               TCA-associated    7/14  2.730630e-03
# 35  gs_ind_0                       Fusion     5/8  3.412393e-03
# 52  gs_ind_0  Mitochondrial central dogma  59/226  1.364626e-03
# 61  gs_ind_0                       OXPHOS  47/162  3.796325e-04
# 87  gs_ind_0                  Translation  48/151  2.218251e-05
# 55  gs_ind_0       Mitochondrial ribosome   34/81  3.903706e-07
#
#     Adjusted P-value  Odds Ratio  Combined Score  \
# 29          0.003451   13.586034      139.450188
# 79          0.027418    2.614538       19.605233
# 12          0.027474    4.711068       33.406276
# 50          0.033450    1.692525       11.094408
# 78          0.033450    2.985602       19.058207
# 82          0.045055    5.533333       32.664500
# 35          0.048261    8.625616       48.996444
# 52          0.036163    1.755452       11.580496
# 61          0.013414    2.012263       15.849202
# 87          0.001176    2.346151       25.141835
# 55          0.000041    3.573474       52.730782
#
#                                                 Genes       FDR direction  \
# 29  SLC25A12;SLC25A23;SLC25A25;EFHD1;MICU2;SLC25A1...  0.003451        up
# 79  ABCB10;SLC25A25;MPV17L;ABCD3;ABCD1;SLC25A12;SL...  0.027418        up
# 12  SLC25A12;SLC25A23;SLC25A25;EFHD1;VDAC1;LETM1;S...  0.027474        up
# 50  ABCB10;NT5DC2;ACSL6;ME3;CS;SLC25A12;PDSS2;HSD1...  0.033450        up
# 78  NLRX1;SLC25A12;PPTC7;SLC25A23;SLC25A25;EFHD1;V...  0.033450        up
# 82             SLC25A1;ACLY;ME2;SFXN5;ME3;D2HGDH;PCK2  0.045055        up
# 35                         OPA1;MIGA2;MFN2;MIGA1;MFN1  0.048261        up
# 52  MRPL4;MRPL18;COA3;MTRES1;MRPL46;MTIF3;MRPS23;M...  0.036163      down
# 61  UQCR10;FOXRED1;TIMMDC1;ATP5MG;COA3;SDHB;ATP5PB...  0.013414      down
# 87  MRPL4;MRPL18;COA3;MTRES1;MRPL46;MTIF3;MRPS23;M...  0.001176      down
# 55  MRPL4;MRPL18;MRPL46;MRPS23;MRPL37;MRPL45;MRPL3...  0.000041      down
#
#        score   sig
# 29  4.457699  True
# 79  3.256577  True
# 12  3.079591  True
# 50  2.846777  True
# 78  2.772263  True
# 82  2.563737  True
# 35  2.466941  True
# 52 -2.864986  True
# 61 -3.420637  True
# 87 -4.653989  True
# 55 -6.408523  True

# %%
enr = gp.enrichr(gene_list=list(genes_down),
                 gene_sets=subset_pathways,
                 outdir='enrichr_results', cutoff=1)

temp = enr.results#.sort_values('P-value', ascending=True).head(10)
p_values = temp['P-value']
# Apply FDR correction (Benjamini-Hochberg method)
_, fdr_corrected_pvals, _, _ = smm.multipletests(p_values, alpha=0.05, method='fdr_bh')
temp['FDR'] = fdr_corrected_pvals

temp.sort_values('FDR', ascending=True).head(10)
# Out:
#      Gene_set                         Term Overlap       P-value  \
# 55   gs_ind_0       Mitochondrial ribosome   34/81  7.081188e-07
# 87   gs_ind_0                  Translation  48/151  4.308153e-05
# 61   gs_ind_0                       OXPHOS  47/162  6.860322e-04
# 52   gs_ind_0  Mitochondrial central dogma  59/226  2.578579e-03
# 63   gs_ind_0              OXPHOS subunits   29/95  3.917040e-03
# 25   gs_ind_0                   Complex II     5/8  8.662752e-03
# 103  gs_ind_0               mtRNA granules   10/28  2.947891e-02
# 7    gs_ind_0                 CII subunits     3/4  2.442402e-02
# 9    gs_ind_0                CIII subunits    5/10  2.784126e-02
# 62   gs_ind_0      OXPHOS assembly factors   19/68  4.803946e-02
#
#      Adjusted P-value  Odds Ratio  Combined Score  \
# 55           0.000075    3.481972       49.307006
# 87           0.002283    2.284635       22.966100
# 61           0.024240    1.954585       14.238341
# 52           0.068332    1.702527       10.147942
# 63           0.083041    2.004086       11.107483
# 25           0.153042    6.701552       31.823813
# 103          0.347196    2.441028        8.602380
# 7            0.347196    9.866850       36.627607
# 9            0.347196    4.253482       15.232723
# 62           0.462926    1.712625        5.199071
#
#                                                  Genes       FDR
# 55   MRPL4;MRPL18;MRPL46;MRPS23;MRPL37;MRPL45;MRPL3...  0.000075
# 87   MRPL4;MRPL18;COA3;MTRES1;MRPL46;MTIF3;MRPS23;M...  0.002283
# 61   UQCR10;FOXRED1;TIMMDC1;ATP5MG;COA3;SDHB;ATP5PB...  0.024240
# 52   MRPL4;MRPL18;COA3;MTRES1;MRPL46;MTIF3;MRPS23;M...  0.068332
# 63   UQCR10;ATP5MG;SDHB;ATP5PB;UQCRH;NDUFA10;COX5B;...  0.083041
# 25                        SDHAF2;SDHAF3;SDHC;SDHB;SDHD  0.153042
# 103  MRPL47;ERAL1;MTPAP;ALKBH1;PTCD2;MRPS7;TFB1M;TR...  0.347196
# 7                                       SDHD;SDHC;SDHB  0.347196
# 9                     UQCR10;CYC1;UQCRH;UQCRC1;UQCRFS1  0.347196
# 62   FOXRED1;TIMMDC1;COA3;COA6;COX7A2L;SDHAF3;FMC1;...  0.462926

# %%
pre_res = gp.prerank(
    rnk=rnk,
    gene_sets=pathways,
    outdir="gseapy_out",
    permutation_num=1000,
    seed=6,
    min_size=5
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[745], line 1
# ----> 1 help(gseapy)
#
# NameError: name 'gseapy' is not defined

# %%
df
# Out:
#           HumanGeneID  MouseOrthologGeneID         Symbol  \
# 0                1537              66445.0           CYC1
# 1                6390              67680.0           SDHB
# 2               10229              12850.0           COQ7
# 3                6389              66945.0           SDHA
# 4                7384              22273.0         UQCRC1
# ...               ...                  ...            ...
# 1131           339983             269642.0          NAT8L
# 1132           401250                  NaN          MCCD1
# 1133        101928527              66364.0        PIGBOS1
# 1134        109703458          109729085.0           HTD2
# 1135  ENSG00000230623                  NaN  RP11_469A15.2
#
#                               Synonyms  \
# 0                         MC3DN6|UQCR4
# 1     CWS2|IP|PGL4|SDH|SDH1|SDH2|SDHIP
# 2              CAT5|CLK-1|CLK1|COQ10D8
# 3        CMD1GG|FP|PGL5|SDH1|SDH2|SDHF
# 4                   D3S3191|QCR1|UQCR1
# ...                                ...
# 1131              CML3|NACED|NAT8-LIKE
# 1132                                 -
# 1133                           HP06981
# 1134                                 -
# 1135                                 -
#
#                                             Description MitoCarta3.0_List  \
# 0                                         cytochrome c1      MitoCarta3.0
# 1     succinate dehydrogenase complex iron sulfur su...      MitoCarta3.0
# 2                              coenzyme Q7, hydroxylase      MitoCarta3.0
# 3     succinate dehydrogenase complex flavoprotein s...      MitoCarta3.0
# 4       ubiquinol-cytochrome c reductase core protein 1      MitoCarta3.0
# ...                                                 ...               ...
# 1131                         N-acetyltransferase 8 like      MitoCarta3.0
# 1132                 mitochondrial coiled-coil domain 1      MitoCarta3.0
# 1133                             PIGB opposite strand 1      MitoCarta3.0
# 1134           hydroxyacyl-thioester dehydratase type 2      MitoCarta3.0
# 1135                                      RP11_469A15.2      MitoCarta3.0
#
#                                   MitoCarta3.0_Evidence  \
# 0     literature, APEX_IMS, APEX_matrix, targetP sig...
# 1     literature, APEX_matrix, targetP signal+, yeas...
# 2     literature, targetP signal+, yeast mito homolo...
# 3     literature, APEX_matrix, targetP signal+, yeas...
# 4     literature, APEX_matrix, targetP signal+, yeas...
# ...                                                 ...
# 1131                                         literature
# 1132                                            manual
# 1133                                         literature
# 1134                                         literature
# 1135                                         literature
#
#      MitoCarta3.0_SubMitoLocalization  \
# 0                                 MIM
# 1                                 MIM
# 2                                 MIM
# 3                                 MIM
# 4                                 MIM
# ...                               ...
# 1131                         Membrane
# 1132                          unknown
# 1133                              MOM
# 1134                           Matrix
# 1135                              MIM
#
#                               MitoCarta3.0_MitoPathways  \
# 0     OXPHOS > Complex III > CIII subunits | Metabol...
# 1     OXPHOS > Complex II > CII subunits | Metabolis...
# 2     Metabolism > Metals and cofactors > Coenzyme Q...
# 3     OXPHOS > Complex II > CII subunits | Metabolis...
# 4     Protein import, sorting and homeostasis > Prot...
# ...                                                 ...
# 1131  Metabolism > Amino acid metabolism > Glutamate...
# 1132                                                  0
# 1133  Mitochondrial dynamics and surveillance > Orga...
# 1134  Metabolism > Lipid metabolism > Type II fatty ...
# 1135                                                NaN
#
#                                         TrainingDataset  ...  \
# 0                                                 Tmito  ...
# 1                                                 Tmito  ...
# 2                                                 Tmito  ...
# 3                                                 Tmito  ...
# 4                                                 Tmito  ...
# ...                                                 ...  ...
# 1131                                     Tpossible_mito  ...
# 1132                                     Tpossible_mito  ...
# 1133               NA - newly added to NCBI Entrez Gene  ...
# 1134               NA - newly added to NCBI Entrez Gene  ...
# 1135  NA - newly define mitochondrial protein (forme...  ...
#
#       heart_total_peak_intensity_log10  \
# 0                                 10.4
# 1                                 10.3
# 2                                  8.6
# 3                                 10.7
# 4                                 10.8
# ...                                ...
# 1131                               NaN
# 1132                               NaN
# 1133                               NaN
# 1134                               NaN
# 1135                               NaN
#
#       skeletalmuscle_total_peak_intensity_log10  \
# 0                                           9.8
# 1                                           9.2
# 2                                           8.7
# 3                                          10.6
# 4                                          10.3
# ...                                         ...
# 1131                                        NaN
# 1132                                        NaN
# 1133                                        NaN
# 1134                                        NaN
# 1135                                        NaN
#
#       adipose_total_peak_intensity_log10  \
# 0                                   10.1
# 1                                   10.1
# 2                                    8.8
# 3                                   10.6
# 4                                   10.1
# ...                                  ...
# 1131                                 NaN
# 1132                                 NaN
# 1133                                 NaN
# 1134                                 NaN
# 1135                                 NaN
#
#      smallintestine_total_peak_intensity_log10  \
# 0                                         10.2
# 1                                         10.3
# 2                                          8.6
# 3                                         10.7
# 4                                         10.6
# ...                                        ...
# 1131                                       NaN
# 1132                                       NaN
# 1133                                       NaN
# 1134                                       NaN
# 1135                                       NaN
#
#      largeintestine_total_peak_intensity_log10  \
# 0                                         10.2
# 1                                          9.9
# 2                                          9.0
# 3                                         10.6
# 4                                         10.2
# ...                                        ...
# 1131                                       NaN
# 1132                                       NaN
# 1133                                       NaN
# 1134                                       NaN
# 1135                                       NaN
#
#      stomach_total_peak_intensity_log10  placenta_total_peak_intensity_log10  \
# 0                                  10.0                                 10.0
# 1                                   9.9                                 10.1
# 2                                   8.7                                  8.3
# 3                                  10.5                                 10.4
# 4                                  10.3                                 10.2
# ...                                 ...                                  ...
# 1131                                NaN                                  NaN
# 1132                                NaN                                  NaN
# 1133                                NaN                                  NaN
# 1134                                NaN                                  NaN
# 1135                                NaN                                  NaN
#
#       testis_total_peak_intensity_log10 HPA_Main_Location_2020 (Reliability)  \
# 0                                   9.8             Mitochondria (Supported)
# 1                                   9.9             Mitochondria (Supported)
# 2                                   8.3           Plasma membrane (Approved)
# 3                                  10.4             Mitochondria (Supported)
# 4                                   9.9             Mitochondria (Supported)
# ...                                 ...                                  ...
# 1131                                NaN              Mitochondria (Approved)
# 1132                                NaN                                  NaN
# 1133                                NaN                                  NaN
# 1134                                NaN             Mitochondria (Supported)
# 1135                                NaN                                  NaN
#
#                                cat
# 0                    CIII subunits
# 1                     CII subunits
# 2            Coenzyme Q metabolism
# 3                     CII subunits
# 4              Preprotein cleavage
# ...                            ...
# 1131          Glutamate metabolism
# 1132                           NaN
# 1133       Organelle contact sites
# 1134  Type II fatty acid synthesis
# 1135                           NaN
#
# [1136 rows x 49 columns]

# %%
# prep data
data1_mito = data1[data1['genes'].str.startswith('SLC25A') | data1['genes'].str.startswith('UCP')]
#data1_mito['cat'] = data1_mito['genes'].map(dictionary)
#data1_mito['cat'][data1_mito['cat'].isna()] = 'other'
data1_mito[data1_mito['adj.P.Val']>0.05]['cat'] = 'other'

plt.figure(figsize=(4, 3))
bottom_genes = data1_mito.nsmallest(10, 'score').index
top_genes = data1_mito.nlargest(10, 'score').index
top_genes = np.concatenate([bottom_genes, top_genes])

data1_mito.loc[~data1_mito.index.isin(top_genes), 'cat'] = 'other'

# Your scatterplot
data1_mito['size'] = np.where(data1_mito.index.isin(top_genes), 50, 10)
data1_mito['cat'][(data1_mito['logFC']<0) & (data1_mito['adj.P.Val']<0.05)] = 'down'
data1_mito['cat'][(data1_mito['logFC']>0) & (data1_mito['adj.P.Val']<0.05)] = 'up'
data1_mito['cat'][data1_mito['adj.P.Val']>0.05] = 'other'
palette = {'down': 'grey', 'up': 'orange', 'other': '#A7A9AC'}
sns.scatterplot(data=data1_mito, x='logFC', y=-1*np.log10(data1_mito['adj.P.Val']), hue='cat', size='size', sizes=(10, 50), palette=palette)
# Label top genes
texts = []
for gene in top_genes:
    
    if data1_mito.loc[gene, 'P.Value'] < 0.05:
        #print(gene)
        color = palette[data1_mito.loc[gene, 'cat']]
        txt = plt.text(data1_mito.loc[gene, 'logFC'],
                       -1 * np.log10(data1_mito.loc[gene, 'adj.P.Val']),
                       gene, fontsize=10, ha='right', va='bottom', style='italic', color=color)
        texts.append(txt)

# Adjust text positions to reduce overlap
#plt.xlim(-3, 3)
#plt.ylim(0,6)

adjust_text(texts, arrowprops=dict(arrowstyle='-', color='grey', lw=0.5))

sns.despine(top=True, right=True)
plt.xlabel('log$_{2}$(Fold Change)')
plt.ylabel('-log$_{10}$(adj.p-value) * sign(logFC)')
plt.legend(bbox_to_anchor=(1.25, 0.5), loc='center left')

plt.annotate('', xy=(3,0), xytext=(1, 0),
             arrowprops=dict(facecolor='black', shrink=0.05, width=1, headwidth=5))
plt.text(2, .5, 'Up in p.Tyr622*', ha='center', fontsize=7)

plt.annotate('', xy=(-3,0), xytext=(-1, 0),
             arrowprops=dict(facecolor='black', shrink=0.05, width=1, headwidth=5))
plt.text(-2, .5, 'Down in p.Tyr622*', ha='center', fontsize=7)
plt.legend().remove()
plt.title('Mitochondrial genes (MitoCarta Database 3.0)', fontsize=10)

#plt.savefig('../../paper/main_plots/y622_mito_degs.png', dpi=300, bbox_inches='tight')

plt.show()
# Out:
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_61885/955358491.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1_mito[data1_mito['adj.P.Val']>0.05]['cat'] = 'other'
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_61885/955358491.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1_mito.loc[~data1_mito.index.isin(top_genes), 'cat'] = 'other'
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_61885/955358491.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1_mito['size'] = np.where(data1_mito.index.isin(top_genes), 50, 10)
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_61885/955358491.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data1_mito['cat'][(data1_mito['logFC']<0) & (data1_mito['adj.P.Val']<0.05)] = 'down'
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_61885/955358491.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1_mito['cat'][(data1_mito['logFC']<0) & (data1_mito['adj.P.Val']<0.05)] = 'down'
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_61885/955358491.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1_mito['cat'][(data1_mito['logFC']<0) & (data1_mito['adj.P.Val']<0.05)] = 'down'
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_61885/955358491.py:17: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data1_mito['cat'][(data1_mito['logFC']>0) & (data1_mito['adj.P.Val']<0.05)] = 'up'
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_61885/955358491.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1_mito['cat'][(data1_mito['logFC']>0) & (data1_mito['adj.P.Val']<0.05)] = 'up'
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_61885/955358491.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1_mito['cat'][(data1_mito['logFC']>0) & (data1_mito['adj.P.Val']<0.05)] = 'up'
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_61885/955358491.py:18: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data1_mito['cat'][data1_mito['adj.P.Val']>0.05] = 'other'
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_61885/955358491.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1_mito['cat'][data1_mito['adj.P.Val']>0.05] = 'other'
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_61885/955358491.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1_mito['cat'][data1_mito['adj.P.Val']>0.05] = 'other'

# %%
data1.loc[data1['genes'].isin(genes)]
# Out:
#              genes     logFC   AveExpr         t   P.Value  adj.P.Val  \
# genes
# SLC25A5    SLC25A5  0.228895  7.596151  2.566022  0.024070   0.106907
# SLC25A14  SLC25A14  0.188000  7.071055  2.306766  0.038909   0.142502
# SLC25A4    SLC25A4  0.114127  9.334606  1.603885  0.133694   0.303505
# SLC25A27  SLC25A27 -0.129514  5.957794 -1.068382  0.305547   0.500192
#
#                  B     score
# genes
# SLC25A5  -4.942853  1.618527
# SLC25A14 -5.366614  1.409945
# SLC25A4  -6.654607  0.873889
# SLC25A27 -7.091216 -0.514923

# %%
genes = [
    "SLC25A4",  # ANT1
    "SLC25A5",  # ANT2
    "SLC25A6",  # ANT3
    "SLC25A8",  # UCP2
    "SLC25A9",  # UCP3
    "SLC25A27", # UCP4
    "SLC25A14"  # UCP5
]

# %%
data1_mito[data1_mito['cat'] == 'down']['genes']
# Out:
# genes
# SLC25A43    SLC25A43
# SLC25A23    SLC25A23
# SLC25A1      SLC25A1
# SLC25A25    SLC25A25
# SLC25A44    SLC25A44
# Name: genes, dtype: object

# %%
# prep data
data3_mito = data3.loc[df['Symbol'][[x in set(data3.index) for x in df['Symbol']]]]
#data1_mito['cat'] = data1_mito['genes'].map(dictionary)
#data1_mito['cat'][data1_mito['cat'].isna()] = 'other'
data3_mito[data3_mito['adj.P.Val']>0.05]['cat'] = 'other'

plt.figure(figsize=(4, 3))
bottom_genes = data3_mito.nsmallest(10, 'score').index
top_genes = data3_mito.nlargest(10, 'score').index
top_genes = np.concatenate([bottom_genes, top_genes])

data3_mito.loc[~data3_mito.index.isin(top_genes), 'cat'] = 'other'

# Your scatterplot
data3_mito['size'] = np.where(data1_mito.index.isin(top_genes), 50, 10)
data3_mito['cat'][(data3_mito['logFC']<0) & (data3_mito['adj.P.Val']<0.05)] = 'down'
data3_mito['cat'][(data3_mito['logFC']>0) & (data3_mito['adj.P.Val']<0.05)] = 'up'
data3_mito['cat'][data3_mito['adj.P.Val']>0.05] = 'other'
palette = {'down': 'grey', 'up': 'orange', 'other': '#A7A9AC'}
sns.scatterplot(data=data1_mito, x='logFC', y=-1*np.log10(data1_mito['adj.P.Val']), hue='cat', size='size', sizes=(10, 50), palette=palette)
# Label top genes
texts = []
for gene in top_genes:
    
    if data3_mito.loc[gene, 'adj.P.Val'] < 0.05:
        #print(gene)
        color = palette[data3_mito.loc[gene, 'cat']]
        txt = plt.text(data3_mito.loc[gene, 'logFC'],
                       -1 * np.log10(data3_mito.loc[gene, 'adj.P.Val']),
                       gene, fontsize=10, ha='right', va='bottom', style='italic', color=color)
        texts.append(txt)

# Adjust text positions to reduce overlap
#plt.xlim(-3, 3)
#plt.ylim(0,6)

adjust_text(texts, arrowprops=dict(arrowstyle='-', color='grey', lw=0.5))

sns.despine(top=True, right=True)
plt.xlabel('log$_{2}$(Fold Change)')
plt.ylabel('-log$_{10}$(adj.p-value) * sign(logFC)')
plt.legend(bbox_to_anchor=(1.25, 0.5), loc='center left')

plt.annotate('', xy=(3,0), xytext=(1, 0),
             arrowprops=dict(facecolor='black', shrink=0.05, width=1, headwidth=5))
plt.text(2, .5, 'Up in p.Tyr622*', ha='center', fontsize=7)

plt.annotate('', xy=(-3,0), xytext=(-1, 0),
             arrowprops=dict(facecolor='black', shrink=0.05, width=1, headwidth=5))
plt.text(-2, .5, 'Down in p.Tyr622*', ha='center', fontsize=7)
plt.legend().remove()
plt.title('Mitochondrial genes (MitoCarta Database 3.0)', fontsize=10)

plt.savefig('../../paper/main_plots/glu_mito_degs.png', dpi=300, bbox_inches='tight')

plt.show()
# Out:
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_61885/1972965696.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3_mito[data3_mito['adj.P.Val']>0.05]['cat'] = 'other'
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_61885/1972965696.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data3_mito['cat'][(data3_mito['logFC']<0) & (data3_mito['adj.P.Val']<0.05)] = 'down'
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_61885/1972965696.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3_mito['cat'][(data3_mito['logFC']<0) & (data3_mito['adj.P.Val']<0.05)] = 'down'
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_61885/1972965696.py:17: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data3_mito['cat'][(data3_mito['logFC']>0) & (data3_mito['adj.P.Val']<0.05)] = 'up'
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_61885/1972965696.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3_mito['cat'][(data3_mito['logFC']>0) & (data3_mito['adj.P.Val']<0.05)] = 'up'
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_61885/1972965696.py:18: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data3_mito['cat'][data3_mito['adj.P.Val']>0.05] = 'other'
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_61885/1972965696.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3_mito['cat'][data3_mito['adj.P.Val']>0.05] = 'other'

# %%
data1_mito.index = np.arange(len(data1_mito))
data3_mito.index = np.arange(len(data3_mito))

# %%
data3_mito
# Out:
#         genes     logFC   AveExpr         t   P.Value  adj.P.Val         B  \
# 0        CYC1  0.038580  8.298457  0.239417  0.815018   0.922226 -7.370177
# 1        SDHB  0.149029  7.292928  1.081804  0.301618   0.617394 -6.748176
# 2        COQ7  0.067097  5.328680  0.475868  0.643127   0.834369 -7.101642
# 3        SDHA  0.090554  5.534595  0.523918  0.610336   0.818459 -7.093837
# 4      UQCRC1 -0.038445  9.231629 -0.257892  0.801071   0.914934 -7.405510
# ...       ...       ...       ...       ...       ...        ...       ...
# 1037   ARMCX6  0.260853  5.067642  1.638446  0.128519   0.467775 -5.887019
# 1038   METTL4 -0.131549  3.181515 -0.475300  0.643520   0.834416 -6.885378
# 1039   SPHKAP -0.131210  3.753122 -0.376426  0.713489   0.872345 -6.999898
# 1040    NAT8L -0.214086  2.277952 -0.989431  0.342920   0.646936 -6.365846
# 1041  PIGBOS1  0.493655  4.226211  2.700223  0.020024   0.255807 -4.054859
#
#          score    cat  size
# 0     0.088833  other    10
# 1     0.520542  other    10
# 2     0.191703  other    10
# 3     0.214431  other    10
# 4    -0.096329  other    10
# ...        ...    ...   ...
# 1037  0.891034  other    10
# 1038 -0.191438  other    10
# 1039 -0.146613  other    10
# 1040 -0.464807  other    10
# 1041  1.698440  other    10
#
# [1042 rows x 10 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy import stats
import stack_data  # Adjust this to your module's data-loading function

data_merged = pd.merge(data1_mito, data3_mito, left_index=True, right_index=True)


plt.figure(figsize=(4, 4))

# Create a random subsample (e.g., 10% of the points)
sample_df = data_merged.sample(frac=1, random_state=42)

# Plot the regression line using the full dataset without scatter points
sns.regplot(x='score_x', y='score_y', data=data_merged, scatter=False, ci=95, color='black', line_kws={'linewidth': 1})

# Overlay scatter points from the subsample
sns.scatterplot(x='score_x', y='score_y', data=sample_df, color='black', alpha=0.3, s=20)

# Calculate Pearson correlation coefficient and p-value
r, p = stats.pearsonr(data_merged['score_x'], data_merged['score_y'])

# Add text annotation with the correlation coefficient
plt.text(0.01, 1.05, f'Pearson r = {r:.3f}',
         transform=plt.gca().transAxes, verticalalignment='top')

# Add horizontal and vertical dotted lines at zero
plt.axhline(y=0, color='grey', linestyle='dotted')
plt.axvline(x=0, color='grey', linestyle='dotted')

plt.xlabel('WT vs p.Tyr622*')
plt.ylabel('WT vs p.Glu50fs*3')
# Add arrow in lower right quadrant
plt.annotate('', xy=(9, 9), xytext=(9, 5),
             arrowprops=dict(facecolor='black', shrink=0.05, width=1, headwidth=5))
plt.text(3, -14.5, 'Up in \n p.Tyr622*', ha='center', fontsize=9)

plt.annotate('', xy=(-14, -14), xytext=(-10, -14),
             arrowprops=dict(facecolor='black', shrink=0.05, width=1, headwidth=5))
plt.text(-7, -14.5, 'Down in \n p.Tyr622*', ha='center', fontsize=9)

plt.annotate('', xy=(9, -14.5), xytext=(9, -11),
             arrowprops=dict(facecolor='black', shrink=0.05, width=1, headwidth=5))
plt.text(8, -2, 'Up in \n p.Glu50fs*3', ha='center', fontsize=9, rotation=90)

plt.annotate('', xy=(9, -14.5), xytext=(6, -14.5),
             arrowprops=dict(facecolor='black', shrink=0.05, width=1, headwidth=5))
plt.text(8, -10, 'Down in \n p.Glu50fs*3', ha='center', fontsize=9, rotation=90)


plt.text(0.01, 1.1, 'Mitochondrial genes (MitoCarta Database 3.0)',
         transform=plt.gca().transAxes, verticalalignment='top')


plt.xlim(-15, 10)
plt.ylim(-15, 10)
plt.savefig('../../paper/extended_plots/rna_correlation_miocarta_both_lines.png', bbox_inches='tight')

plt.show()

# %%
data2_mito.index = np.arange(len(data2_mito))

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy import stats
import stack_data  # Adjust this to your module's data-loading function

data_merged = pd.merge(data1_mito, data2_mito, left_index=True, right_index=True)


plt.figure(figsize=(4, 4))

# Create a random subsample (e.g., 10% of the points)
sample_df = data_merged.sample(frac=1, random_state=42)

# Plot the regression line using the full dataset without scatter points
sns.regplot(x='score_x', y='score_y', data=data_merged, scatter=False, ci=95, color='black', line_kws={'linewidth': 1})

# Overlay scatter points from the subsample
sns.scatterplot(x='score_x', y='score_y', data=sample_df, color='black', alpha=0.3, s=20)

# Calculate Pearson correlation coefficient and p-value
r, p = stats.pearsonr(data_merged['score_x'], data_merged['score_y'])

# Add text annotation with the correlation coefficient
plt.text(0.01, 1.05, f'Pearson r = {r:.3f}',
         transform=plt.gca().transAxes, verticalalignment='top')

# Add horizontal and vertical dotted lines at zero
plt.axhline(y=0, color='grey', linestyle='dotted')
plt.axvline(x=0, color='grey', linestyle='dotted')

plt.xlabel('WT vs p.Tyr622*')
plt.ylabel('p.Tyr622* + H$_2$O vs p.Tyr622* + CDP-choline')
# Add arrow in lower right quadrant
plt.annotate('', xy=(14, 14), xytext=(14, 8),
             arrowprops=dict(facecolor='black', shrink=0.05, width=1, headwidth=5))
plt.text(5, -14.5, 'Up in \n p.Tyr622*', ha='center', fontsize=9)

plt.annotate('', xy=(-14, -14), xytext=(-10, -14),
             arrowprops=dict(facecolor='black', shrink=0.05, width=1, headwidth=5))
plt.text(-7, -14.5, 'Down in \n p.Tyr622*', ha='center', fontsize=9)

plt.annotate('', xy=(14, -13), xytext=(14, -8),
             arrowprops=dict(facecolor='black', shrink=0.05, width=1, headwidth=5))
plt.text(12, 4, 'Up in p.Tyr622* \n + CDP-choline', ha='center', fontsize=9, rotation=90)

plt.annotate('', xy=(14, -14), xytext=(9, -14),
             arrowprops=dict(facecolor='black', shrink=0.05, width=1, headwidth=5))
plt.text(12, -13, 'Down in p.Tyr622*\n  + CDP-choline', ha='center', fontsize=9, rotation=90)


plt.text(0.01, 1.1, 'Mitochondrial genes (MitoCarta Database 3.0)',
         transform=plt.gca().transAxes, verticalalignment='top')


plt.xlim(-15, 15)
plt.ylim(-15, 15)
plt.savefig('../../paper/extended_plots/rna_correlation_miocarta_choline.png', bbox_inches='tight')

plt.show()

# %%
data_merged.shape#[data1_mito.index.str.startswith('NDUF')]
# Out:
# (1042, 20)

# %%
# prep data
data1_mito = data1.loc[df['Symbol'][[x in set(data1.index) for x in df['Symbol']]]]
#data1_mito['cat'] = data1_mito['genes'].map(dictionary)
#data1_mito['cat'][data1_mito['cat'].isna()] = 'other'
data1_mito[data1_mito['adj.P.Val']>0.05]['cat'] = 'other'

plt.figure(figsize=(4, 3))
bottom_genes = data1_mito.nsmallest(10, 'score').index
top_genes = data1_mito.nlargest(10, 'score').index
top_genes = np.concatenate([bottom_genes, top_genes])

data1_mito.loc[~data1_mito.index.isin(top_genes), 'cat'] = 'other'

# Your scatterplot
data1_mito['size'] = np.where(data1_mito.index.isin(top_genes), 50, 10)
data1_mito['cat'][(data1_mito['logFC']<0) & (data1_mito['adj.P.Val']<0.05)] = 'down'
data1_mito['cat'][(data1_mito['logFC']>0) & (data1_mito['adj.P.Val']<0.05)] = 'up'
data1_mito['cat'][data1_mito['adj.P.Val']>0.05] = 'other'
palette = {'down': 'gray', 'up': 'orange', 'other': 'lightgrey'}
sns.scatterplot(data=data1_mito, x='logFC', y=-1*np.log10(data1_mito['adj.P.Val']), hue='cat', size='size', sizes=(10, 50), palette=palette)
# Label top genes
texts = []
for gene in top_genes:
    
    if data1_mito.loc[gene, 'adj.P.Val'] < 0.05:
        #print(gene)
        color = palette[data1_mito.loc[gene, 'cat']]
        txt = plt.text(data1_mito.loc[gene, 'logFC'],
                       -1 * np.log10(data1_mito.loc[gene, 'adj.P.Val']),
                       gene, fontsize=10, ha='right', va='bottom', style='italic', color=color)
        texts.append(txt)

# Adjust text positions to reduce overlap
plt.xlim(-4, 4)
plt.ylim(0,6)

adjust_text(texts, arrowprops=dict(arrowstyle='-', color='grey', lw=0.5))

plt.legend(bbox_to_anchor=(1.25, 0.5), loc='center left')
plt.show()
# Out:
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_61885/2088305225.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1_mito[data1_mito['adj.P.Val']>0.05]['cat'] = 'other'
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_61885/2088305225.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data1_mito['cat'][(data1_mito['logFC']<0) & (data1_mito['adj.P.Val']<0.05)] = 'down'
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_61885/2088305225.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1_mito['cat'][(data1_mito['logFC']<0) & (data1_mito['adj.P.Val']<0.05)] = 'down'
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_61885/2088305225.py:17: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data1_mito['cat'][(data1_mito['logFC']>0) & (data1_mito['adj.P.Val']<0.05)] = 'up'
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_61885/2088305225.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1_mito['cat'][(data1_mito['logFC']>0) & (data1_mito['adj.P.Val']<0.05)] = 'up'
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_61885/2088305225.py:18: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data1_mito['cat'][data1_mito['adj.P.Val']>0.05] = 'other'
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_61885/2088305225.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1_mito['cat'][data1_mito['adj.P.Val']>0.05] = 'other'

# %%
data1_mito[data1_mito['genes'] == 'UCP2']
# Out:
#     genes     logFC   AveExpr         t  P.Value  adj.P.Val         B  \
# 815  UCP2 -0.491852  2.568785 -3.213421   0.0071   0.052417 -3.169911
#
#         score    cat  size
# 815 -2.148715  other    10

# %%
data1.loc[['UCP2']]
# Out:
#       genes     logFC   AveExpr         t  P.Value  adj.P.Val         B  \
# genes
# UCP2   UCP2 -0.491852  2.568785 -3.213421   0.0071   0.052417 -3.169911
#
#           score
# genes
# UCP2  -2.148715

# %%
bottom_genes = data1_mito.nsmallest(10, 'score').index
top_genes = data1_mito.nlargest(10, 'score').index
bottom_genes
# Out:
# Index(['UQCRFS1', 'CASP3', 'COX7A2', 'MTPAP', 'ACOT9', 'C5orf63', 'MTHFD2L',
#        'COMT', 'BID', 'APOOL'],
#       dtype='object', name='genes')

# %%
# prep data
data1_mito = data1.loc[df['Symbol'][[x in set(data1.index) for x in df['Symbol']]]]
data1_mito['cat'] = data1_mito['genes'].map(dictionary)
data1_mito['cat'][data1_mito['cat'].isna()] = 'other'
data1_mito[data1_mito['adj.P.Val']>0.05]['cat'] = 'other'

plt.figure(figsize=(2.7, 4))
top_genes = data1_mito.nsmallest(20, 'score').index
data1_mito.loc[~data1_mito.index.isin(top_genes), 'cat'] = 'other'

# Your scatterplot
data1_mito['size'] = np.where(data1_mito.index.isin(top_genes), 50, 10)
sns.scatterplot(data=data1_mito, x='logFC', y=-1*np.log10(data1_mito['adj.P.Val']), hue='cat', size='size', sizes=(10, 50), palette=palette)
# Label top genes
texts = []
for gene in top_genes:
    
    if data1_mito.loc[gene, 'adj.P.Val'] < 0.05:
        print(gene)
        txt = plt.text(data1_mito.loc[gene, 'logFC'],
                       -1 * np.log10(data1_mito.loc[gene, 'adj.P.Val']),
                       gene, fontsize=10, ha='right', va='bottom')
        texts.append(txt)

# Adjust text positions to reduce overlap
plt.xlim(-4, 0)
plt.ylim(0,6)

adjust_text(texts, arrowprops=dict(arrowstyle='-', color='grey', lw=0.5))

plt.legend(bbox_to_anchor=(1.25, 0.5), loc='center left')
plt.show()
# Out:
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_61885/120320246.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data1_mito['cat'][data1_mito['cat'].isna()] = 'other'
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_61885/120320246.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1_mito['cat'][data1_mito['cat'].isna()] = 'other'
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_61885/120320246.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1_mito[data1_mito['adj.P.Val']>0.05]['cat'] = 'other'
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_61885/120320246.py:13: UserWarning: The palette list has more values (20) than needed (18), which may not be intended.
#   sns.scatterplot(data=data1_mito, x='logFC', y=-1*np.log10(data1_mito['adj.P.Val']), hue='cat', size='size', sizes=(10, 50), palette=palette)
# CAT
# STOM
# COX7A1
# MAOA
# SEPTIN4
# PNPO
# DNAJC15
# SLC25A43
# PDE2A
# SLC25A23
# SPATA20
# IDI1
# TSTD1
# ACP6
# ACAD9
# EPHX2
# CYB5R3
# CYP27A1
# GPAT2
# TRMT2B

# %%
data1_mito.loc[top_genes]
# Out:
#              genes     logFC   AveExpr          t       P.Value     adj.P.Val  \
# genes
# CAT            CAT -9.251469 -2.005603 -25.357150  3.984076e-12  1.655830e-08
# STOM          STOM -1.524403  3.999877 -13.944854  5.466140e-09  3.428051e-06
# COX7A1      COX7A1 -4.593914 -2.700801  -9.750946  3.349631e-07  6.455614e-05
# MAOA          MAOA -1.221503  5.512410  -9.546440  4.240028e-07  7.864953e-05
# SEPTIN4    SEPTIN4 -0.734639  6.735638  -8.278617  2.005596e-06  2.358365e-04
# PNPO          PNPO -1.216590  3.439266  -7.465916  5.958095e-06  5.095332e-04
# DNAJC15    DNAJC15 -0.772756  5.953554  -7.323752  7.267152e-06  5.908835e-04
# SLC25A43  SLC25A43 -2.253449 -0.278374  -6.381124  2.896392e-05  1.649764e-03
# PDE2A        PDE2A -1.072235  3.846505  -6.376105  2.918717e-05  1.649764e-03
# SLC25A23  SLC25A23 -0.670004  5.262162  -5.807236  7.127533e-05  3.083819e-03
#
#                   B      score                             cat  size
# genes
# CAT       13.553572 -11.399672  ROS and glutathione metabolism    50
# STOM      11.135883  -8.262319                           other    50
# COX7A1     6.441461  -6.475003                    CIV subunits    50
# MAOA       6.501733  -6.372631             Catechol metabolism    50
# SEPTIN4    4.792512  -5.697757                       Apoptosis    50
# PNPO       3.941023  -5.224893           Vitamin B6 metabolism    50
# DNAJC15    3.488688  -5.138636                    Import motor    50
# SLC25A43   2.791203  -4.538143                   SLC25A family    50
# PDE2A      2.233296  -4.534808              cAMP-PKA signaling    50
# SLC25A23   1.152501  -4.147061               Nucleotide import    50

# %%
# prep data
data1_mito = data1.loc[df['Symbol'][[x in set(data1.index) for x in df['Symbol']]]]
data1_mito['cat'] = data1_mito['genes'].map(dictionary)
data1_mito['cat'][data1_mito['cat'].isna()] = 'other'
data1_mito[data1_mito['adj.P.Val']>0.05]['cat'] = 'other'

plt.figure(figsize=(2.7, 4))
top_genes = data1_mito.nlargest(20, 'score').index
data1_mito.loc[~data1_mito.index.isin(top_genes), 'cat'] = 'other'

# Your scatterplot
data1_mito['size'] = np.where(data1_mito.index.isin(top_genes), 50, 10)
sns.scatterplot(data=data1_mito, x='logFC', y=-1*np.log10(data1_mito['adj.P.Val']), hue='cat', size='size', sizes=(10, 50), palette=palette)
# Label top genes
texts = []
for gene in top_genes:
    
    if data1_mito.loc[gene, 'adj.P.Val'] < 0.05:
        print(gene)
        txt = plt.text(data1_mito.loc[gene, 'logFC'],
                       -1 * np.log10(data1_mito.loc[gene, 'adj.P.Val']),
                       gene, fontsize=10, ha='right', va='bottom')
        texts.append(txt)

# Adjust text positions to reduce overlap
plt.xlim(0, 2)
plt.ylim(0,6)

adjust_text(texts, arrowprops=dict(arrowstyle='-', color='grey', lw=0.5))

plt.legend(bbox_to_anchor=(1.25, 0.5), loc='center left')
plt.show()
# Out:
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_61885/2906457360.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data1_mito['cat'][data1_mito['cat'].isna()] = 'other'
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_61885/2906457360.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1_mito['cat'][data1_mito['cat'].isna()] = 'other'
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_61885/2906457360.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1_mito[data1_mito['adj.P.Val']>0.05]['cat'] = 'other'
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_61885/2906457360.py:13: UserWarning: The palette list has more values (20) than needed (16), which may not be intended.
#   sns.scatterplot(data=data1_mito, x='logFC', y=-1*np.log10(data1_mito['adj.P.Val']), hue='cat', size='size', sizes=(10, 50), palette=palette)
# CASP3
# MTHFD2L
# CRYZ
# BCL2L1
# FUNDC1
# SUCLG1
# MT-ND2
# BID
# MMADHC
# COQ3
# FUNDC2
# LDHB
# NDUFA1
# LETMD1
# TIMM8A
# ATP5MG
# DHRS1
# MRPL47
# ATP5MC3
# NDUFS4

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from adjustText import adjust_text

data1_mito = data1.loc[df['Symbol'][[x in set(data1.index) for x in df['Symbol']]]]

df['cat'] = [x.split(' |')[0].split('> ')[-1] if isinstance(x, str) else np.NaN for x in df['MitoCarta3.0_MitoPathways'].values]
dictionary = dict(zip(df['Symbol'], df['cat']))

data1_mito['cat'] = data1_mito['genes'].map(dictionary)

data1_mito['cat'][data1_mito['cat'].isna()] = 'other'



data1_mito[data1_mito['adj.P.Val']<0.05]['cat'] = 'other'

plt.figure(figsize=(2.7, 4))
top_genes = data1_mito.nsmallest(10, 'logFC').index

data1_mito.loc[~data1_mito.index.isin(top_genes), 'cat'] = 'other'
# Your scatterplot
data1_mito['size'] = np.where(data1_mito.index.isin(top_genes), 50, 10)
sns.scatterplot(data=data1_mito, x='logFC', y=-1*np.log10(data1_mito['adj.P.Val']), hue='cat', size='size', sizes=(10, 50), palette=palette)

# Label top genes
texts = []
for gene in top_genes:
    if data1_mito.loc[gene, 'adj.P.Val'] < 0.05:
        txt = plt.text(data1_mito.loc[gene, 'logFC'],
                       -1 * np.log10(data1_mito.loc[gene, 'adj.P.Val']),
                       gene, fontsize=9, ha='right', va='bottom')
        texts.append(txt)

# Adjust text positions to reduce overlap
plt.xlim(-2, 0)

adjust_text(texts, arrowprops=dict(arrowstyle='-', color='grey', lw=0.5))

plt.legend(bbox_to_anchor=(1.25, 0.5), loc='center left')
plt.show()
# Out:
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_61885/1657186307.py:13: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data1_mito['cat'][data1_mito['cat'].isna()] = 'other'
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_61885/1657186307.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1_mito['cat'][data1_mito['cat'].isna()] = 'other'
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_61885/1657186307.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1_mito[data1_mito['adj.P.Val']<0.05]['cat'] = 'other'
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_61885/1657186307.py:25: UserWarning: The palette list has more values (20) than needed (9), which may not be intended.
#   sns.scatterplot(data=data1_mito, x='logFC', y=-1*np.log10(data1_mito['adj.P.Val']), hue='cat', size='size', sizes=(10, 50), palette=palette)

# %%
x.sort_values(by='logFC_x', ascending=True)[:50]
# Out:
#            genes_x   logFC_x  AveExpr_x        t_x     P.Value_x  \
# genes
# CAT            CAT -9.251469  -2.005603 -25.357150  3.984076e-12
# COX7A1      COX7A1 -4.593914  -2.700801  -9.750946  3.349631e-07
# SLC25A43  SLC25A43 -2.253449  -0.278374  -6.381124  2.896392e-05
# GPAT2        GPAT2 -1.610503  -0.868233  -5.066137  2.440621e-04
# STOM          STOM -1.524403   3.999877 -13.944854  5.466140e-09
# ABCD2        ABCD2 -1.358543   0.635982  -4.713592  4.500873e-04
# ECHDC3      ECHDC3 -1.328385   0.040476  -4.017498  1.577326e-03
# ACADL        ACADL -1.310221  -0.486255  -3.365642  5.325931e-03
# BCL2L10    BCL2L10 -1.249756  -0.274770  -4.276391  9.829372e-04
# MAOA          MAOA -1.221503   5.512410  -9.546440  4.240028e-07
# SLC25A23       MIM
# SLC25A25       MIM
# EPHX2      unknown
# ABCD1     Membrane
# MGST1     Membrane
# PC          Matrix
# MUTYH       Matrix
# ACAD10      Matrix
# HTATIP2   Membrane
# MCCC2       Matrix

# %%
sns.scatterplot(data=x, x='logFC_x', y=-1*np.log10(x['adj.P.Val_x']), hue='category', s = 10)

# Label top genes
top_genes = x.nlargest(30, 'logFC_x').index

for gene in top_genes:
    if x.loc[gene, 'adj.P.Val_x']<0.05:
        plt.text(x.loc[gene, 'logFC_x'], -1*np.log10(x.loc[gene, 'adj.P.Val_x']), gene, fontsize=9, ha='right', va='bottom')

plt.xlim(-2,2)
sns.scatterplot(data=x, x='logFC_x', y=-1*np.log10(x['adj.P.Val_x']), hue='category', s = 10)


# Move legend outside
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %%
x
# Out:
#          genes_x   logFC_x  AveExpr_x       t_x  P.Value_x  adj.P.Val_x  \
# genes
# CYC1        CYC1 -0.010086   8.262270 -0.112412   0.912282     0.950910
# SDHB        SDHB  0.158903   7.299210  1.757461   0.103282     0.256550
# COQ7        COQ7  0.106409   5.356537  1.009527   0.331864     0.527029
# SDHA        SDHA  0.062024   5.515638  0.552580   0.590296     0.740710
# UQCRC1    UQCRC1 -0.105863   9.183046 -1.242216   0.236957     0.428024
# ...          ...       ...        ...       ...        ...          ...
# ARMCX6    ARMCX6  0.290565   5.089564  2.848507   0.014157     0.077331
# METTL4    METTL4  0.027856   3.303517  0.160038   0.875408     0.930969
# SPHKAP    SPHKAP -0.046563   3.818177 -0.303046   0.766839     0.866133
# NAT8L      NAT8L  0.154988   2.544380  0.813187   0.431328     0.616961
# PIGBOS1  PIGBOS1  0.387362   4.147284  2.936639   0.011986     0.070406
#
#               B_x   score_x  genes_y   logFC_y  AveExpr_y       t_y  \
# genes
# CYC1    -7.841391 -0.039871     CYC1 -0.280341   8.119527 -5.007905
# SDHB    -6.285683  0.985974     SDHB -0.240714   7.226107 -4.359117
# COQ7    -7.085754  0.479039     COQ7 -0.149634   5.313715 -2.224002
# SDHA    -7.469801  0.228930     SDHA -0.155638   5.458298 -2.092805
# UQCRC1  -7.127569 -0.625330   UQCRC1 -0.296956   9.005188 -5.323783
# ...           ...       ...      ...       ...        ...       ...
# ARMCX6  -4.207370  1.849034   ARMCX6 -0.120844   5.111135 -1.803883
# METTL4  -7.298622  0.057790   METTL4 -0.014871   3.304112 -0.132596
# SPHKAP  -7.359504 -0.115296   SPHKAP -0.227022   3.686494 -2.563317
# NAT8L   -6.800241  0.365193    NAT8L -0.118335   2.534297 -0.817303
# PIGBOS1 -3.905759  1.921332  PIGBOS1 -0.125612   4.198410 -1.546257
#
#          P.Value_y  adj.P.Val_y       B_y   score_y  category
# genes
# CYC1      0.000093     0.000909  0.010392 -4.030579       MIM
# SDHB      0.000384     0.002656 -1.355676 -3.415666       MIM
# COQ7      0.039284     0.087394 -5.684523 -1.405785       MIM
# SDHA      0.050909     0.106644 -5.940550 -1.293208       MIM
# UQCRC1    0.000047     0.000543  0.636534 -4.323868       MIM
# ...            ...          ...       ...       ...       ...
# ARMCX6    0.088134     0.163092 -6.381881 -1.054856  Membrane
# METTL4    0.895995     0.930399 -7.610452 -0.047695    Matrix
# SPHKAP    0.019622     0.051498 -4.755112 -1.707268       MIM
# NAT8L     0.424518     0.542701 -7.092987 -0.372103  Membrane
# PIGBOS1   0.139568     0.233441 -6.621749 -0.855213       MOM
#
# [1042 rows x 17 columns]

# %%
sns.scatterplot(data=x, x='logFC_x', y=-1*np.log10(x['P.Value_x']), hue='category', s = 10)

# Label top genes
top_genes = x.nlargest(15, 'logFC_x').index
bottom_genes = x.nsmallest(15, 'logFC_x').index

for gene in top_genes:
    plt.text(x.loc[gene, 'logFC_x'], -1*np.log10(x.loc[gene, 'P.Value_x']), gene, fontsize=9, ha='right', va='bottom')

for gene in bottom_genes:
    plt.text(x.loc[gene, 'logFC_x'], -1*np.log10(x.loc[gene, 'P.Value_x']), gene, fontsize=9, ha='right', va='bottom')

plt.xlim(-2,2)
sns.scatterplot(data=x, x='logFC_x', y=-1*np.log10(x['P.Value_x']), hue='category', s = 10)


# Move legend outside
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %%
f = data2_mito[data2_mito['adj.P.Val']<0.05]
f.sort_values(by='logFC', ascending=False)[:50]
# Out:
#              genes     logFC   AveExpr          t       P.Value     adj.P.Val  \
# genes
# CAT            CAT  8.377915 -0.464827  19.164868  2.312056e-13  1.127769e-10
# COX7A1      COX7A1  3.236254 -2.462194   4.857757  1.289356e-04  1.155157e-03
# KMO            KMO  2.760587 -0.250769   9.711403  1.496525e-08  8.798768e-07
# SLC25A43  SLC25A43  1.489805 -0.185117   4.861642  1.278539e-04  1.147404e-03
# TSTD1        TSTD1  1.423471  4.246444  11.121307  1.841695e-09  1.580587e-07
# PNPO          PNPO  1.339435  3.755787  12.747413  2.084573e-10  2.603329e-08
# BCL2          BCL2  1.164530  1.397172   6.390962  5.290085e-06  9.649643e-05
# FHIT          FHIT  1.119670  5.059994   8.051748  2.352803e-07  8.443164e-06
# AK4            AK4  1.119607  0.286850   3.895826  1.071624e-03  5.761179e-03
# TST            TST  1.064256  1.136468   5.667569  2.303952e-05  3.118504e-04
# GLDC          GLDC  1.007417  1.167410   4.970141  1.011076e-04  9.642992e-04
# GPAT2        GPAT2  0.983327 -0.825157   3.238950  4.587916e-03  1.719000e-02
# DNAJC15    DNAJC15  0.957886  6.213405  14.723433  1.964254e-11  3.979881e-09
# BCL2L11    BCL2L11  0.956324  0.918102   3.706888  1.630369e-03  7.851355e-03
# PRKN          PRKN  0.938162  2.304055   5.938387  1.317659e-05  2.017857e-04
# MPV17L      MPV17L  0.920742  2.478595   7.060163  1.443060e-06  3.399839e-05
# EFHD1        EFHD1  0.895264 -0.100743   2.821173  1.136734e-02  3.414870e-02
# ABCD1        ABCD1  0.866845 -0.712500   2.743570  1.341552e-02  3.874615e-02
# CHCHD10    CHCHD10  0.855967  1.120844   3.706489  1.631814e-03  7.852022e-03
# NLRX1        NLRX1  0.846705  0.570630   4.029861  7.958073e-04  4.550926e-03
# HEBP1        HEBP1  0.752259  2.754504   6.388340  5.317707e-06  9.686611e-05
# ABCD1     -3.299600   1.872392
# CHCHD10   -1.691790   2.787329
# NLRX1     -0.855860   3.099192
# HEBP1      3.677459   5.274276
# MT-ND3     1.291108   4.462622
# SFXN5     -1.780748   2.771277
# CRYZ       2.537333   4.767368
# NMNAT3    -3.142743   2.113381
# DCAKD      5.490992   6.248768
# ACP6       1.696653   4.418827
# GATM       8.871802   7.646556
# GLYCTK    -2.331598   2.545621
# PDK3       6.820946   6.768441
# FASN      -0.411379   3.557032
# SDHAF4     2.083751   4.717966
# SPATA20    4.724489   5.875148
# MT-ND1     3.813172   5.658987
# ABCD2     -3.324473   1.993074
# PCK2      -3.156791   2.290261
# PDE2A     -0.755430   3.479019
# GLS       -0.312308   3.798412
# DLST      -1.882459   2.904716
# SFXN1      2.863023   5.179480
# TK2       -0.750296   3.386265
# ACADS     -2.205554   2.718021
# HSD17B4    4.853443   6.022444
# ABCD3     -0.959238   3.537670
# MT-ND2     0.230337   4.142132
# ABAT       2.557449   4.952414
# ABCB10     3.161214   5.238136
# MCCC2     -1.099323   3.357869
# ACLY       0.055176   4.047754
# OXCT1      1.282956   4.539892

# %%
import statsmodels.stats.multitest as smm
import gseapy as gp

mito_dict = {}
for loc, symbol in zip(df['MitoCarta3.0_MitoPathways'], df['Symbol']):
    mito_dict.setdefault(str(loc), []).append(symbol)

mito_dict.keys()
# Out:
# dict_keys(['OXPHOS > Complex III > CIII subunits | Metabolism > Metals and cofactors > Heme-containing proteins | Metabolism > Electron carriers > Cytochromes | OXPHOS > OXPHOS subunits', 'OXPHOS > Complex II > CII subunits | Metabolism > Carbohydrate metabolism > TCA cycle | Metabolism > Metals and cofactors > Fe-S-containing proteins | OXPHOS > OXPHOS subunits', 'Metabolism > Metals and cofactors > Coenzyme Q metabolism', 'OXPHOS > Complex II > CII subunits | Metabolism > Carbohydrate metabolism > TCA cycle | OXPHOS > OXPHOS subunits', 'Protein import, sorting and homeostasis > Protein import and sorting > Preprotein cleavage | OXPHOS > Complex III > CIII subunits | OXPHOS > OXPHOS subunits', 'Metabolism > Carbohydrate metabolism > Pyruvate metabolism', 'Mitochondrial central dogma > mtRNA metabolism > Transcription | Mitochondrial central dogma > Translation > Mitochondrial ribosome', 'OXPHOS > Complex V > CV subunits | OXPHOS > OXPHOS subunits', 'OXPHOS > Complex IV > CIV subunits | OXPHOS > OXPHOS subunits', 'Metabolism > Metals and cofactors > Fe-S cluster biosynthesis | Metabolism > Metals and cofactors > Fe-S-containing proteins', 'Protein import, sorting and homeostasis > Protein import and sorting > Preprotein cleavage | Protein import, sorting and homeostasis > Protein homeostasis > Proteases', 'OXPHOS > Complex III > CIII subunits | Metabolism > Metals and cofactors > Fe-S-containing proteins | OXPHOS > OXPHOS subunits', 'Metabolism > Carbohydrate metabolism > TCA cycle', 'OXPHOS > Complex II > CII subunits | Metabolism > Carbohydrate metabolism > TCA cycle | Metabolism > Metals and cofactors > Heme-containing proteins | OXPHOS > OXPHOS subunits', 'Mitochondrial central dogma > Translation > Mitochondrial ribosome', 'OXPHOS > Complex III > CIII subunits | OXPHOS > OXPHOS subunits', 'Metabolism > Amino acid metabolism > Branched-chain amino acid metabolism | Metabolism > Amino acid metabolism > Branched-chain amino acid dehydrogenase complex', 'Metabolism > Carbohydrate metabolism > Gluconeogenesis | Metabolism > Carbohydrate metabolism > Malate-aspartate shuttle | Metabolism > Carbohydrate metabolism > TCA cycle', 'Protein import, sorting and homeostasis > Protein import and sorting > Import motor | Metabolism > Metals and cofactors > Fe-S cluster biosynthesis', 'Mitochondrial central dogma > mtRNA metabolism > mtRNA stability and decay | Mitochondrial central dogma > Translation', 'Metabolism > Carbohydrate metabolism > TCA cycle | Metabolism > Amino acid metabolism > Lysine metabolism', 'Mitochondrial central dogma > Translation > Translation factors', 'Metabolism > Carbohydrate metabolism > Gluconeogenesis | Metabolism > Carbohydrate metabolism > Pyruvate metabolism | Metabolism > Carbohydrate metabolism > TCA-associated | Small molecule transport', 'OXPHOS > Complex I > CI subunits | Metabolism > Metals and cofactors > Fe-S-containing proteins | OXPHOS > OXPHOS subunits', 'Metabolism > Metals and cofactors > Copper metabolism | Signaling > Calcium homeostasis > Calcium cycle | Small molecule transport > SLC25A family', 'OXPHOS > Complex II > CII assembly factors | OXPHOS > OXPHOS assembly factors', 'Metabolism > Carbohydrate metabolism > TCA cycle | Metabolism > Carbohydrate metabolism > Itaconate metabolism | Metabolism > Nucleotide metabolism > Nucleotide synthesis and processing', 'Mitochondrial central dogma > Translation > mt-tRNA synthetases', 'OXPHOS > Complex IV > CIV assembly factors | Metabolism > Metals and cofactors > Copper metabolism | OXPHOS > OXPHOS assembly factors', 'Metabolism > Lipid metabolism > Fatty acid oxidation | Metabolism > Amino acid metabolism > Branched-chain amino acid metabolism | Metabolism > Amino acid metabolism > Lysine metabolism | Metabolism > Amino acid metabolism > Glycine metabolism | Metabolism > Metals and cofactors > Fe-S-containing proteins | Metabolism > Vitamin metabolism > Choline and betaine metabolism | Metabolism > Electron carriers > Q-linked reactions, other ...

# %%
data1['score'] = -np.log10(data1['P.Value']) * np.sign(data1['logFC'])
rnk = data1[['genes', 'score']].dropna()
rnk.columns = ['gene', 'score']
rnk = rnk.sort_values('score', ascending=False)

pre_res = gp.prerank(
    rnk=rnk,
    gene_sets=mito_dict,
    outdir="gseapy_out",
    permutation_num=1000,
    seed=6,
    min_size=5
)

temp = pre_res.res2d
p_values = temp['NOM p-val']
# Apply FDR correction (Benjamini-Hochberg method)
_, fdr_corrected_pvals, _, _ = smm.multipletests(p_values, alpha=0.05, method='fdr_bh')
temp['FDR'] = fdr_corrected_pvals

# extract leading edge genes
temp = pre_res.res2d
temp = temp.sort_values('FDR')
temp['Term']
# Out:
# 0     Mitochondrial central dogma > Translation > Mi...
# 1     OXPHOS > Complex I > CI subunits | OXPHOS > OX...
# 2     OXPHOS > Complex V > CV subunits | OXPHOS > OX...
# 3     OXPHOS > Complex IV > CIV assembly factors | O...
# 4     OXPHOS > Complex III > CIII subunits | OXPHOS ...
# 5     OXPHOS > Complex IV > CIV subunits | OXPHOS > ...
# 6     OXPHOS > Complex IV > CIV assembly factors | M...
# 7     Metabolism > Nucleotide metabolism > Nucleotid...
# 8     Metabolism > Lipid metabolism > Cholesterol, b...
# 9     Metabolism > Vitamin metabolism > Folate and 1...
# 12    Metabolism > Lipid metabolism > Fatty acid oxi...
# 13                       Signaling > cAMP-PKA signaling
# 10    Mitochondrial dynamics and surveillance > Cris...
# 18    Metabolism > Amino acid metabolism > Branched-...
# 17             Small molecule transport > SLC25A family
# 11    Protein import, sorting and homeostasis > Prot...
# 14    Mitochondrial central dogma > mtDNA maintenanc...
# 15    OXPHOS > Complex I > CI assembly factors | OXP...
# 16    Metabolism > Metals and cofactors > Fe-S clust...
# 19    Metabolism > Carbohydrate metabolism > Pyruvat...
# 20    Metabolism > Detoxification > ROS and glutathi...
# 21    Protein import, sorting and homeostasis > Prot...
# 22    Metabolism > Metals and cofactors > Fe-S clust...
# 23                             Small molecule transport
# 24     Metabolism > Carbohydrate metabolism > TCA cycle
# 25    Protein import, sorting and homeostasis > Prot...
# 26    Metabolism > Metals and cofactors > NAD biosyn...
# 27    Mitochondrial dynamics and surveillance > Apop...
# 29    Mitochondrial dynamics and surveillance > Mito...
# 28    Metabolism > Amino acid metabolism > Branched-...
# 36    Mitochondrial central dogma > Translation > Tr...
# 34    Protein import, sorting and homeostasis > Prot...
# 33    Mitochondrial central dogma > mtRNA metabolism...
# 35    Protein import, sorting and homeostasis > Prot...
# 31    Metabolism > Carbohydrate metabolism > TCA-ass...
# 30    OXPHOS > Complex I > CI subunits | Metabolism ...
# 32                                                    0
# 37    Metabolism > Lipid metabolism > Cardiolipin sy...
# 38    Metabolism > Detoxification > Xenobiotic metab...
# 39    OXPHOS > Complex III > CIII assembly factors |...
# 40    Metabolism > Lipid metabolism > Phospholipid m...
# 41    Mitochondrial central dogma > Translation > Mi...
# 42    Mitochondrial central dogma > Translation > mt...
# 43    Mitochondrial dynamics and surveillance > Fission
# 44    Metabolism > Metals and cofactors > Coenzyme Q...
# 46                                            Signaling
# 45                        Metabolism > Lipid metabolism
# 47    Metabolism > Lipid metabolism > Type II fatty ...
# Name: Term, dtype: object

# %%
temp
# Out:
#        Name                                               Term        ES  \
# 0   prerank  Mitochondrial central dogma > Translation > Mi...  0.651249
# 1   prerank  OXPHOS > Complex I > CI subunits | OXPHOS > OX...  0.754173
# 2   prerank  OXPHOS > Complex V > CV subunits | OXPHOS > OX...  0.749931
# 3   prerank  OXPHOS > Complex IV > CIV assembly factors | O...  0.660736
# 4   prerank  OXPHOS > Complex III > CIII subunits | OXPHOS ...  0.852867
# 5   prerank  OXPHOS > Complex IV > CIV subunits | OXPHOS > ...  0.611241
# 6   prerank  OXPHOS > Complex IV > CIV assembly factors | M...  0.815378
# 7   prerank  Metabolism > Nucleotide metabolism > Nucleotid...  0.491511
# 8   prerank  Metabolism > Lipid metabolism > Cholesterol, b...  0.730071
# 9   prerank  Metabolism > Vitamin metabolism > Folate and 1...  0.681533
# 12  prerank  Metabolism > Lipid metabolism > Fatty acid oxi... -0.600235
# 13  prerank                     Signaling > cAMP-PKA signaling -0.739599
# 10  prerank  Mitochondrial dynamics and surveillance > Cris...  0.671233
# 18  prerank  Metabolism > Amino acid metabolism > Branched-... -0.651677
# 17  prerank           Small molecule transport > SLC25A family -0.559668
# 11  prerank  Protein import, sorting and homeostasis > Prot...  0.612525
# 12                     ACADVL;ACAD10;CROT;ACADL;ACADS  0.425532
# 13                                              PDE2A  0.425532
# 10                                        APOO;CHCHD6  0.445249
# 18                                    MCCC2;HIBCH;IVD  0.452381
# 17                    SLC25A43;UCP2;SLC25A39;SLC25A22  0.452381
# 11                         TIMM8A;TIMM10;TIMM9;TIMM8B  0.452381
# 14                                     UNG;POLB;APEX1  0.452381
# 15  TMEM126A;NDUFAF2;TMEM126B;NDUFAF6;NDUFAF5;LYRM...  0.452381
# 16            ISCA1;CISD1;GLRX5;NFU1;BOLA3;ISCU;BOLA1  0.454562
# 19                                     DLAT;PDP2;PDP1  0.533915
# 20                                                CAT  0.533915
# 21                                       TOMM22;TOMM5  0.562647
# 22                                     LYRM4;FXN;HSCB  0.610546
# 23                                       LETMD1;VDAC2   0.66289
# 24                           IDH2;IDH3A;OGDHL;OGDH;CS  0.709994
# 25  YME1L1;AFG3L2;SPG7;IDE;LAP3;PITRM1;AFG1L;NLN;A...  0.709994
# 26                                   NMNAT3;NNT;SIRT5  0.709994
# 27                                     BCL2L1;BID;BIK  0.709994
# 29                                             FUNDC1  0.709994
# 28                                 PPM1K;BCKDHB;BCKDK  0.734059
# 36                              MTIF3;TUFM;MRRF;MTIF2  0.776904
# 34                             PHB2;HSPE1;HSPD1;MAIP1  0.776904
# 33                             TRNT1;QTRT1;TRMU;NSUN2  0.776904
# 35                        IMMP2L;IMMP1L;XPNPEP3;PMPCB  0.776904
# 31                                        ACLY;D2HGDH  0.776904
# 30                               NDUFV1;NDUFS2;NDUFS1  0.776904
# 32  STOM;SPATA20;CRY1;TDRKH;HTATIP2;DMPK;ECHDC3;AD...  0.776904
# 37                                GPAT2;AGPAT5;PNPLA8  0.863017
# 38                                 DHRS2;CBR3;ALDH1B1  0.863017
# 39                                              TTC19  0.863017
# 40                                          ACP6;PISD  0.863017
# 41                                       MPV17L2;MTG2  0.890732
# 42  MARS2;HARS2;PARS2;IARS2;AARS2;SARS2;WARS2;LARS...  0.918205
# 43                                        DNM1L;MIEF2  0.918205
# 44                                         COQ3;PDSS1  0.918205
# 46    OCIAD2;PPTC7;MCRIP2;BLOC1S1;CSKMT;MACROD1;DELE1  0.943636
# 45                         ECHDC1;THEM4;LYPLAL1;ACOT2  0.943636
# 47                                    MECR;ACSF3;CBR4  0.947839

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statannotations.Annotator import Annotator

gene = 'UCP2'

plt.figure(figsize=(2, 2))
# Select data for batch 1 and H20 treatment
batch_1_seqids = metadata[metadata['Notes'].str.contains('batch 1')]['SeqID']
line_seqids = metadata[metadata['Treatment'] == 'H20']['SeqID']
common_seqids = np.intersect1d(batch_1_seqids, line_seqids)
counts_cpm_protein_coding_batch_1 = counts_cpm_protein_coding.loc[:, common_seqids]

# Create a DataFrame for gene ABCA7; assume gene names are in the index
x = pd.DataFrame(counts_cpm_protein_coding_batch_1.loc[gene])
x['SeqID'] = x.index

# Merge with metadata on 'SeqID'
merged = pd.merge(x, metadata, on='SeqID')

# Create a swarmplot of ABCA7 expression by Line
sns.boxplot(x='Line', y=gene, data=merged, hue='Line')
ax = sns.swarmplot(x='Line', y=gene, data=merged, hue='Line',
                   palette={'Control': 'grey', 'Y622': 'orange', 'G2': 'blue'})

# Define pairs to compare (adjust these as needed)
pairs = [('Control', 'Y622'), ('Control', 'G2')]
# Define the order of the groups; for example, if you want "Control", "Y622", then "G2"
order = ['Control', 'Y622', 'G2']

# Create and configure the Annotator
annotator = Annotator(ax, pairs, data=merged, x='Line', y=gene, order=order)
annotator.configure(test='t-test_ind', text_format='full', loc='outside',
                    verbose=2, show_test_name=False)
annotator.apply_and_annotate()

plt.legend([], [], frameon=False)
plt.show()
# Out:
# Control vs. Y622: t-test independent samples, P_val:8.154e-03 t=4.242e+00
# Control vs. G2: t-test independent samples, P_val:1.642e-01 t=1.629e+00
# /Users/djuna/Library/Python/3.9/lib/python/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/djuna/Library/Python/3.9/lib/python/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/djuna/Library/Python/3.9/lib/python/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
data2.loc[['UCP2']]
# Out:
#       genes     logFC   AveExpr         t   P.Value  adj.P.Val         B  \
# genes
# UCP2   UCP2  0.052862  2.455362  0.454185  0.655164   0.744864 -7.308195
#
#          score
# genes
# UCP2   0.18365

# %%
import pandas as pd
import numpy as np

data1 = pd.read_csv('../../bulkRNAseq/y622_degs.csv', index_col=0)
data2 = pd.read_csv('../../bulkRNAseq/choline_degs.csv', index_col=0)
data3 = pd.read_csv('../../bulkRNAseq/g2_degs.csv', index_col=0)

data1.head()
data2.head()
data1.index = data1['genes']
data2.index = data2['genes']
data3.index = data3['genes']
data1['score'] = -np.log10(data1['P.Value']) * np.sign(data1['logFC'])
data2['score'] = -np.log10(data2['P.Value']) * np.sign(data2['logFC'])
data3['score'] = -np.log10(data3['P.Value']) * np.sign(data3['logFC'])

# %%
pathways = np.load('../../processed_data/GO_Biological_Process_2023.npy', allow_pickle=True).item()

# %%
# List of keywords to look for
keywords = ['lipid', 'fatty', 'triglyceride', 'cholesterol', 'phosphatidyl']
#keywords = ['choline']
# Filter dictionary: check if any keyword is in the pathway name (case-sensitive)
filtered_pathways = {
    name: details
    for name, details in pathways.items()
    if any(keyword in name for keyword in keywords)
}

print(len(filtered_pathways))
#print(filtered_pathways)
# Out:
# 36

# %%
temp.iloc[0]['Lead_genes']
# Out:
# 'PLA2G3;PLPPR4;PCYT2;PLA2G4C;PNPLA3;ACP6;PLPPR5;PLPP6;PIP4P1;PLAAT3;PLPPR1;PLD2;PLB1;LIPG;PLPPR2;MBOAT2;FADS1;ABHD12;FDFT1;LCP1;PLCD1'

# %%
import statsmodels.stats.multitest as smm

data1['score'] = -np.log10(data1['P.Value']) * np.sign(data1['logFC'])
rnk = data1[['genes', 'score']].dropna()
rnk.columns = ['gene', 'score']
rnk = rnk.sort_values('score', ascending=False)

pre_res = gp.prerank(
    rnk=rnk,
    gene_sets=filtered_pathways,
    outdir="gseapy_out",
    permutation_num=1000,
    seed=6,
    min_size=5
)

temp = pre_res.res2d
p_values = temp['NOM p-val']
# Apply FDR correction (Benjamini-Hochberg method)
_, fdr_corrected_pvals, _, _ = smm.multipletests(p_values, alpha=0.05, method='fdr_bh')
temp['FDR'] = fdr_corrected_pvals

# extract leading edge genes
temp = pre_res.res2d
temp = temp.sort_values('FDR')
temp
# Out:
#        Name                                               Term        ES  \
# 0   prerank        Phospholipid Metabolic Process (GO:0006644) -0.689123
# 1   prerank  Glycerophospholipid Biosynthetic Process (GO:0... -0.519186
# 2   prerank      fatty-acyl-CoA Metabolic Process (GO:0035337) -0.687202
# 3   prerank        Glycerolipid Metabolic Process (GO:0046486) -0.755276
# 7   prerank  Glycerophospholipid Metabolic Process (GO:0006... -0.518867
# 4   prerank        Phospholipid Dephosphorylation (GO:0046839) -0.578275
# 5   prerank  Long-Chain fatty-acyl-CoA Metabolic Process (G... -0.630466
# 8   prerank                   Phospholipid Efflux (GO:0033700) -0.821441
# 6   prerank     Phospholipid Biosynthetic Process (GO:0008654) -0.576088
# 11  prerank                Phospholipid Transport (GO:0015914) -0.484681
# 9   prerank   fatty-acyl-CoA Biosynthetic Process (GO:0046949) -0.573577
# 13  prerank        Sphingolipid Metabolic Process (GO:0006665) -0.423598
# 10  prerank        Sphingolipid Catabolic Process (GO:0030149)  -0.61084
# 12  prerank  Long-Chain fatty-acyl-CoA Biosynthetic Process... -0.601037
# 14  prerank        Phospholipid Catabolic Process (GO:0009395) -0.558376
# 16  prerank     Sphingolipid Biosynthetic Process (GO:0030148) -0.411286
# 15  prerank  Positive Regulation Of Phospholipid Transport ... -0.670986
# 18  prerank       Glycolipid Biosynthetic Process (GO:0009247) -0.415749
# 17  prerank  N-acylphosphatidylethanolamine Metabolic Proce... -0.660794
# 19  prerank              Phospholipid Homeostasis (GO:0055091) -0.641741
# 20  prerank          Glycolipid Metabolic Process (GO:0006664) -0.419015
# 21  prerank        Glycerolipid Catabolic Process (GO:0046503) -0.513495
# 22  prerank            Phospholipid Translocation (GO:0045332) -0.407245
# 23  prerank   Glycosphingolipid Metabolic Process (GO:0006687) -0.353454
# 24  prerank           Aminophospholipid Transport (GO:0015917) -0.500332
# 25  prerank  Glycerophospholipid Catabolic Process (GO:0046... -0.350176
# 26  prerank   Glycosphingolipid Catabolic Process (GO:0046479) -0.414907
# 28  prerank  Regulation Of Phospholipid Metabolic Process (...  0.288357
# 27  prerank  Glycosphingolipid Biosynthetic Process (GO:000... -0.301544
# 29  prerank      fatty-acyl-CoA Catabolic Process (GO:0036115) -0.371964
#
#          NES NOM p-val FDR q-val FWER p-val  Tag %  Gene %  \
# 0  -2.043449       0.0       0.0        0.0  21/47  11.50%
# 1  -1.697767       0.0  0.035834      0.048  54/95  32.69%
# 2  -1.619694  0.010855   0.07034      0.128   6/15  10.17%
# 3  -1.589227  0.015873  0.075981      0.181    4/9   8.54%
# 7  -1.499875  0.013819  0.094893      0.406  11/43  11.75%
# 4  -1.580518  0.022667  0.069278      0.206  17/30  31.86%
# 5  -1.541386  0.021563  0.087593      0.296  13/19  31.92%
# 8  -1.495227  0.028302  0.087888      0.417    2/5   3.02%
# 6  -1.501731  0.036364  0.106932      0.402  12/23  24.40%
# 11 -1.418274  0.033835  0.128514      0.625  18/44  28.46%
# 9  -1.439883  0.041278  0.128205      0.565   8/21  19.67%
# 13 -1.348724  0.050286  0.188269      0.819  33/75  33.30%
# 10 -1.421209  0.065598  0.136337      0.613   7/13  24.87%
# 12 -1.396992  0.065642  0.138332      0.672   9/15  31.92%
# 14 -1.343847  0.107994  0.182265      0.832   5/16   6.94%
# 16 -1.266598  0.121749  0.264575      0.943  22/63  26.46%
# 15 -1.273565   0.16804  0.269913      0.934    2/6   3.02%
# 18 -1.189224  0.202581  0.356101       0.99   9/38  11.75%
# 17 -1.213021  0.223602  0.333562      0.982    2/5   7.73%
# 19 -1.161442   0.29653   0.38468      0.995    2/5   6.94%
# 20 -1.144187  0.281879  0.394422      0.995  16/27  37.34%
# 21 -1.139396  0.304654  0.384698      0.995   2/11   2.14%
# 27  ST3GAL5;ST6GALNAC5;B3GALT4;ST6GALNAC3;TM9SF2;S...  0.881064
# 29                                       FITM2;NUDT19  0.895735

# %%
import statsmodels.stats.multitest as smm

data2['score'] = -np.log10(data2['P.Value']) * np.sign(data2['logFC'])
rnk = data2[['genes', 'score']].dropna()
rnk.columns = ['gene', 'score']
rnk = rnk.sort_values('score', ascending=False)

pre_res = gp.prerank(
    rnk=rnk,
    gene_sets=filtered_pathways,
    outdir="gseapy_out",
    permutation_num=1000,
    seed=6,
    min_size=5
)

temp = pre_res.res2d
p_values = temp['NOM p-val']
# Apply FDR correction (Benjamini-Hochberg method)
_, fdr_corrected_pvals, _, _ = smm.multipletests(p_values, alpha=0.05, method='fdr_bh')
temp['FDR'] = fdr_corrected_pvals

# extract leading edge genes
temp = pre_res.res2d
temp = temp.sort_values('FDR')

# %%
temp
# Out:
#        Name                                               Term        ES  \
# 0   prerank          Glycolipid Metabolic Process (GO:0006664)  0.652819
# 1   prerank      fatty-acyl-CoA Metabolic Process (GO:0035337)  0.714978
# 3   prerank  Glycerophospholipid Biosynthetic Process (GO:0...  0.472155
# 2   prerank        Phospholipid Metabolic Process (GO:0006644)  0.542492
# 6   prerank           Aminophospholipid Transport (GO:0015917)  0.785798
# 7   prerank                Phospholipid Transport (GO:0015914)   0.47077
# 4   prerank            Phospholipid Translocation (GO:0045332)  0.562864
# 5   prerank        Phospholipid Catabolic Process (GO:0009395)  0.598924
# 8   prerank              Phospholipid Homeostasis (GO:0055091)  0.766057
# 9   prerank  Long-Chain fatty-acyl-CoA Metabolic Process (G...  0.538692
# 10  prerank   Glycosphingolipid Metabolic Process (GO:0006687)  0.501073
# 11  prerank  Glycosphingolipid Biosynthetic Process (GO:000...  0.558289
# 12  prerank  N-acylphosphatidylethanolamine Metabolic Proce...  0.687965
# 13  prerank     Phospholipid Biosynthetic Process (GO:0008654)   0.44756
# 14  prerank  Glycerophospholipid Catabolic Process (GO:0046...  0.475488
# 15  prerank        Glycerolipid Metabolic Process (GO:0046486)  0.509017
# 16  prerank        Sphingolipid Metabolic Process (GO:0006665)  0.316967
# 17  prerank        Phospholipid Dephosphorylation (GO:0046839)  0.365112
# 18  prerank  Glycerophospholipid Metabolic Process (GO:0006...  0.344705
# 19  prerank                   Phospholipid Efflux (GO:0033700)  0.542109
# 20  prerank       Glycolipid Biosynthetic Process (GO:0009247)  0.331215
# 21  prerank        Sphingolipid Catabolic Process (GO:0030149) -0.348439
# 22  prerank        Glycerolipid Catabolic Process (GO:0046503)  0.403892
# 23  prerank  Long-Chain fatty-acyl-CoA Biosynthetic Process...  0.359611
# 24  prerank   fatty-acyl-CoA Biosynthetic Process (GO:0046949)  0.329076
# 25  prerank  Positive Regulation Of Phospholipid Transport ...  0.402858
# 27  prerank      fatty-acyl-CoA Catabolic Process (GO:0036115)  0.389916
# 28  prerank   Glycosphingolipid Catabolic Process (GO:0046479) -0.334291
# 26  prerank     Sphingolipid Biosynthetic Process (GO:0030148)  0.223917
# 29  prerank  Regulation Of Phospholipid Metabolic Process (...  0.311441
#
#          NES NOM p-val FDR q-val FWER p-val  Tag %  Gene %  \
# 
# 13   SRD5A3;FAR1;PCYT2;LPCAT1;IDI1;SGMS1;AGPAT5;SPHK2  0.492154
# 14  OCRL;ENPP2;GPCPD1;PNPLA6;PLA2G7;SMPD4;PLA2G6;P...  0.563504
# 15                      DGKB;DGKQ;GAL3ST1;DGKZ;PNPLA3  0.736648
# 16  UGCG;PPM1L;HACD1;ENPP2;B4GALNT1;TEX2;ELOVL5;CE...  0.736648
# 17  PLPPR4;OCRL;PLPPR2;INPP5J;MTMR3;PLPP6;SGPP1;PL...  0.736648
# 18  PLCD1;PIGZ;ACP6;FAR1;PLCB1;PAFAH1B1;PLAAT1;GPC...  0.769447
# 19                            ABCA7;APOE;ABCA12;APOC1   0.78772
# 20    TP53INP2;PIGZ;ST6GALNAC5;B3GNT5;ST8SIA3;B4GALT6   0.78772
# 21                                    SGPL1;GLA;SMPD3   0.78772
# 22  MGLL;GPCPD1;PNPLA6;ABHD2;SMPD4;LYPLA2;PLA2G4C;...  0.817594
# 23                        ACSL4;HSD17B12;HACD1;ELOVL5  0.858128
# 24                ACSL4;HSD17B12;HACD1;ELOVL5;SLC25A1  0.863861
# 25                                      TMEM30A;ABCA7  0.916567
# 27                                        FITM2;NUDT8  0.916567
# 28                                                GLA  0.916567
# 26  ST6GALNAC5;PPM1L;HACD1;ST8SIA3;ELOVL5;TLCD3B;K...   0.93401
# 29          MTMR3;MTMR4;MTMR9;MTMR2;MTMR1;MFSD2A;PHB2   0.93401

# %%
temp.iloc[1]['Lead_genes']
# Out:
# 'PLCG2;PCYT2;PLA2G4C;PNPLA3;PITPNM1;ACP6;GPAT2;LPCAT3;FAR1;INPP4B;PLD2;ETNK2;INPP5J;DGKB;PI4K2B;PI4K2A;MBOAT2;DGKQ;FIG4;INPPL1;PI4KB;ABHD4;MTMR14;SACM1L;MTMR4;CDS1;SLC44A2;SFI1;AGPAT5;IMPA1;GPAT4;MTMR1;VAC14;MBOAT7;ETNK1;PTDSS2;PMPCA;CLN3;MTMR7;PITPNM2;AGPAT2;SLC27A1;ABHD5;MTMR6;MTMR2;DGKE;INPP5K;CHKB;DGKG;MFSD2A;PIP5K1A;MTMR3;GNPAT;CHAT'

# %%
temp
# Out:
#        Name                                               Term        ES  \
# 0   prerank        Phospholipid Metabolic Process (GO:0006644) -0.689123
# 1   prerank  Glycerophospholipid Biosynthetic Process (GO:0... -0.519186
# 2   prerank      fatty-acyl-CoA Metabolic Process (GO:0035337) -0.687202
# 3   prerank        Glycerolipid Metabolic Process (GO:0046486) -0.755276
# 7   prerank  Glycerophospholipid Metabolic Process (GO:0006... -0.518867
# 4   prerank        Phospholipid Dephosphorylation (GO:0046839) -0.578275
# 5   prerank  Long-Chain fatty-acyl-CoA Metabolic Process (G... -0.630466
# 8   prerank                   Phospholipid Efflux (GO:0033700) -0.821441
# 6   prerank     Phospholipid Biosynthetic Process (GO:0008654) -0.576088
# 11  prerank                Phospholipid Transport (GO:0015914) -0.484681
# 9   prerank   fatty-acyl-CoA Biosynthetic Process (GO:0046949) -0.573577
# 13  prerank        Sphingolipid Metabolic Process (GO:0006665) -0.423598
# 10  prerank        Sphingolipid Catabolic Process (GO:0030149)  -0.61084
# 12  prerank  Long-Chain fatty-acyl-CoA Biosynthetic Process... -0.601037
# 14  prerank        Phospholipid Catabolic Process (GO:0009395) -0.558376
# 16  prerank     Sphingolipid Biosynthetic Process (GO:0030148) -0.411286
# 15  prerank  Positive Regulation Of Phospholipid Transport ... -0.670986
# 18  prerank       Glycolipid Biosynthetic Process (GO:0009247) -0.415749
# 17  prerank  N-acylphosphatidylethanolamine Metabolic Proce... -0.660794
# 19  prerank              Phospholipid Homeostasis (GO:0055091) -0.641741
# 20  prerank          Glycolipid Metabolic Process (GO:0006664) -0.419015
# 21  prerank        Glycerolipid Catabolic Process (GO:0046503) -0.513495
# 22  prerank            Phospholipid Translocation (GO:0045332) -0.407245
# 23  prerank   Glycosphingolipid Metabolic Process (GO:0006687) -0.353454
# 24  prerank           Aminophospholipid Transport (GO:0015917) -0.500332
# 25  prerank  Glycerophospholipid Catabolic Process (GO:0046... -0.350176
# 26  prerank   Glycosphingolipid Catabolic Process (GO:0046479) -0.414907
# 28  prerank  Regulation Of Phospholipid Metabolic Process (...  0.288357
# 27  prerank  Glycosphingolipid Biosynthetic Process (GO:000... -0.301544
# 29  prerank      fatty-acyl-CoA Catabolic Process (GO:0036115) -0.371964
#
#          NES NOM p-val FDR q-val FWER p-val  Tag %  Gene %  \
# 0  -2.043449       0.0       0.0        0.0  21/47  11.50%
# 1  -1.697767       0.0  0.035834      0.048  54/95  32.69%
# 2  -1.619694  0.010855   0.07034      0.128   6/15  10.17%
# 3  -1.589227  0.015873  0.075981      0.181    4/9   8.54%
# 7  -1.499875  0.013819  0.094893      0.406  11/43  11.75%
# 4  -1.580518  0.022667  0.069278      0.206  17/30  31.86%
# 5  -1.541386  0.021563  0.087593      0.296  13/19  31.92%
# 8  -1.495227  0.028302  0.087888      0.417    2/5   3.02%
# 6  -1.501731  0.036364  0.106932      0.402  12/23  24.40%
# 11 -1.418274  0.033835  0.128514      0.625  18/44  28.46%
# 9  -1.439883  0.041278  0.128205      0.565   8/21  19.67%
# 13 -1.348724  0.050286  0.188269      0.819  33/75  33.30%
# 10 -1.421209  0.065598  0.136337      0.613   7/13  24.87%
# 12 -1.396992  0.065642  0.138332      0.672   9/15  31.92%
# 14 -1.343847  0.107994  0.182265      0.832   5/16   6.94%
# 16 -1.266598  0.121749  0.264575      0.943  22/63  26.46%
# 15 -1.273565   0.16804  0.269913      0.934    2/6   3.02%
# 18 -1.189224  0.202581  0.356101       0.99   9/38  11.75%
# 17 -1.213021  0.223602  0.333562      0.982    2/5   7.73%
# 19 -1.161442   0.29653   0.38468      0.995    2/5   6.94%
# 20 -1.144187  0.281879  0.394422      0.995  16/27  37.34%
# 21 -1.139396  0.304654  0.384698      0.995   2/11   2.14%
# 22 -1.028894  0.450667  0.557527        1.0  10/20  31.44%
# 23 -0.951521  0.549669  0.671272        1.0  15/27  37.84%
# 24  -0.90709   0.64127  0.723733        1.0    2/5  28.07%
# 25 -0.834915  0.694168  0.802734        1.0   6/15  28.92%
# 26 -0.791395  0.790977  0.833316        1.0    3/6  37.84%
# 28  0.698209  0.817308  0.880231      0.998    2/9   8.10%
# 27 -0.723677  0.851695  0.886739        1.0   8/16  34.93%
# 29 -0.669927  0.895735  0.908471        1.0    2/5  43.35%
#
#                                            Lead_genes       FDR
# 0   PLA2G3;PLPPR4;PCYT2;PLA2G4C;PNPLA3;ACP6;PLPPR5...       0.0
# 1   PLCG2;PCYT2;PLA2G4C;PNPLA3;PITPNM1;ACP6;GPAT2;...       0.0
# 2                  FAR2;ACSL3;SLC25A1;FAR1;DGAT2;PPT1  0.095238
# 3                            PNPLA3;GAL3ST1;DGKB;DGKQ  0.095238
# 7   PLA2G3;PLA2G4C;PNPLA3;ACP6;PIGZ;FAR1;ABHD3;ABH...  0.095238
# 4   PLPPR4;PLPPR5;PLPP6;PIP4P1;PLPPR1;INPP5J;PLPPR...  0.097143
# 5   FAR2;ACSL3;FAR1;HACD1;ELOVL1;DGAT2;ELOVL5;HACD...  0.097143
# 8                                          APOE;ABCA7  0.106132
# 6   PCYT2;IDI1;FAR1;DHDDS;SRD5A3;FADS1;FDPS;AGPAT5...  0.109091
# 11  PITPNM1;LDLR;ABCB1;APOE;ABCA7;ATP8B3;SCARB1;TM...  0.109091
# 9   ACSL3;SLC25A1;HACD1;ELOVL1;PPT1;ELOVL5;HACD2;A...  0.112577
# 13  SPTSSB;GAL3ST1;CERS2;HACD1;ELOVL1;CSNK1G2;PPT1...  0.125714
# 10         SMPDL3A;PPT1;ACER3;ASAH1;SGPL1;ENPP2;SMPD4  0.140662
# 12  ACSL3;HACD1;ELOVL1;ELOVL5;HACD2;ACSL4;ELOVL6;E...  0.140662
# 14                    PLA2G4C;PLPP6;SMPDL3A;PLD2;LIPG  0.215989
# 16  SPTSSB;CERS2;HACD1;ELOVL1;CSNK1G2;ST3GAL5;ST6G...   0.22828
# 15                                         APOE;ABCA7   0.29654
# 18  PGF;PIGZ;TP53INP2;PIGQ;ST3GAL5;ST6GALNAC5;PIGN...  0.337634
# 17                                        PLAAT3;NAAA  0.353057
# 19                                         FABP3;LIPG  0.415438
# 20  B3GALNT1;GBA2;PGAP3;GLB1;NAGA;FUCA1;NEU3;GALC;...  0.415438
# 21                                       PLA2G4C;MGLL  0.415438
# 22  ABCB1;ABCA7;ATP8B3;TMEM30B;ATP8B2;ATP10D;ATP11...  0.587826
# 23  ST3GAL5;ST6GALNAC5;B3GALNT1;GBA2;GLB1;NEU3;GAL...  0.687086
# 24                                     TMEM30B;ATP8A2  0.769524
# 25          PLA2G4C;PNPLA8;ENPP2;SMPD4;PNPLA6;ABHD16A  0.800963
# 26                                      NEU1;NEU3;GLA  0.875687
# 28                                       DNAJC19;PHB2  0.875687
# 27  ST3GAL5;ST6GALNAC5;B3GALT4;ST6GALNAC3;TM9SF2;S...  0.881064
# 29                                       FITM2;NUDT19  0.895735

# %% [markdown]
# ### Below is scrap

# %%
genes_all = [[ 'MICAL1', 'MICAL3', 'MICAL2', 'MICU1', 'MICALL2', 'MICU2', 'MICALL1', 'MICU3', 'MICOS10', 'MICOS13'],
    ['DRP1', 'GDAP1', 'INF2', 'MFF', 'MFN2', 'MFN1', 'OPA1'],
    [ 'APOE', 'APOD', 'APOO', 'APOLD1', 'APOM', 'APOL2', 'APOC1', 'APOOL'],
    [ 'ABCA7', 'ABCA5', 'ABCA1', 'ABCA10', 'ABCA6', 'ABCA2', 'ABCA3', 'ABCA12'],
    ['SLC44A2', 'SLC44A1', 'SLC44A3', 'SLC44A5'],
    ['SCD', 'SCD5', 'FADS1', 'FADS2', 'FADS3', 'ELOVL2', 'ELOVL5', 'ACSL'],
['CHKA', 'CHKB', 'PCYT1A', 'PCYT1B', 'CHPT1', 'CEPT1', 'PEMT', 'LPCAT1', 'LPCAT2', 'LPCAT3', 'LPCAT4'],
['ACADM', 'ACADVL', 'ACADL', 'CPT1A', 'CPT1B', 'CPT2', 'SLC25A20', 'HADHA', 'HADHB', 'ACAA2', 'ECHS1', 'ETFA', 'ETFB', 'ETFDH'],
['HK1', 'HK2', 'HK3', 'GCK', 'PGI', 'PFKL', 'PFKM', 'PFKP', 'ALDOA', 'ALDOB', 'ALDOC', 'GAPDH', 'PGK1', 'PGAM1', 'PGAM2', 'ENO1', 'ENO2', 'ENO3', 'PKM', 'PKLR'],
['DGAT1', 'DGAT2', 'GPAT1', 'GPAT2', 'GPAT3', 'GPAT4', 'AGPAT1', 'AGPAT2', 'LPIN1', 'LPIN2', 'LPIN3', 'MGLL', 'PNPLA2', 'PNPLA3', 'LPL', 'APOB', 'MTTP', 'ANGPTL3', 'ANGPTL4', 'ANGPTL8', 'CETP', 'FABP1', 'FABP2', 'FABP3']]

# %%
genes = genes_all[5]
x = data1.loc[np.array(genes)[[g in data1.index for g in genes]]][['score']]
y = data2.loc[np.array(genes)[[g in data2.index for g in genes]]][['score']]

# %%
merged_data
# Out:
#            Y622   Choline
# genes
# GDAP1 -0.864304  0.233449
# INF2  -3.898009  0.584116
# MFF    1.250986  0.244463
# MFN2  -2.204852  2.681944
# MFN1  -1.952015  2.809985
# OPA1  -0.330525  2.953759

# %%
merged_data = pd.merge(x, y, left_index=True, right_index=True)
merged_data.columns = ['Y622', 'Choline']

plt.figure(figsize=(6, 4))
bar_width = 0.35
x_pos = np.arange(len(merged_data.index))

plt.bar(x_pos - bar_width/2, merged_data['Y622'], bar_width, label='Y622', color='lightblue')
plt.bar(x_pos + bar_width/2, merged_data['Choline'], bar_width, label='Choline', color='lightgreen')

plt.xticks(x_pos, merged_data.index, rotation=45, ha='right')
plt.ylabel('Score')
plt.title('Gene Scores Comparison')
plt.legend()
plt.tight_layout()
plt.show()

# %%
data1.loc[]
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Cell In[426], line 1
# ----> 1 data1.loc['SCD', 'SCD5', 'FADS1', 'FADS2', 'FADS3', 'ELOVL2', 'ELOVL5', 'ACSL']
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/indexing.py:1371, in _LocIndexer._getitem_tuple(self, tup)
#    1368     return self._getitem_lowerdim(tup)
#    1370 # no multi-index, so validate all of the indexers
# -> 1371 tup = self._validate_tuple_indexer(tup)
#    1373 # ugly hack for GH #836
#    1374 if self._multi_take_opportunity(tup):
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/indexing.py:962, in _LocationIndexer._validate_tuple_indexer(self, key)
#     957 @final
#     958 def _validate_tuple_indexer(self, key: tuple) -> tuple:
#     959     """
#     960     Check the key for valid keys across my indexer.
#     961     """
# --> 962     key = self._validate_key_length(key)
#     963     key = self._expand_ellipsis(key)
#     964     for i, k in enumerate(key):
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/indexing.py:1001, in _LocationIndexer._validate_key_length(self, key)
#     999             raise IndexingError(_one_ellipsis_message)
#    1000         return self._validate_key_length(key)
# -> 1001     raise IndexingError("Too many indexers")
#    1002 return key
#
# IndexingError: Too many indexers

# %%
data1[data1.index.str.startswith('MIC')]['genes']
# Out:
# genes
# MICAL1      MICAL1
# MICAL3      MICAL3
# MICAL2      MICAL2
# MICU1        MICU1
# MICALL2    MICALL2
# MICU2        MICU2
# MICALL1    MICALL1
# MICU3        MICU3
# MICOS10    MICOS10
# MICOS13    MICOS13
# Name: genes, dtype: object

# %%
data3.loc[['MFN1', 'MFN2', 'DNM1L']]
# Out:
#        genes     logFC   AveExpr         t   P.Value  adj.P.Val         B  \
# genes
# MFN1    MFN1 -0.247719  4.203945 -1.351608  0.202624   0.539102 -6.212386
# MFN2    MFN2 -0.401164  6.428368 -1.833382  0.092878   0.422158 -5.723536
# DNM1L  DNM1L -0.297898  7.539003 -1.607936  0.135080   0.473897 -6.111154
#
#           score
# genes
# MFN1  -0.693310
# MFN2  -1.032085
# DNM1L -0.869407

# %%
data1.loc[['CHKA', 'CHKB', 'PCYT1B', 'CEPT1', 'PEMT', 'LPCAT1', 'LPCAT2', 'LPCAT3', 'LPCAT4']]
# Out:
#          genes     logFC   AveExpr         t   P.Value  adj.P.Val         B
# genes
# CHKA      CHKA -0.041077  5.926654 -0.388762  0.703993   0.822314 -7.593317
# CHKB      CHKB -0.462188 -0.179943 -1.563658  0.142850   0.315926 -5.322544
# PCYT1B  PCYT1B  0.004241  5.138743  0.035358  0.972353   0.985371 -7.592860
# CEPT1    CEPT1  0.113672  4.511640  0.898632  0.385831   0.576184 -7.083543
# PEMT      PEMT  0.202663  5.557004  1.671607  0.119429   0.281174 -6.272126
# LPCAT1  LPCAT1 -0.003767  6.066344 -0.032053  0.974936   0.987078 -7.684035
# LPCAT2  LPCAT2 -0.293837  0.944482 -1.271889  0.226566   0.415813 -5.970962
# LPCAT3  LPCAT3 -0.536861  3.753375 -4.156753  0.001222   0.018498 -1.599943
# LPCAT4  LPCAT4 -0.283146  4.992760 -2.789747  0.015816   0.082526 -4.332430

# %%
pathways = np.load('../../processed_data/all_paths.npy', allow_pickle=True).item()

# %%
# Load specific tab from Excel file
data2 = pd.read_excel('../../../../Downloads/Human.MitoCarta3.0.xls', sheet_name='C MitoPathways')

# %%
data2 = data2.dropna()

# %%
data2['MitoPathway']
# Out:
# 0      Mitochondrial central dogma
# 1                mtDNA maintenance
# 2                mtDNA replication
# 3                   mtDNA nucleoid
# 4                     mtDNA repair
#                   ...
# 144                      Mitophagy
# 145                      Autophagy
# 146                      Apoptosis
# 147              Cristae formation
# 148                  MICOS complex
# Name: MitoPathway, Length: 148, dtype: object

# %%
dictionary = dict(zip(data2['MitoPathway'], [x.split(', ') for x in data2['Genes']]))

# %%
# Define lipid-related keywords
lipid_keywords = ['phospholipid']

# Filter pathways dictionary to only keep lipid-related pathways
lipid_pathways = {}
for pathway_name, genes in pathways.items():
    if any(keyword.lower() in pathway_name.lower() for keyword in lipid_keywords):
        lipid_pathways[pathway_name] = genes

print(f"Found {len(lipid_pathways)} lipid-related pathways out of {len(pathways)} total pathways")
#lipid_pathways
# Out:
# Found 17 lipid-related pathways out of 5406 total pathways

# %%
# Convert pathways into a list of lists
pathway_lists = [
    ['SCD', 'SCD5', 'FADS1', 'FADS2', 'FADS3', 'ELOVL2', 'ELOVL5', 'ACSL'],
    ['CHKA', 'CHKB', 'PCYT1A', 'PCYT1B', 'CHPT1', 'CEPT1', 'PEMT', 'LPCAT1', 'LPCAT2', 'LPCAT3', 'LPCAT4'],
    ['ACADM', 'ACADVL', 'ACADL', 'CPT1A', 'CPT1B', 'CPT2', 'SLC25A20', 'HADHA', 'HADHB', 'ACAA2', 'ECHS1', 'ETFA', 'ETFB', 'ETFDH'],
    ['HK1', 'HK2', 'HK3', 'GCK', 'PGI', 'PFKL', 'PFKM', 'PFKP', 'ALDOA', 'ALDOB', 'ALDOC', 'GAPDH', 'PGK1', 'PGAM1', 'PGAM2', 'ENO1', 'ENO2', 'ENO3', 'PKM', 'PKLR'],
    ['DGAT1', 'DGAT2', 'GPAT1', 'GPAT2', 'GPAT3', 'GPAT4', 'AGPAT1', 'AGPAT2', 'LPIN1', 'LPIN2', 'LPIN3', 'MGLL', 'PNPLA2', 'PNPLA3', 'LPL', 'APOB', 'MTTP', 'ANGPTL3', 'ANGPTL4', 'ANGPTL8', 'CETP', 'FABP1', 'FABP2', 'FABP3']
]

# Create descriptive names for each pathway
pathway_names = [
    'Fatty Acid Desaturation and Elongation',
    'Phosphatidylcholine Synthesis',
    'Fatty Acid Beta Oxidation',
    'Glycolysis',
    'Triglyceride Synthesis and Transport'
]

# Create dictionary mapping pathway names to gene lists
pathway_dict = dict(zip(pathway_names, pathway_lists))

# %%
data1 = data2

# %%
import numpy as np
import pandas as pd
import gseapy as gp
data1 = data2
data1['score'] = -np.log10(data1['P.Value']) * np.sign(data1['logFC'])
rnk = data1[['genes', 'score']].dropna()
rnk.columns = ['gene', 'score']
rnk = rnk.sort_values('score', ascending=False)

pre_res = gp.prerank(
    rnk=rnk,
    gene_sets=dictionary,
    outdir="gseapy_out",
    permutation_num=1000,  # For more robust results, increase this number.
    seed=6,
    min_size=5
)

# %%
# Get results from prerank analysis
temp = pre_res.res2d
import numpy as np
import statsmodels.stats.multitest as smm

# Example list of raw p-values
p_values = temp['NOM p-val']

# Apply FDR correction (Benjamini-Hochberg method)
_, fdr_corrected_pvals, _, _ = smm.multipletests(p_values, alpha=0.05, method='fdr_bh')

temp['FDR'] = fdr_corrected_pvals

# %%
temp = pre_res.res2d
# Sort by FDR q-value (NES_FDR column)
temp = temp.sort_values('FDR')
temp[temp['FDR']<0.1]
# Out:
#        Name                                     Term        ES       NES  \
# 0   prerank                   Mitochondrial ribosome -0.682621 -2.651795
# 16  prerank                 Fe-S-containing proteins  -0.55334 -1.752714
# 15  prerank                         mtRNA metabolism -0.452224  -1.75877
# 24  prerank  Protein import, sorting and homeostasis -0.423449 -1.624241
# 10  prerank                               Complex IV -0.530123 -1.829728
# 8   prerank                     CIV assembly factors -0.601559 -1.889221
# 18  prerank                                Complex I -0.466114 -1.722353
# 5   prerank                  OXPHOS assembly factors -0.563531 -2.103653
# 4   prerank                          OXPHOS subunits -0.536685 -2.159261
# 3   prerank                              Translation -0.541686 -2.268644
# 2   prerank                                   OXPHOS -0.531723 -2.275808
# 1   prerank              Mitochondrial central dogma -0.514889 -2.309188
# 6   prerank                              Complex III -0.763126 -2.065633
# 7   prerank                            CIII subunits  -0.83168 -1.960696
# 9   prerank                                Complex V -0.615802 -1.870357
# 13  prerank               Protein import and sorting -0.512821 -1.788656
# 14  prerank                      Preprotein cleavage -0.816067 -1.776579
# 19  prerank                              CV subunits -0.593496 -1.719289
# 11  prerank                    mt-rRNA modifications -0.641765  -1.80926
# 28  prerank                              CI subunits -0.441502 -1.540641
# 12  prerank                           mtRNA granules -0.570177 -1.808445
# 17  prerank                      Translation factors -0.655438  -1.73186
# 21  prerank                            MICOS complex -0.779619 -1.689038
# 23  prerank                        Electron carriers -0.654226 -1.646129
# 22  prerank                Fe-S cluster biosynthesis -0.545805 -1.662361
# 20  prerank                TIM23 presequence pathway  -0.82277 -1.709278
# 27  prerank                      CI assembly factors -0.527358 -1.571859
#
#    NOM p-val FDR q-val FWER p-val    Tag %  Gene %  \
# 0        0.0       0.0        0.0    48/81  18.38%
# 16       0.0  0.024871       0.19    13/30  20.74%
# 15       0.0  0.024563      0.179    28/76  19.28%
# 24       0.0  0.053121      0.486    23/82  14.09%
# 10       0.0   0.01761       0.09    27/46  23.24%
# 8        0.0  0.010555      0.047    15/30  19.84%
# 18       0.0  0.030292      0.257    43/66  25.05%
# 5        0.0  0.000931      0.003    36/68  19.84%
# 4        0.0  0.000373      0.001    43/95  16.84%
# 3        0.0  0.000466      0.001   74/151  21.16%
# 2        0.0  0.000621      0.001  101/162  25.31%
# 1        0.0       0.0        0.0   97/226  20.59%
# 6        0.0   0.00133      0.005     9/16  16.69%
# 7   0.002874  0.004889       0.02     5/10   7.15%
# 9   0.003484  0.012107      0.058    10/24  15.09%
# 13  0.004082  0.020488      0.132    18/46  15.14%
# 14  0.005362   0.02173       0.15      2/8   9.91%
# 19  0.006515  0.029708      0.262    11/19  25.31%
# 11  0.006349  0.021109      0.118     6/18   9.42%
# 28  0.007547  0.087477      0.724    28/44  24.79%
# 12  0.007326  0.019772      0.119    17/28  21.69%
# 17  0.008646  0.028767      0.234     8/15  21.16%
# 21  0.011173  0.035728      0.333      3/7  12.40%
# 23  0.012085  0.047186      0.432     3/12   8.00%
# 22  0.014035  0.043082      0.393     9/23  19.83%
# 20  0.015504  0.030866      0.281      5/6  15.14%
# 27  0.015432  0.072774       0.63    16/22  26.55%
#
#                                            Lead_genes       FDR
# 0   MRPL16;MRPL37;MRPL14;MRPL15;MRPS7;MRPS18A;MRPL...       0.0
# 16  UQCRFS1;ISCA2;SDHB;ISCU;NDUFV1;NDUFS2;NTHL1;LI...       0.0
# 15  MTPAP;TEFM;MTERF1;TRUB2;MRPS7;TFB1M;MRM3;RMND1...       0.0
# 24  CASP3;TIMM21;OMA1;TIMM17B;UQCRC1;TIMM23;TOMM5;...       0.0
# 10  COX7A2;TIMM21;COX16;COX6A1;COA7;COA3;COA6;COX7...       0.0
# 8   TIMM21;COX16;COA7;COA3;COA6;COX14;SURF1;CMC2;C...       0.0
# 18  NDUFB8;NDUFA12;FOXRED1;NDUFA6;NDUFA1;MT-ND4L;N...       0.0
# 5   TIMM21;COX16;FOXRED1;BCS1L;COA7;COA3;RAB5IF;CO...       0.0
# 4   UQCRFS1;COX7A2;NDUFB8;UQCRC1;UQCR10;NDUFA12;CO...       0.0
# 3   MTERF3;TIMM21;MRPL16;MRPL37;MRPL14;MRPL15;MRPS...       0.0
# 2   UQCRFS1;COX7A2;NDUFB8;TIMM21;UQCRC1;UQCR10;COX...       0.0
# 1   MTPAP;TEFM;MTERF3;TIMM21;MRPL16;MTERF1;MRPL37;...       0.0
# 6   UQCRFS1;UQCRC1;UQCR10;CYC1;BCS1L;UQCRH;UQCR11;...       0.0
# 7                    UQCRFS1;UQCRC1;UQCR10;CYC1;UQCRH  0.022373
# 9   ATP5F1C;ATP5IF1;ATP5MG;FMC1;ATP5PB;ATP5F1A;TME...  0.025319
# 13  TIMM21;TIMM17B;UQCRC1;TIMM23;TOMM5;MTX1;TIMM8A...  0.027806
# 14                                       UQCRC1;PMPCA  0.034379
# 19  ATP5F1C;ATP5IF1;ATP5MG;ATP5PB;ATP5F1A;ATP5PF;A...  0.037374
# 11                 MTPAP;TRUB2;TFB1M;MRM3;NGRN;METTL5  0.037374
# 28  NDUFB8;NDUFA12;NDUFA6;NDUFA1;MT-ND4L;NDUFS4;ND...  0.039173
# 12  MTPAP;TRUB2;MRPS7;TFB1M;RMND1;ERAL1;TRMT10C;MR...  0.039173
# 17       TIMM21;COA3;MTIF3;COX14;TSFM;MTRF1;MRRF;GFM2  0.042835
# 21                                  APOOL;APOO;CHCHD3  0.052951
# 23                                   ETFA;CYC1;ETFRF1  0.054884
# 22  ISCA2;GRPEL1;ISCU;FXN;NDUFAB1;BOLA1;GLRX5;BOLA...  0.061193
# 20               TIMM21;TIMM17B;TIMM23;TIMM50;TIMM17A   0.06259
# 27  FOXRED1;NDUFAF6;TIMMDC1;NDUFAF1;LYRM2;TMEM70;N...   0.06259

# %%
temp = pre_res.res2d
# Sort by FDR q-value (NES_FDR column)
temp = temp.sort_values('FDR')
temp[temp['NOM p-val']<0.05]
# Out:
#        Name                                     Term        ES       NES  \
# 0   prerank                   Mitochondrial ribosome -0.682621 -2.651795
# 16  prerank                 Fe-S-containing proteins  -0.55334 -1.752714
# 15  prerank                         mtRNA metabolism -0.452224  -1.75877
# 24  prerank  Protein import, sorting and homeostasis -0.423449 -1.624241
# 10  prerank                               Complex IV -0.530123 -1.829728
# 8   prerank                     CIV assembly factors -0.601559 -1.889221
# 18  prerank                                Complex I -0.466114 -1.722353
# 5   prerank                  OXPHOS assembly factors -0.563531 -2.103653
# 4   prerank                          OXPHOS subunits -0.536685 -2.159261
# 3   prerank                              Translation -0.541686 -2.268644
# 2   prerank                                   OXPHOS -0.531723 -2.275808
# 1   prerank              Mitochondrial central dogma -0.514889 -2.309188
# 6   prerank                              Complex III -0.763126 -2.065633
# 7   prerank                            CIII subunits  -0.83168 -1.960696
# 9   prerank                                Complex V -0.615802 -1.870357
# 13  prerank               Protein import and sorting -0.512821 -1.788656
# 14  prerank                      Preprotein cleavage -0.816067 -1.776579
# 19  prerank                              CV subunits -0.593496 -1.719289
# 11  prerank                    mt-rRNA modifications -0.641765  -1.80926
# 28  prerank                              CI subunits -0.441502 -1.540641
# 12  prerank                           mtRNA granules -0.570177 -1.808445
# 17  prerank                      Translation factors -0.655438  -1.73186
# 21  prerank                            MICOS complex -0.779619 -1.689038
# 23  prerank                        Electron carriers -0.654226 -1.646129
# 22  prerank                Fe-S cluster biosynthesis -0.545805 -1.662361
# 20  prerank                TIM23 presequence pathway  -0.82277 -1.709278
# 27  prerank                      CI assembly factors -0.527358 -1.571859
# 40  prerank  Mitochondrial dynamics and surveillance -0.335028 -1.325002
# 31  prerank                    mt-tRNA modifications -0.510282 -1.498918
# 33  prerank                         ABC transporters   0.76142  1.472211
# 25  prerank                            Transcription -0.704477 -1.617536
# 29  prerank                         EF hand proteins  0.680283  1.527819
#
#    NOM p-val FDR q-val FWER p-val    Tag %  Gene %  \
# 0        0.0       0.0        0.0    48/81  18.38%
# 16       0.0  0.024871       0.19    13/30  20.74%
# 15       0.0  0.024563      0.179    28/76  19.28%
# 24       0.0  0.053121      0.486    23/82  14.09%
# 10       0.0   0.01761       0.09    27/46  23.24%
# 8        0.0  0.010555      0.047    15/30  19.84%
# 18       0.0  0.030292      0.257    43/66  25.05%
# 5        0.0  0.000931      0.003    36/68  19.84%
# 4        0.0  0.000373      0.001    43/95  16.84%
# 3        0.0  0.000466      0.001   74/151  21.16%
# 2        0.0  0.000621      0.001  101/162  25.31%
# 1        0.0       0.0        0.0   97/226  20.59%
# 6        0.0   0.00133      0.005     9/16  16.69%
# 7   0.002874  0.004889       0.02     5/10   7.15%
# 9   0.003484  0.012107      0.058    10/24  15.09%
# 13  0.004082  0.020488      0.132    18/46  15.14%
# 14  0.005362   0.02173       0.15      2/8   9.91%
# 19  0.006515  0.029708      0.262    11/19  25.31%
# 11  0.006349  0.021109      0.118     6/18   9.42%
# 28  0.007547  0.087477      0.724    28/44  24.79%
# 12  0.007326  0.019772      0.119    17/28  21.69%
# 17  0.008646  0.028767      0.234     8/15  21.16%
# 21  0.011173  0.035728      0.333      3/7  12.40%
# 23  0.012085  0.047186      0.432     3/12   8.00%
# 22  0.014035  0.043082      0.393     9/23  19.83%
# 20  0.015504  0.030866      0.281      5/6  15.14%
# 27  0.015432  0.072774       0.63    16/22  26.55%
# 40   0.03871  0.216354      0.978    19/98  12.59%
# 31  0.039344  0.107369       0.81    10/22  26.04%
# 33  0.037975  0.785578      0.882      4/7  23.06%
# 25  0.042373   0.05466      0.507      4/8  12.65%
# 29  0.044207  0.925561      0.727     8/11  22.25%
#
#                                            Lead_genes       FDR
# 0   MRPL16;MRPL37;MRPL14;MRPL15;MRPS7;MRPS18A;MRPL...       0.0
# 16  UQCRFS1;ISCA2;SDHB;ISCU;NDUFV1;NDUFS2;NTHL1;LI...       0.0
# 15  MTPAP;TEFM;MTERF1;TRUB2;MRPS7;TFB1M;MRM3;RMND1...       0.0
# 24  CASP3;TIMM21;OMA1;TIMM17B;UQCRC1;TIMM23;TOMM5;...       0.0
# 10  COX7A2;TIMM21;COX16;COX6A1;COA7;COA3;COA6;COX7...       0.0
# 8   TIMM21;COX16;COA7;COA3;COA6;COX14;SURF1;CMC2;C...       0.0
# 18  NDUFB8;NDUFA12;FOXRED1;NDUFA6;NDUFA1;MT-ND4L;N...       0.0
# 5   TIMM21;COX16;FOXRED1;BCS1L;COA7;COA3;RAB5IF;CO...       0.0
# 4   UQCRFS1;COX7A2;NDUFB8;UQCRC1;UQCR10;NDUFA12;CO...       0.0
# 3   MTERF3;TIMM21;MRPL16;MRPL37;MRPL14;MRPL15;MRPS...       0.0
# 2   UQCRFS1;COX7A2;NDUFB8;TIMM21;UQCRC1;UQCR10;COX...       0.0
# 1   MTPAP;TEFM;MTERF3;TIMM21;MRPL16;MTERF1;MRPL37;...       0.0
# 6   UQCRFS1;UQCRC1;UQCR10;CYC1;BCS1L;UQCRH;UQCR11;...       0.0
# 7                    UQCRFS1;UQCRC1;UQCR10;CYC1;UQCRH  0.022373
# 9   ATP5F1C;ATP5IF1;ATP5MG;FMC1;ATP5PB;ATP5F1A;TME...  0.025319
# 13  TIMM21;TIMM17B;UQCRC1;TIMM23;TOMM5;MTX1;TIMM8A...  0.027806
# 14                                       UQCRC1;PMPCA  0.034379
# 19  ATP5F1C;ATP5IF1;ATP5MG;ATP5PB;ATP5F1A;ATP5PF;A...  0.037374
# 11                 MTPAP;TRUB2;TFB1M;MRM3;NGRN;METTL5  0.037374
# 28  NDUFB8;NDUFA12;NDUFA6;NDUFA1;MT-ND4L;NDUFS4;ND...  0.039173
# 12  MTPAP;TRUB2;MRPS7;TFB1M;RMND1;ERAL1;TRMT10C;MR...  0.039173
# 17       TIMM21;COA3;MTIF3;COX14;TSFM;MTRF1;MRRF;GFM2  0.042835
# 21                                  APOOL;APOO;CHCHD3  0.052951
# 23                                   ETFA;CYC1;ETFRF1  0.054884
# 22  ISCA2;GRPEL1;ISCU;FXN;NDUFAB1;BOLA1;GLRX5;BOLA...  0.061193
# 20               TIMM21;TIMM17B;TIMM23;TIMM50;TIMM17A   0.06259
# 27  FOXRED1;NDUFAF6;TIMMDC1;NDUFAF1;LYRM2;TMEM70;N...   0.06259
# 40  CASP3;BID;APOOL;TMEM11;APOO;OMA1;FUNDC2;GHITM;...  0.142951
# 31  TRMT10C;ALKBH1;NSUN3;PUS1;CDK5RAP1;QTRT1;HSD17...  0.142951
# 33                           ABCB10;ABCD3;ABCD2;ABCD1  0.142951
# 25                           TEFM;MTERF1;MTRES1;TFB2M  0.148989
# 29  SLC25A23;SLC25A13;SLC25A25;SLC25A12;MICU2;SLC2...  0.150581

# %%
temp[temp['FDR']<0.05]['Lead_genes'].to_list()
# Out:
#  'DUSP6;BDNF;CACNA1E;CDC25B;HSPA1B;FGFR1;MAPK8;CACNG2;MRAS;MAP2K5;GNA12;NLK;DUSP3;FGF2;MAPK9;PRKCD;CACNG3;TGFBR1;CACNB1;MAP3K6;PRKACB;CACNA1I;MAPK8IP2;PAK1;NF1;DUSP10;CACNG4;PPM1B;DUSP8;RAPGEF2;HSPA1A;SOS1;NR4A1;PPP3CB;CRK;MAP4K4;TAOK2;MAPK1;RAP1A;MAPKAPK3;KRAS;MAPK14;FOS;TAOK1;MAP2K6;SOS2;MAP4K2;MAP3K12;AKT3;JUND;FLNA;MAPK8IP1;PPM1A;MAP2K1;CACNA1H;CACNA2D2;MAPT;BRAF;CACNA1A;ATF2;CACNA1G;MAP2K4;CACNB2;DUSP1;NRAS;MAPK13;GRB2;TGFB2;MAPKAPK2;TNFRSF1A;PTPN5;MAP2K3;TP53;MAPK12;FGF10;RELB;RASGRF2;AKT1;FGFR2',
#  'PSMB5;PSMC2;PSMB6;PSMB1;PSMB3;PSMD7;PSMB7;PSMA5;PSMC1;PSMB4;PSMA4;UBE2B;PSMA6;PSMD4;PSMD6;PSMC3;PSMD11;PSMC4;PSMB2;PSMC5;PSMD10;PSMA1;PSMA3;PSMD9;PSMD13;PSMB10;PSMD8',
#  'GABRE;GABRA3;GABRB1;GABRG3;GABRA2;GABRG2;GABRG1;ABAT;GABRQ;GABRA5;GAD1;SLC6A11;GPHN;GABRB3;ALDH9A1;AP2A2;AP2A1;GABBR1;SLC6A1;GABRB2',
#  'CLDN6;MAPK8;CLDN23;MMP2;FN1;DLL1;DSP;WNT4;GSK3B;TGFBR1;FZD6;WNT10B;PAK1;FZD7;FZD9;CDH2;CLDN3;FZD3;FZD5;WNT5A;SOS1;LATS2;CTNNB1;CLDN5;LRP6;MAPK1;KRAS;MAPK14;PIK3CB;MAP2K6;SOS2;MEF2D;TUSC3;AKT3;MAP2K1;TJP1;MMP15;MAP2K4;MAPK13;GRB2;TGFB2;MAP2K3;TP53;MAPK12;STRAP;AKT1;JUP;PIK3R3;DLL4;RAF1;EZH2;HRAS;JAG2;PKD1;EIF5A2;MAPK11;SUZ12;LRP5',
#  'SQLE;HMGCR;LSS;IDI1;DHCR7;MVD;SC5D;CYP51A1',
#  'SOX1;DVL3;CSNK1E;MAPK8;PRKCB;NLK;MAPK9;GSK3B;FRAT1;RHOA;MTOR;TSC2;CTNNB1;TCF4;LRP6;MAPK1',
#  'RBP1;CYP26A1;RXRG;CRABP1;CRABP2;DHRS3;LPL;RBP4;SCARB1;MAPK1;RXRA']

# %%
# Step 1: Load your expression data into a DataFrame.
# Replace 'data2.csv' with your actual data file.
data2 = pd.read_csv('data2.csv')

# Step 2: Calculate the score as specified:
# score = log2(P.Value) * sign(logFC)
# (Note: Make sure your P.Values are >0 so that log2 is defined.)
data2['score'] = -np.log2(data2['P.Value']) * np.sign(data2['logFC'])

# Step 3: Prepare a ranked list.
# It is assumed that your DataFrame has a column 'gene' for gene names.
# The ranked list should be sorted by the score in descending order.
rnk = data2[['gene', 'score']].dropna()
rnk = rnk.sort_values('score', ascending=False)

# Optionally, you can save the ranked list to a file in .rnk format,
# which is required by gseapy.prerank (a two-column, tab-delimited file).
rnk.to_csv("ranked_genes.rnk", sep="\t", index=False, header=False)

# Step 4: Load your pathways (gene sets) from a NumPy file.
# The file 'pathways.npy' should contain a dictionary with pathway names as keys
# and a list of gene names as values.
pathways = np.load('pathways.npy', allow_pickle=True).item()

# Step 5: Run GSEApy prerank.
# Adjust permutation_num and other parameters as needed.
pre_res = gp.prerank(
    rnk="ranked_genes.rnk",
    gene_sets=pathways,
    outdir="gseapy_out",
    permutation_num=100,  # For more robust results, increase this number.
    seed=6
)

# Print the top results
print(pre_res.res2d.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[314], line 3
#       1 # Step 1: Load your expression data into a DataFrame.
#       2 # Replace 'data2.csv' with your actual data file.
# ----> 3 data2 = pd.read_csv('data2.csv')
#       5 # Step 2: Calculate the score as specified:
#       6 # score = log2(P.Value) * sign(logFC)
#       7 # (Note: Make sure your P.Values are >0 so that log2 is defined.)
#       8 data2['score'] = -np.log2(data2['P.Value']) * np.sign(data2['logFC'])
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data2.csv'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statannotations.Annotator import Annotator

plt.figure(figsize=(2, 2))
# Select data for batch 1 and H20 treatment
batch_1_seqids = metadata[metadata['Notes'].str.contains('batch 1')]['SeqID']
line_seqids = metadata[metadata['Treatment'] == 'H20']['SeqID']
common_seqids = np.intersect1d(batch_1_seqids, line_seqids)
counts_cpm_protein_coding_batch_1 = counts_cpm_protein_coding.loc[:, common_seqids]

# Create a DataFrame for gene ABCA7; assume gene names are in the index
x = pd.DataFrame(counts_cpm_protein_coding_batch_1.loc['ABCA7'])
x['SeqID'] = x.index

# Merge with metadata on 'SeqID'
merged = pd.merge(x, metadata, on='SeqID')

# Create a swarmplot of ABCA7 expression by Line
ax = sns.swarmplot(x='Line', y='ABCA7', data=merged, hue='Line',
                   palette={'Control': 'grey', 'Y622': 'orange', 'G2': 'blue'})

# Define pairs to compare (adjust these as needed)
pairs = [('Control', 'Y622'), ('Control', 'G2')]
# Define the order of the groups; for example, if you want "Control", "Y622", then "G2"
order = ['Control', 'Y622', 'G2']

# Create and configure the Annotator
annotator = Annotator(ax, pairs, data=merged, x='Line', y='ABCA7', order=order)
annotator.configure(test='t-test_ind', text_format='full', loc='outside',
                    verbose=2, show_test_name=False)
annotator.apply_and_annotate()

plt.legend([], [], frameon=False)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_15542/3609223616.py in ?()
# ---> 19 import numpy as np
#      20 import pandas as pd
#      21 import matplotlib.pyplot as plt
#      22 import seaborn as sns
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/core/reshape/merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     166             validate=validate,
#     167             copy=copy,
#     168         )
#     169     else:
# --> 170         op = _MergeOperation(
#     171             left_df,
#     172             right_df,
#     173             how=how,
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/core/reshape/merge.py in ?(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     790             self.right_join_keys,
#     791             self.join_names,
#     792             left_drop,
#     793             right_drop,
# --> 794         ) = self._get_merge_keys()
#     795
#     796         if left_drop:
#     797             self.left = self.left._drop_labels_or_levels(left_drop)
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/core/reshape/merge.py in ?(self)
#    1293                         # Then we're either Hashable or a wrong-length arraylike,
#    1294                         #  the latter of which will raise
#    1295                         rk = cast(Hashable, rk)
#    1296                         if rk is not None:
# -> 1297                             right_keys.append(right._get_label_or_level_values(rk))
#    1298                         else:
#    1299                             # work-around for merge_asof(right_index=True)
#    1300                             right_keys.append(right.index._values)
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/core/generic.py in ?(self, key, axis)
#    1902         axis = self._get_axis_number(axis)
#    1903         other_axes = [ax for ax in range(self._AXIS_LEN) if ax != axis]
#    1904
#    1905         if self._is_label_reference(key, axis=axis):
# -> 1906             self._check_label_or_level_ambiguity(key, axis=axis)
#    1907             values = self.xs(key, axis=other_axes[0])._values
#    1908         elif self._is_level_reference(key, axis=axis):
#    1909             values = self.axes[axis].get_level_values(key)._values
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/core/generic.py in ?(self, key, axis)
#    1864             msg = (
#    1865                 f"'{key}' is both {level_article} {level_type} level and "
#    1866                 f"{label_article} {label_type} label, which is ambiguous."
#    1867             )
# -> 1868             raise ValueError(msg)
#
# ValueError: 'SeqID' is both an index level and a column label, which is ambiguous.

# %%
metadata.index = metadata['SeqID']

# %%
data2.index = data2['genes']

# %%
data2.loc[['MFN1', 'MFN2', 'DNM1L']]
# Out:
#        genes     logFC   AveExpr         t   P.Value  adj.P.Val         B  \
# genes
# MFN1    MFN1  0.328352  4.195592  3.729983  0.001549   0.007561 -2.378961
# MFN2    MFN2  0.317922  6.415288  3.597135  0.002080   0.009495 -2.976396
# DNM1L  DNM1L  0.187812  7.517285  2.211825  0.040250   0.088808 -5.924745
#
#           score
# genes
# MFN1  -9.334570
# MFN2  -8.909224
# DNM1L -4.634864

# %%
# Select data for batch 1 and H20 treatment
batch_1_seqids = metadata[metadata['Notes'].str.contains('batch 1')]['SeqID']
line_seqids = metadata[metadata['Line'] == 'Y622']['SeqID']
common_seqids = np.intersect1d(batch_1_seqids, line_seqids)
counts_cpm_protein_coding_batch_1 = counts_cpm_protein_coding.loc[:, common_seqids]
counts_cpm_protein_coding_batch_1 = counts_cpm_protein_coding_batch_1.loc[['MFN1', 'MFN2', 'DNM1L']]

counts_cpm_protein_coding_batch_1 = counts_cpm_protein_coding_batch_1.sub(
    counts_cpm_protein_coding_batch_1.mean(axis=1), axis=0
).div(
    counts_cpm_protein_coding_batch_1.std(axis=1), axis=0
)

counts_cpm_protein_coding_batch_1 = counts_cpm_protein_coding_batch_1.T
x = metadata.loc[counts_cpm_protein_coding_batch_1.index]
counts_cpm_protein_coding_batch_1['line'] = x['Line']
counts_cpm_protein_coding_batch_1['treatment'] = x['Treatment']

counts_cpm_protein_coding_batch_1 = pd.melt(counts_cpm_protein_coding_batch_1, id_vars=['line', 'treatment'], value_vars=counts_cpm_protein_coding_batch_1.columns)

counts_cpm_protein_coding_batch_1['grp'] = counts_cpm_protein_coding_batch_1['line'] + '_' + counts_cpm_protein_coding_batch_1['treatment']


plt.figure(figsize=(2, 1))
sns.swarmplot(x='gene_name', y='value', data=counts_cpm_protein_coding_batch_1, hue='grp', dodge=True)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
# Out:
# /Users/djuna/Library/Python/3.9/lib/python/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/djuna/Library/Python/3.9/lib/python/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /var/folders/y7/zpj5hbtd2bl78b1t9h2723hw0000gn/T/ipykernel_15542/1956088963.py:27: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
# Select data for batch 1 and H20 treatment
batch_1_seqids = metadata[metadata['Notes'].str.contains('batch 1')]['SeqID']
line_seqids = metadata[metadata['Line'] == 'Y622']['SeqID']
common_seqids = np.intersect1d(batch_1_seqids, line_seqids)
counts_cpm_protein_coding_batch_1 = counts_cpm_protein_coding.loc[:, common_seqids]
counts_cpm_protein_coding_batch_1 = counts_cpm_protein_coding_batch_1.loc[['CHKA', 'CHKB', 'PCYT1B', 'CEPT1', 'PEMT', 'LPCAT1', 'LPCAT2', 'LPCAT3', 'LPCAT4']]

counts_cpm_protein_coding_batch_1 = counts_cpm_protein_coding_batch_1.sub(
    counts_cpm_protein_coding_batch_1.mean(axis=1), axis=0
).div(
    counts_cpm_protein_coding_batch_1.std(axis=1), axis=0
)

counts_cpm_protein_coding_batch_1 = counts_cpm_protein_coding_batch_1.T
x = metadata.loc[counts_cpm_protein_coding_batch_1.index]
counts_cpm_protein_coding_batch_1['line'] = x['Line']
counts_cpm_protein_coding_batch_1['treatment'] = x['Treatment']

counts_cpm_protein_coding_batch_1 = pd.melt(counts_cpm_protein_coding_batch_1, id_vars=['line', 'treatment'], value_vars=counts_cpm_protein_coding_batch_1.columns)

counts_cpm_protein_coding_batch_1['grp'] = counts_cpm_protein_coding_batch_1['line'] + '_' + counts_cpm_protein_coding_batch_1['treatment']


plt.figure(figsize=(5, 2))
sns.boxplot(x='gene_name', y='value', data=counts_cpm_protein_coding_batch_1, hue='grp')
plt.legend().remove()
plt.tight_layout()

# %%
data1.index = data1['genes']

# %%
data2.loc[['CHKA', 'CHKB', 'PCYT1A', 'PCYT1B', 'CHPT1', 'CEPT1', 'PEMT', 'LPCAT1', 'LPCAT2', 'LPCAT3', 'LPCAT4']]
# Out:
#          genes     logFC   AveExpr         t   P.Value  adj.P.Val         B  \
# genes
# CHKA      CHKA -0.190555  5.818572 -2.830800  0.011135   0.033582 -4.558723
# CHKB      CHKB  0.650668  0.017244  2.568974  0.019391   0.051106 -3.805171
# PCYT1A  PCYT1A -0.151971  3.736764 -1.602655  0.126539   0.217051 -6.448413
# PCYT1B  PCYT1B  0.301386  5.284164  3.939732  0.000972   0.005361 -2.090959
# CHPT1    CHPT1 -0.089040  6.249736 -1.541826  0.140638   0.234792 -6.917653
# CEPT1    CEPT1  0.312544  4.704705  3.728636  0.001554   0.007572 -2.471126
# PEMT      PEMT -0.195513  5.518065 -2.901862  0.009558   0.029904 -4.375961
# LPCAT1  LPCAT1  0.334958  6.227937  4.309574  0.000428   0.002873 -1.376837
# LPCAT2  LPCAT2  1.288040  1.522171  6.823165  0.000002   0.000049  4.834189
# LPCAT3  LPCAT3  0.280044  3.740435  2.501278  0.022327   0.056800 -4.883862
# LPCAT4  LPCAT4  0.293464  5.055527  4.014535  0.000823   0.004680 -1.892157
#
#             score
# genes
# CHKA     6.488719
# CHKB    -5.688480
# PCYT1A   2.982347
# PCYT1B -10.006656
# CHPT1    2.829942
# CEPT1   -9.330255
# PEMT     6.709063
# LPCAT1 -11.188844
# LPCAT2 -18.748726
# LPCAT3  -5.485036
# LPCAT4 -10.246228

# %%
counts_cpm_protein_coding_batch_1['grp'] = counts_cpm_protein_coding_batch_1['line'] + '_' + counts_cpm_protein_coding_batch_1['treatment']

# %%
counts_cpm_protein_coding_batch_1.head()
# Out:
#       line treatment gene_name      value          grp
# 0  Control       H20      MFN1  20.938322  Control_H20
# 1  Control       H20      MFN1  20.727382  Control_H20
# 2     Y622       H20      MFN1  17.037154     Y622_H20
# 3     Y622       H20      MFN1  15.352705     Y622_H20
# 4     Y622       H20      MFN1  14.399624     Y622_H20

# %%
g = sns.FacetGrid(
    counts_cpm_protein_coding_batch_1,
    col='gene_name',
    sharex=False,
    sharey=False,
    height=2,      # height of each facet (in inches)
    aspect=0.5       # width/height ratio of each facet
)
g.map_dataframe(sns.boxplot, x='grp', y='value', hue='line')
# Out:
# /Users/djuna/Library/Python/3.9/lib/python/site-packages/seaborn/axisgrid.py:118: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   self._figure.tight_layout(*args, **kwargs)

# %%
np.log2(0.1)
# Out:
# -3.321928094887362

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy import stats
import stack_data  # Adjust this to your module's data-loading function

data1['score'] = -np.log10(data1['P.Value']) * np.sign(data1['logFC'])
data2['score'] = -np.log10(data2['P.Value']) * np.sign(data2['logFC'])

data_merged = pd.merge(data1, data2, left_index=True, right_index=True)


plt.figure(figsize=(4, 4))

# Create a random subsample (e.g., 10% of the points)
sample_df = data_merged.sample(frac=0.2, random_state=42)

# Plot the regression line using the full dataset without scatter points
sns.regplot(x='score_x', y='score_y', data=data_merged, scatter=False, ci=95, color='black', line_kws={'linewidth': 1})

# Overlay scatter points from the subsample
sns.scatterplot(x='score_x', y='score_y', data=sample_df, color='black', alpha=0.3, s=20)

# Calculate Pearson correlation coefficient and p-value
r, p = stats.pearsonr(data_merged['score_x'], data_merged['score_y'])

# Add text annotation with the correlation coefficient
plt.text(0.05, 0.95, f'Pearson r = {r:.3f}',
         transform=plt.gca().transAxes, verticalalignment='top')

# Add horizontal and vertical dotted lines at zero
plt.axhline(y=0, color='grey', linestyle='dotted')
plt.axvline(x=0, color='grey', linestyle='dotted')

plt.xlabel('WT vs p.Tyr622*')
plt.ylabel('p.Tyr622* + H$_2$O vs p.Tyr622* + CDP-choline')
# Add arrow in lower right quadrant
plt.annotate('', xy=(50, -60), xytext=(20, -60),
             arrowprops=dict(facecolor='black', shrink=0.05, width=2, headwidth=8))
plt.text(25, -55, 'Up in LoF & \n Down in CDP-choline', ha='center')

plt.savefig('../../paper/main_plots/rna_correlation_plot.png', bbox_inches='tight')

plt.show()

# %%
data_merged['score_x'].values
# Out:
# array([ 4.60035812e+01,  4.24418036e+01,  3.78688921e+01, ...,
#         6.83807812e-04, -5.77856573e-04, -6.87487687e-05])

# %%
data_merged['score_x2'] = -1*data_merged['score_x']
data_merged['S'] = data_merged[['score_x2','score_y']].mean(axis=1)

# Sort data_merged by S column in descending order
data_merged = data_merged.sort_values('S', ascending=False)

# %%
data_merged[-20:]
# Out:
#                      genes_x   logFC_x  AveExpr_x        t_x     P.Value_x  \
# ENSG00000171551.12     ECEL1 -0.753956   5.766764  -7.026581  1.109785e-05
# ENSG00000163297.18    ANTXR2 -2.329199   2.275820 -14.511808  3.412380e-09
# ENSG00000164756.13   SLC30A8 -6.409202  -0.271344 -16.369277  8.122650e-10
# ENSG00000145248.7    SLC10A4 -0.917822   6.128881  -9.904938  2.812014e-07
# ENSG00000115665.9     SLC5A7 -1.019677   3.714263  -7.221425  8.397098e-06
# ENSG00000106829.21      TLE4 -0.729269   5.978892  -7.364115  6.866947e-06
# ENSG00000187714.7    SLC18A3 -1.206589   4.742754 -10.378404  1.663964e-07
# ENSG00000159176.14     CSRP1 -1.352676   5.498786 -14.301277  4.056906e-09
# ENSG00000262655.4      SPON1 -1.989786   3.008746 -11.120279  7.594047e-08
# ENSG00000147065.18       MSN -2.322210   3.700418 -14.419909  3.679044e-09
# ENSG00000166736.12     HTR3A -2.443531   3.553720 -17.603030  3.392344e-10
# ENSG00000075223.14    SEMA3C -1.698668   6.145250 -13.381833  8.878288e-09
# ENSG00000119973.6      PRLHR -1.050508   3.223033  -7.719030  4.209198e-06
# ENSG00000121691.7        CAT -9.251469  -2.005603 -25.357150  3.984076e-12
# ENSG00000109132.7     PHOX2B -1.610724   6.389907 -17.107903  4.782311e-10
# ENSG00000180616.9      SSTR2 -1.626017   5.454188 -15.542240  1.509639e-09
# ENSG00000147256.12  ARHGAP36 -1.499875   7.310729 -18.446702  1.928093e-10
# ENSG00000198105.16    ZNF248 -7.518673   0.796406 -23.058675  1.276735e-11
# ENSG00000083750.13     RRAGB -9.288784   0.757204 -32.792928  1.673956e-13
# ENSG00000131773.15   KHDRBS3 -8.247147   1.515007 -40.023848  1.417562e-14
#
#                      adj.P.Val_x        B_x    score_x   genes_y   logFC_y  \
# ENSG00000171551.12  7.986810e-04   3.058038  16.459361     ECEL1  1.377586
# ENSG00000163297.18  2.496724e-06  11.660240  28.126575    ANTXR2  1.841740
# ENSG00000164756.13  8.914609e-07  12.031733  30.197330   SLC30A8  4.667823
# ENSG00000145248.7   5.973262e-05   6.897667  21.761893   SLC10A4  1.206352
# ENSG00000115665.9   6.675014e-04   3.553619  16.861678    SLC5A7  2.360435
# ENSG00000106829.21  5.677653e-04   3.547516  17.151900      TLE4  1.488748
# ENSG00000187714.7   4.134795e-05   7.542662  22.518872   SLC18A3  1.815559
# ENSG00000159176.14  2.671472e-06  11.363133  27.876973     CSRP1  1.232872
# ENSG00000262655.4   2.222524e-05   8.501467  23.650556     SPON1  2.231512
# ELOVL1  ELOVL1 -0.105811  3.126014  -0.784189  4.432005e-01  5.597919e-01
#
#                B      score
# genes
# ELOVL6  9.994114  27.005995
# ELOVL5 -1.191381 -11.617111
# ELOVL3 -3.492923   5.914522
# ELOVL4 -6.336750  -4.089691
# ELOVL7 -4.973397  -3.698107
# ELOVL2 -6.126826  -3.580687
# ELOVL1 -7.261998   1.173969

# %%
genes1 = data1[(data1['genes'].str.startswith('ABCA')) & (data1['adj.P.Val'] < 0.05)]['genes']
genes2 = data2[(data2['genes'].str.startswith('ABCA')) & (data2['adj.P.Val'] < 0.05)]['genes']

# %%
intersect_genes = np.intersect1d(genes1, genes2)
genes2
# Out:
# ENSG00000154265.16    ABCA5
# ENSG00000064687.13    ABCA7
# ENSG00000167972.14    ABCA3
# ENSG00000107331.18    ABCA2
# Name: genes, dtype: object

# %%
# show PCA; treatment batch 1
batch_1_seqids = metadata[metadata['Notes'].str.contains('batch 1')]['SeqID']
line_seqids = metadata[metadata['Treatment'] == 'H20']['SeqID']
counts_cpm_protein_coding_batch_1 = counts_cpm_protein_coding[np.intersect1d(batch_1_seqids, line_seqids)]


# Perform PCA on the counts_cpm_protein_coding
scaler = StandardScaler()
counts_cpm_protein_coding_scaled = scaler.fit_transform(counts_cpm_protein_coding_batch_1.T)
pca = PCA(n_components=2)
principal_components = pca.fit_transform(counts_cpm_protein_coding_scaled)

# Create a DataFrame with the principal components
pca_df = pd.DataFrame(data=principal_components, columns=['PC1', 'PC2'])
pca_df['SeqID'] = counts_cpm_protein_coding_batch_1.columns

pca_df = pd.merge(pca_df, metadata, on='SeqID')

plt.figure(figsize=(5, 5))
sns.scatterplot(x='PC1', y='PC2', hue='Line', style='Treatment', data=pca_df, palette='viridis', edgecolor='w')

# Calculate the explained variance for each principal component
explained_variance = pca.explained_variance_ratio_

plt.xlabel(f'Principal Component 1 ({explained_variance[0]*100:.2f}% Variance)')
plt.ylabel(f'Principal Component 2 ({explained_variance[1]*100:.2f}% Variance)')
plt.title('PCA of Protein Coding Gene Counts')
plt.legend(title='Line', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
treatment_seqids
# Out:
# 0     D24-18553
# 1     D24-18554
# 2     D24-18555
# 3     D24-18556
# 4     D24-18557
# 5     D24-18558
# 6     D24-18559
# 7     D24-18560
# 8     D24-18561
# 9     D24-18562
# 18    D24-18571
# 19    D24-18572
# 20    D24-18574
# 21    D24-18575
# 22    D24-18576
# 23    D24-18577
# 24    D24-18578
# 25    D24-18580
# Name: SeqID, dtype: object

# %%
# show PCA; treatment batch 1
batch_1_seqids = metadata[metadata['Notes'].str.contains('batch 1')]['SeqID']
line_seqids = metadata[metadata['Line']!= 'Control']['SeqID']
treatment_seqids = metadata[metadata['Treatment'] == 'H20']['SeqID']
counts_cpm_protein_coding_batch_1 = counts_cpm_protein_coding[np.intersect1d(np.intersect1d(batch_1_seqids, line_seqids), (treatment_seqids))]


# Perform PCA on the counts_cpm_protein_coding
scaler = StandardScaler()
counts_cpm_protein_coding_scaled = scaler.fit_transform(counts_cpm_protein_coding_batch_1.T)
pca = PCA(n_components=2)
principal_components = pca.fit_transform(counts_cpm_protein_coding_scaled)

# Create a DataFrame with the principal components
pca_df = pd.DataFrame(data=principal_components, columns=['PC1', 'PC2'])
pca_df['SeqID'] = counts_cpm_protein_coding_batch_1.columns

pca_df = pd.merge(pca_df, metadata, on='SeqID')

plt.figure(figsize=(5, 5))
sns.scatterplot(x='PC1', y='PC2', hue='Line', style='Treatment', data=pca_df, palette='viridis', edgecolor='w')

# Calculate the explained variance for each principal component
explained_variance = pca.explained_variance_ratio_

plt.xlabel(f'Principal Component 1 ({explained_variance[0]*100:.2f}% Variance)')
plt.ylabel(f'Principal Component 2 ({explained_variance[1]*100:.2f}% Variance)')
plt.title('PCA of Protein Coding Gene Counts')
plt.legend(title='Line', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
#
# 19        30  2-10 ng/ul  totalRNA   NaN  human
# 20        30  2-10 ng/ul  totalRNA   NaN  human
# 21        30  2-10 ng/ul  totalRNA   NaN  human
# 22        30  2-10 ng/ul  totalRNA   NaN  human
# 23        30  2-10 ng/ul  totalRNA   NaN  human
# 24        30  2-10 ng/ul  totalRNA   NaN  human
# 25        30  2-10 ng/ul  totalRNA   NaN  human
#
#                                                 Notes
# 0   diff & extraction batch 1 (1 well, DOI:101624,...
# 1   diff & extraction batch 1 (1 well, DOI:101624,...
# 2   diff & extraction batch 1 (1 well, DOI:101624,...
# 3   diff & extraction batch 1 (1 well, DOI:101624,...
# 4   diff & extraction batch 1 (1 well, DOI:101624,...
# 5   diff & extraction batch 1 (1 well, DOI:101624,...
# 6   diff & extraction batch 1 (1 well, DOI:101624,...
# 7          diff & extraction batch 2 (2 wells pooled)
# 8          diff & extraction batch 2 (2 wells pooled)
# 9          diff & extraction batch 2 (2 wells pooled)
# 10  diff & extraction batch 1 (1 well, DOI:101624,...
# 11  diff & extraction batch 1 (1 well, DOI:101624,...
# 12  diff & extraction batch 1 (1 well, DOI:101624,...
# 13  diff & extraction batch 1 (1 well, DOI:101624,...
# 14  diff & extraction batch 1 (1 well, DOI:101624,...
# 15         diff & extraction batch 2 (2 wells pooled)
# 16         diff & extraction batch 2 (2 wells pooled)
# 17         diff & extraction batch 2 (2 wells pooled)
# 18  diff & extraction batch 1 (1 well, DOI:101624,...
# 19  diff & extraction batch 1 (1 well, DOI:101624,...
# 20  diff & extraction batch 1 (1 well, DOI:101624,...
# 21  diff & extraction batch 1 (1 well, DOI:101624,...
# 22  diff & extraction batch 1 (1 well, DOI:101624,...
# 23         diff & extraction batch 2 (2 wells pooled)
# 24         diff & extraction batch 2 (2 wells pooled)
# 25         diff & extraction batch 2 (2 wells pooled)

# %%
import seaborn as sns
import matplotlib.pyplot as plt


plt.figure(figsize=(5, 5))
sns.scatterplot(x='PC1', y='PC2', hue='Line', style='Treatment', data=pca_df, palette='viridis', edgecolor='w')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA of Protein Coding Gene Counts')
plt.legend(title='Line', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
metadata
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 metadata
#
# NameError: name 'metadata' is not defined

# %%
metadata
# Out:
#                SampleName     Line      Treatment  Vol (ul)        Conc  \
# SeqID
#     D24-18553          E1  Control            H20        30  2-10 ng/ul
#     D24-18554          E2  Control            H20        30  2-10 ng/ul
#     D24-18555          Y1     Y622            H20        30  2-10 ng/ul
#     D24-18556          Y2     Y622            H20        30  2-10 ng/ul
#     D24-18557          Y3     Y622            H20        30  2-10 ng/ul
#     D24-18558          Y4     Y622            H20        30  2-10 ng/ul
#     D24-18559          Y5     Y622            H20        30  2-10 ng/ul
#     D24-18560          Y6     Y622            H20        30  2-10 ng/ul
#     D24-18561          Y7     Y622            H20        30  2-10 ng/ul
#     D24-18562          Y8     Y622            H20        30  2-10 ng/ul
#     D24-18563          C1     Y622  Choline2Weeks        30  2-10 ng/ul
#     D24-18564          C2     Y622  Choline2Weeks        30  2-10 ng/ul
#     D24-18565          C3     Y622  Choline2Weeks        30  2-10 ng/ul
#     D24-18566          C4     Y622  Choline2Weeks        30  2-10 ng/ul
#     D24-18567          C5     Y622  Choline2Weeks        30  2-10 ng/ul
#     D24-18568          C6     Y622  Choline2Weeks        30  2-10 ng/ul
#     D24-18569          C7     Y622  Choline2Weeks        30  2-10 ng/ul
#     D24-18570          C8     Y622  Choline2Weeks        30  2-10 ng/ul
#     D24-18571          G1       G2            H20        30  2-10 ng/ul
#     D24-18572          G2       G2            H20        30  2-10 ng/ul
#     D24-18574          G4       G2            H20        30  2-10 ng/ul
#     D24-18575          G5       G2            H20        30  2-10 ng/ul
#     D24-18576          G6       G2            H20        30  2-10 ng/ul
#     D24-18577          G7       G2            H20        30  2-10 ng/ul
#     D24-18578          G8       G2            H20        30  2-10 ng/ul
#     D24-18580         G10       G2            H20        30  2-10 ng/ul
#
#                     Type  Pool Genome  \
# SeqID
#     D24-18553   totalRNA   NaN  human
#     D24-18554   totalRNA   NaN  human
#     D24-18555   totalRNA   NaN  human
#     D24-18556   totalRNA   NaN  human
#     D24-18557   totalRNA   NaN  human
#     D24-18558   totalRNA   NaN  human
#     D24-18559   totalRNA   NaN  human
#     D24-18560   totalRNA   NaN  human
#     D24-18561   totalRNA   NaN  human
#     D24-18562   totalRNA   NaN  human
#     D24-18563   totalRNA   NaN  human
#     D24-18564   totalRNA   NaN  human
#     D24-18565   totalRNA   NaN  human
#     D24-18566   totalRNA   NaN  human
#     D24-18567   totalRNA   NaN  human
#     D24-18568   totalRNA   NaN  human
#     D24-18569   totalRNA   NaN  human
#     D24-18570   totalRNA   NaN  human
#     D24-18571   totalRNA   NaN  human
#     D24-18572   totalRNA   NaN  human
#     D24-18574   totalRNA   NaN  human
#     D24-18575   totalRNA   NaN  human
#     D24-18576   totalRNA   NaN  human
#     D24-18577   totalRNA   NaN  human
#     D24-18578   totalRNA   NaN  human
#     D24-18580   totalRNA   NaN  human
#
#                                                             Notes  \
# SeqID
#     D24-18553   diff & extraction batch 1 (1 well, DOI:101624,...
#     D24-18554   diff & extraction batch 1 (1 well, DOI:101624,...
#     D24-18555   diff & extraction batch 1 (1 well, DOI:101624,...
#     D24-18556   diff & extraction batch 1 (1 well, DOI:101624,...
#     D24-18557   diff & extraction batch 1 (1 well, DOI:101624,...
#     D24-18558   diff & extraction batch 1 (1 well, DOI:101624,...
#     D24-18559   diff & extraction batch 1 (1 well, DOI:101624,...
#     D24-18560          diff & extraction batch 2 (2 wells pooled)
#     D24-18561          diff & extraction batch 2 (2 wells pooled)
#     D24-18562          diff & extraction batch 2 (2 wells pooled)
#     D24-18563   diff & extraction batch 1 (1 well, DOI:101624,...
#     D24-18564   diff & extraction batch 1 (1 well, DOI:101624,...
#     D24-18565   diff & extraction batch 1 (1 well, DOI:101624,...
#     D24-18566   diff & extraction batch 1 (1 well, DOI:101624,...
#     D24-18567   diff & extraction batch 1 (1 well, DOI:101624,...
#     D24-18568          diff & extraction batch 2 (2 wells pooled)
#     D24-18569          diff & extraction batch 2 (2 wells pooled)
#     D24-18570          diff & extraction batch 2 (2 wells pooled)
#     D24-18571   diff & extraction batch 1 (1 well, DOI:101624,...
#     D24-18572   diff & extraction batch 1 (1 well, DOI:101624,...
#     D24-18574   diff & extraction batch 1 (1 well, DOI:101624,...
#     D24-18575   diff & extraction batch 1 (1 well, DOI:101624,...
#     D24-18576   diff & extraction batch 1 (1 well, DOI:101624,...
#     D24-18577          diff & extraction batch 2 (2 wells pooled)
#     D24-18578          diff & extraction batch 2 (2 wells pooled)
#     D24-18580          diff & extraction batch 2 (2 wells pooled)
#
#                          SeqID
# SeqID
#     D24-18553       D24-18553
#     D24-18554       D24-18554
#     D24-18555       D24-18555
#     D24-18556       D24-18556
#     D24-18557       D24-18557
#     D24-18558       D24-18558
#     D24-18559       D24-18559
#     D24-18560       D24-18560
#     D24-18561       D24-18561
#     D24-18562       D24-18562
#     D24-18563       D24-18563
#     D24-18564       D24-18564
#     D24-18565       D24-18565
#     D24-18566       D24-18566
#     D24-18567       D24-18567
#     D24-18568       D24-18568
#     D24-18569       D24-18569
#     D24-18570       D24-18570
#     D24-18571       D24-18571
#     D24-18572       D24-18572
#     D24-18574       D24-18574
#     D24-18575       D24-18575
#     D24-18576       D24-18576
#     D24-18577       D24-18577
#     D24-18578       D24-18578
#     D24-18580       D24-18580

# %%
x = counts_cpm_protein_coding.mean(axis=1).sort_values(ascending=False).index

# %%
np.where(x=='ABCA7')
# Out:
# (array([9398]),)
